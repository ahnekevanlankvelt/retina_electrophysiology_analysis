# %% [markdown]
# ## Import Packages

# %%
from pathlib import Path

import pyabf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.integrate import trapezoid

import ipywidgets as widgets
from IPython.display import display

sns.set_context("talk")
sns.set_style("whitegrid")

# %% [markdown]
# ## Set folder paths

# %%
PROJECT = Path.home() / "Desktop" / "retina_project"

DATA_DIR = PROJECT / "data"
META_DIR = PROJECT / "metadata"
NOTEBOOK_DIR = PROJECT / "notebooks"
RESULTS_DIR = PROJECT / "results"
FIG_DIR = RESULTS_DIR / "figures"

META_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)
FIG_DIR.mkdir(exist_ok=True)

print("Project folder:", PROJECT)
print("Data folder:", DATA_DIR)
print("Metadata folder:", META_DIR)
print("Results folder:", RESULTS_DIR)
# Out:
# Project folder: /Users/ahnekevanlankvelt/Desktop/retina_project
# Data folder: /Users/ahnekevanlankvelt/Desktop/retina_project/data
# Metadata folder: /Users/ahnekevanlankvelt/Desktop/retina_project/metadata
# Results folder: /Users/ahnekevanlankvelt/Desktop/retina_project/results

# %% [markdown]
# ## Create metadata table

# %%
META_FILE = META_DIR / "experiment_metadata.csv"

metadata = pd.DataFrame([
    {
        "file": "2026_05_08_0000.abf",
        "drug": "control",
        "stimulus_type": "spot",
        "center_sf": np.nan,
        "surround_sf": np.nan,
        "sweeps": "0",
        "clamp_mV": -70,
        "notes": "simple spot diameter 200um contrast 4090"
    },
    {
        "file": "2026_05_08_0010.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0011.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 32,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0012.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0013.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center only"
    },
    {
        "file": "2026_05_08_0014.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 4,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0015.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 8,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0016.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0017.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 0.5,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0023.abf",
        "drug": "TTX",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center only"
    },
    {
        "file": "2026_05_08_0024.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0025.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0026.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 4,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0028.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 0.5,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0029.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 32,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0030.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    },
    {
        "file": "2026_05_08_0031.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 8,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 20 surround contrast 50"
    }

])

metadata.to_csv(META_FILE, index=False)
metadata
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_08_0000.abf  control             spot        NaN          NaN
# 1   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 2   2026_05_08_0011.abf  control  center_surround        1.0         32.0
# 3   2026_05_08_0012.abf  control  center_surround        1.0          2.0
# 4   2026_05_08_0013.abf  control      center_only        1.0        100.0
# 5   2026_05_08_0014.abf  control  center_surround        1.0          4.0
# 6   2026_05_08_0015.abf  control  center_surround        1.0          8.0
# 7   2026_05_08_0016.abf  control  center_surround        1.0         16.0
# 8   2026_05_08_0017.abf  control  center_surround        1.0          0.5
# 9   2026_05_08_0023.abf      TTX      center_only        1.0        100.0
# 10  2026_05_08_0024.abf      TTX  center_surround        1.0         16.0
# 11  2026_05_08_0025.abf      TTX  center_surround        1.0          1.0
# 12  2026_05_08_0026.abf      TTX  center_surround        1.0          4.0
# 13  2026_05_08_0028.abf      TTX  center_surround        1.0          0.5
# 14  2026_05_08_0029.abf      TTX  center_surround        1.0         32.0
# 15  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 16  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
#
#    sweeps  clamp_mV                                     notes
# 0       0       -70  simple spot diameter 200um contrast 4090
# 1   0;1;2       -70   center contrast 20 surround contrast 50
# 2   0;1;2       -70   center contrast 20 surround contrast 50
# 3   0;1;2       -70   center contrast 20 surround contrast 50
# 4   0;1;2       -70                               center only
# 5   0;1;2       -70   center contrast 20 surround contrast 50
# 6   0;1;2       -70   center contrast 20 surround contrast 50
# 7   0;1;2       -70   center contrast 20 surround contrast 50
# 8   0;1;2       -70   center contrast 20 surround contrast 50
# 9   0;1;2       -70                               center only
# 10  0;1;2       -70   center contrast 20 surround contrast 50
# 11  0;1;2       -70   center contrast 20 surround contrast 50
# 12  0;1;2       -70   center contrast 20 surround contrast 50
# 13  0;1;2       -70   center contrast 20 surround contrast 50
# 14  0;1;2       -70   center contrast 20 surround contrast 50
# 15  0;1;2       -70   center contrast 20 surround contrast 50
# 16  0;1;2       -70   center contrast 20 surround contrast 50

# %% [markdown]
# ## Load Metadata

# %%
META_FILE = META_DIR / "experiment_metadata.csv"

metadata = pd.read_csv(META_FILE)

metadata
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_08_0000.abf  control             spot        NaN          NaN
# 1   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 2   2026_05_08_0011.abf  control  center_surround        1.0         32.0
# 3   2026_05_08_0012.abf  control  center_surround        1.0          2.0
# 4   2026_05_08_0013.abf  control      center_only        1.0        100.0
# 5   2026_05_08_0014.abf  control  center_surround        1.0          4.0
# 6   2026_05_08_0015.abf  control  center_surround        1.0          8.0
# 7   2026_05_08_0016.abf  control  center_surround        1.0         16.0
# 8   2026_05_08_0017.abf  control  center_surround        1.0          0.5
# 9   2026_05_08_0023.abf      TTX      center_only        1.0        100.0
# 10  2026_05_08_0024.abf      TTX  center_surround        1.0         16.0
# 11  2026_05_08_0025.abf      TTX  center_surround        1.0          1.0
# 12  2026_05_08_0026.abf      TTX  center_surround        1.0          4.0
# 13  2026_05_08_0028.abf      TTX  center_surround        1.0          0.5
# 14  2026_05_08_0029.abf      TTX  center_surround        1.0         32.0
# 15  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 16  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
#
#    sweeps  clamp_mV                                     notes
# 0       0       -70  simple spot diameter 200um contrast 4090
# 1   0;1;2       -70   center contrast 20 surround contrast 50
# 2   0;1;2       -70   center contrast 20 surround contrast 50
# 3   0;1;2       -70   center contrast 20 surround contrast 50
# 4   0;1;2       -70                               center only
# 5   0;1;2       -70   center contrast 20 surround contrast 50
# 6   0;1;2       -70   center contrast 20 surround contrast 50
# 7   0;1;2       -70   center contrast 20 surround contrast 50
# 8   0;1;2       -70   center contrast 20 surround contrast 50
# 9   0;1;2       -70                               center only
# 10  0;1;2       -70   center contrast 20 surround contrast 50
# 11  0;1;2       -70   center contrast 20 surround contrast 50
# 12  0;1;2       -70   center contrast 20 surround contrast 50
# 13  0;1;2       -70   center contrast 20 surround contrast 50
# 14  0;1;2       -70   center contrast 20 surround contrast 50
# 15  0;1;2       -70   center contrast 20 surround contrast 50
# 16  0;1;2       -70   center contrast 20 surround contrast 50

# %% [markdown]
# ## Define helper functions to load ABF files

# %%
def parse_sweeps(sweep_string):
    """
    Converts a sweep string like '0;1;2' into a list: [0, 1, 2].
    """
    return [int(s.strip()) for s in str(sweep_string).split(";")]


def load_sweeps(file_name, sweeps):
    """
    Loads multiple sweeps from one ABF file.

    Parameters
    ----------
    file_name : str
        Name of the ABF file.
    sweeps : list
        List of sweep numbers, for example [0, 1, 2].

    Returns
    -------
    time : array
        Time values in seconds.
    traces : array
        Shape is number of sweeps x number of timepoints.
    """

    file_path = DATA_DIR / file_name

    if not file_path.exists():
        raise FileNotFoundError(f"Could not find file: {file_path}")

    abf = pyabf.ABF(str(file_path))

    traces = []
    time = None

    for sweep in sweeps:
        abf.setSweep(int(sweep))

        if time is None:
            time = abf.sweepX

        traces.append(abf.sweepY)

    traces = np.array(traces)

    return time, traces

# %% [markdown]
# ## load and plot one file's three sweeps

# %%
test_file = metadata.loc[1, "file"]
test_sweeps = parse_sweeps(metadata.loc[1, "sweeps"])

time, traces = load_sweeps(test_file, test_sweeps)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, traces):
    plt.plot(time, trace, alpha=0.7, label=f"Sweep {sweep_number}")

plt.xlabel("Time (s)")
plt.ylabel("Current (pA)")
plt.title(test_file)
plt.legend()
plt.show()

# %% [markdown]
# ## Baseline-subtract each sweep

# %%
def baseline_subtract_traces(time, traces, baseline_window=(0.2, 1.0)):
    """
    Baseline-subtracts each sweep independently.

    Parameters
    ----------
    time : array
        Time values.
    traces : array
        Shape is number of sweeps x number of timepoints.
    baseline_window : tuple
        Start and end of baseline window in seconds.

    Returns
    -------
    corrected_traces : array
        Baseline-subtracted traces.
    baselines : array
        Baseline mean for each sweep.
    """

    baseline_mask = (time >= baseline_window[0]) & (time <= baseline_window[1])

    corrected_traces = []
    baselines = []

    for trace in traces:
        baseline = np.mean(trace[baseline_mask])
        baselines.append(baseline)
        corrected_traces.append(trace - baseline)

    corrected_traces = np.array(corrected_traces)
    baselines = np.array(baselines)

    return corrected_traces, baselines

# %%
baseline_window = (0.2, 1.0)

corrected_traces, baselines = baseline_subtract_traces(
    time,
    traces,
    baseline_window=baseline_window
)

print("Baseline values for each sweep:", baselines)
# Out:
# Baseline values for each sweep: [-37.867  -37.5567 -36.9041]

# %% [markdown]
# ## Average the baseline-subtracted sweeps

# %%
def average_baseline_corrected_sweeps(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0)
):
    """
    Loads sweeps, baseline-subtracts each sweep, then averages them.
    """

    time, traces = load_sweeps(file_name, sweeps)

    corrected_traces, baselines = baseline_subtract_traces(
        time,
        traces,
        baseline_window=baseline_window
    )

    average_trace = np.mean(corrected_traces, axis=0)

    return time, corrected_traces, average_trace, baselines

# %%
time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
    test_file,
    test_sweeps,
    baseline_window=(0.2, 1.0)
)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, corrected_traces):
    plt.plot(time, trace, alpha=0.35, label=f"Sweep {sweep_number}")

plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

plt.axhline(0, color="black", lw=1)
plt.xlabel("Time (s)")
plt.ylabel("Baseline-subtracted current (pA)")
plt.title(f"{test_file}: baseline-subtracted sweeps and average")
plt.legend()
plt.show()

# %% [markdown]
# ## Make a reusable plotting function

# %%
def plot_condition_average(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(1.2, 10.0),
    title=None
):
    """
    Plots individual baseline-subtracted sweeps and their average.
    """

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    plt.figure(figsize=(12, 5))

    for sweep_number, trace in zip(sweeps, corrected_traces):
        plt.plot(time, trace, alpha=0.35, lw=1, label=f"Sweep {sweep_number}")

    plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

    plt.axvspan(
        baseline_window[0],
        baseline_window[1],
        color="gray",
        alpha=0.15,
        label="baseline"
    )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    if title is None:
        title = f"{file_name}, sweeps {sweeps}"

    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_condition_average(
    file_name=test_file,
    sweeps=test_sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(1.2, 10.0)
)

# %% [markdown]
# ## Add interactive viewer

# %%
file_dropdown = widgets.Dropdown(
    options=metadata["file"].tolist(),
    description="File:",
    layout=widgets.Layout(width="400px")
)

baseline_start_widget = widgets.FloatText(value=0.2, description="Base start")
baseline_end_widget = widgets.FloatText(value=1.0, description="Base end")

stim_start_widget = widgets.FloatText(value=1.2, description="Stim start")
stim_end_widget = widgets.FloatText(value=10.0, description="Stim end")


def interactive_average_plot(file_name, b0, b1, s0, s1):
    row = metadata[metadata["file"] == file_name].iloc[0]
    sweeps = parse_sweeps(row["sweeps"])

    title = (
        f"{file_name} | {row['drug']} | {row['stimulus_type']} | "
        f"center SF={row['center_sf']} | surround SF={row['surround_sf']}"
    )

    plot_condition_average(
        file_name=file_name,
        sweeps=sweeps,
        baseline_window=(b0, b1),
        stim_window=(s0, s1),
        title=title
    )


widgets.interact(
    interactive_average_plot,
    file_name=file_dropdown,
    b0=baseline_start_widget,
    b1=baseline_end_widget,
    s0=stim_start_widget,
    s1=stim_end_widget
);
# Out:
# interactive(children=(Dropdown(description='File:', layout=Layout(width='400px'), options=('2026_05_08_0000.ab…

# %% [markdown]
# ## Define response windows

# %%
baseline_window = (0.2, 1.0)
stim_window = (1.05, 10.0)
early_window = (1.5, 2.2)
late_window = (2.2, 10.0)

# %% [markdown]
# ## Analyze one trace

# %%
def analyze_trace(
    time,
    trace,
    stim_window=(1.05, 10.0),
    early_window=(1.5, 2.2),
    late_window=(2.2, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes a baseline-subtracted trace.

    Because the trace is already baseline-subtracted:
    - baseline is approximately 0
    - inward currents at -70 mV are negative
    """

    stim_mask = (time >= stim_window[0]) & (time <= stim_window[1])
    early_mask = (time >= early_window[0]) & (time <= early_window[1])
    late_mask = (time >= late_window[0]) & (time <= late_window[1])

    stim_current = trace[stim_mask]
    stim_time = time[stim_mask]

    early_current = trace[early_mask]
    late_current = trace[late_mask]

    cleaned_stim = stim_current.copy()
    cleaned_stim[np.abs(cleaned_stim) > artifact_threshold_pA] = np.nan

    peak_inward = np.nanmin(cleaned_stim)
    peak_outward = np.nanmax(cleaned_stim)

    mean_response = np.nanmean(cleaned_stim)
    early_mean_response = np.nanmean(early_current)
    late_mean_response = np.nanmean(late_current)

    charge_transfer = trapezoid(stim_current, stim_time)

    return {
        "peak_inward_pA": peak_inward,
        "peak_outward_pA": peak_outward,
        "mean_response_pA": mean_response,
        "early_mean_response_pA": early_mean_response,
        "late_mean_response_pA": late_mean_response,
        "charge_transfer_pA_s": charge_transfer
    }

# %% [markdown]
# ## Analyze individual sweeps and the averaged trace
# It will produce
# - one row for sweep 0
# - one row for sweep 1
# - one row for sweep 2
# - one row for the average trace

# %%
def analyze_condition_row(
    row,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0),
    early_window=(1.5, 2.2),
    late_window=(2.2, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes all sweeps for one stimulus condition.

    Each metadata row represents one condition/file.
    """

    file_name = row["file"]
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    output_rows = []

    # Analyze individual sweeps
    for sweep_number, trace, baseline in zip(sweeps, corrected_traces, baselines):
        result = analyze_trace(
            time=time,
            trace=trace,
            stim_window=stim_window,
            early_window=early_window,
            late_window=late_window,
            artifact_threshold_pA=artifact_threshold_pA
        )

        output = row.to_dict()
        output.update(result)

        output["analysis_level"] = "individual_sweep"
        output["sweep"] = sweep_number
        output["baseline_mean_pA"] = baseline
        output["n_sweeps_averaged"] = 1

        output_rows.append(output)

    # Analyze averaged trace
    avg_result = analyze_trace(
        time=time,
        trace=average_trace,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=artifact_threshold_pA
    )

    output = row.to_dict()
    output.update(avg_result)

    output["analysis_level"] = "average_trace"
    output["sweep"] = "avg"
    output["baseline_mean_pA"] = np.mean(baselines)
    output["n_sweeps_averaged"] = len(sweeps)

    output_rows.append(output)

    return output_rows

# %% [markdown]
# ## Analyze the whole experiment
# everything is multiplied by -1 because at -70mV, excitatory inward currents are negative. Turning them positive makes graphs easier to interpret: bigger response = higher value

# %%
all_results = []

for _, row in metadata.iterrows():
    condition_results = analyze_condition_row(
        row,
        baseline_window=baseline_window,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=500
    )

    all_results.extend(condition_results)

results = pd.DataFrame(all_results)

results["inward_mean_response_pA"] = -results["mean_response_pA"]
results["inward_peak_response_pA"] = -results["peak_inward_pA"]
results["inward_late_response_pA"] = -results["late_mean_response_pA"]
results["inward_early_response_pA"] = -results["early_mean_response_pA"]
results["inward_charge_pA_s"] = -results["charge_transfer_pA_s"]

results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_08_0000.abf  control             spot        NaN          NaN
# 1   2026_05_08_0000.abf  control             spot        NaN          NaN
# 2   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 3   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 4   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# ..                  ...      ...              ...        ...          ...
# 61  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 62  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
# 63  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
# 64  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
# 65  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
#
#    sweeps  clamp_mV                                     notes  peak_inward_pA  \
# 0       0       -70  simple spot diameter 200um contrast 4090     -268.241974
# 1       0       -70  simple spot diameter 200um contrast 4090     -268.241974
# 2   0;1;2       -70   center contrast 20 surround contrast 50     -164.769745
# 3   0;1;2       -70   center contrast 20 surround contrast 50     -157.755768
# 4   0;1;2       -70   center contrast 20 surround contrast 50     -100.425049
# ..    ...       ...                                       ...             ...
# 61  0;1;2       -70   center contrast 20 surround contrast 50     -130.607101
# 62  0;1;2       -70   center contrast 20 surround contrast 50     -194.428726
# 63  0;1;2       -70   center contrast 20 surround contrast 50     -168.598129
# 64  0;1;2       -70   center contrast 20 surround contrast 50     -162.345703
# 65  0;1;2       -70   center contrast 20 surround contrast 50     -106.357910
#
#     peak_outward_pA  ...  charge_transfer_pA_s    analysis_level  sweep  \
# 0         71.113480  ...            -96.632019  individual_sweep      0
# 1         71.113480  ...            -96.632019     average_trace    avg
# 2         52.515404  ...           -228.048752  individual_sweep      0
# 3         35.725681  ...           -225.070206  individual_sweep      1
# 4         22.865971  ...           -236.777634  individual_sweep      2
# ..              ...  ...                   ...               ...    ...
# 61        11.808266  ...           -393.080078     average_trace    avg
# 62        10.649399  ...           -359.695374  individual_sweep      0
# 63        13.286633  ...           -380.885162  individual_sweep      1
# 64        18.928715  ...           -341.213074  individual_sweep      2
# 65         5.946777  ...           -360.597870     average_trace    avg
#
#     baseline_mean_pA n_sweeps_averaged inward_mean_response_pA  \
# 0         -54.633991                 1               10.796857
# 1         -54.633991                 1               10.796857
# 2         -37.866966                 1               25.480600
# 3         -37.556736                 1               25.147682
# 4         -36.904057                 1               26.455841
# ..               ...               ...                     ...
# 61        -34.391273                 3               43.919827
# 62        -42.387680                 1               40.189491
# 63        -32.817883                 1               42.557198
# 64        -32.966801                 1               38.124561
# 65        -36.057453                 3               40.290421
#
#     inward_peak_response_pA  inward_late_response_pA  \
# 0                268.241974                 0.804809
# 1                268.241974                 0.804809
# 2                164.769745                24.867859
# 3                157.755768                24.904470
# 4                100.425049                26.382320
# ..                      ...                      ...
# 61               130.607101                42.927608
# 62               194.428726                39.240517
# 63               168.598129                41.157261
# 64               162.345703                36.958149
# 65               106.357910                39.118641
#
#     inward_early_response_pA  inward_charge_pA_s
# 0                  69.240364           96.632019
# 1                  69.240364           96.632019
# 2                  28.445843          228.048752
# 3                  22.469740          225.070206
# 4                  20.675131          236.777634
# ..                       ...                 ...
# 61                 47.789516          393.080078
# 62                 41.169907          359.695374
# 63                 45.930550          380.885162
# 64                 43.474670          341.213074
# 65                 43.525040          360.597870
#
# [66 rows x 23 columns]

# %% [markdown]
# ## Save Results

# %%
RESULTS_FILE = RESULTS_DIR / "response_summary.csv"

results.to_csv(RESULTS_FILE, index=False)

print("Saved results to:", RESULTS_FILE)
# Out:
# Saved results to: /Users/ahnekevanlankvelt/Desktop/retina_project/results/response_summary.csv

# %% [markdown]
# ## Separate individual sweeps from average traces

# %%
individual_results = results[results["analysis_level"] == "individual_sweep"].copy()
average_results = results[results["analysis_level"] == "average_trace"].copy()

individual_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_08_0000.abf  control             spot        NaN          NaN
# 2   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 3   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 4   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 6   2026_05_08_0011.abf  control  center_surround        1.0         32.0
# 7   2026_05_08_0011.abf  control  center_surround        1.0         32.0
# 8   2026_05_08_0011.abf  control  center_surround        1.0         32.0
# 10  2026_05_08_0012.abf  control  center_surround        1.0          2.0
# 11  2026_05_08_0012.abf  control  center_surround        1.0          2.0
# 12  2026_05_08_0012.abf  control  center_surround        1.0          2.0
# 14  2026_05_08_0013.abf  control      center_only        1.0        100.0
# 15  2026_05_08_0013.abf  control      center_only        1.0        100.0
# 16  2026_05_08_0013.abf  control      center_only        1.0        100.0
# 18  2026_05_08_0014.abf  control  center_surround        1.0          4.0
# 19  2026_05_08_0014.abf  control  center_surround        1.0          4.0
# 20  2026_05_08_0014.abf  control  center_surround        1.0          4.0
# 22  2026_05_08_0015.abf  control  center_surround        1.0          8.0
# 23  2026_05_08_0015.abf  control  center_surround        1.0          8.0
# 24  2026_05_08_0015.abf  control  center_surround        1.0          8.0
# 26  2026_05_08_0016.abf  control  center_surround        1.0         16.0
# 27  2026_05_08_0016.abf  control  center_surround        1.0         16.0
# 28  2026_05_08_0016.abf  control  center_surround        1.0         16.0
# 30  2026_05_08_0017.abf  control  center_surround        1.0          0.5
# 31  2026_05_08_0017.abf  control  center_surround        1.0          0.5
# 32  2026_05_08_0017.abf  control  center_surround        1.0          0.5
# 34  2026_05_08_0023.abf      TTX      center_only        1.0        100.0
# 35  2026_05_08_0023.abf      TTX      center_only        1.0        100.0
# 36  2026_05_08_0023.abf      TTX      center_only        1.0        100.0
# 38  2026_05_08_0024.abf      TTX  center_surround        1.0         16.0
# 39  2026_05_08_0024.abf      TTX  center_surround        1.0         16.0
# 40  2026_05_08_0024.abf      TTX  center_surround        1.0         16.0
# 42  2026_05_08_0025.abf      TTX  center_surround        1.0          1.0
# 43  2026_05_08_0025.abf      TTX  center_surround        1.0          1.0
# 44  2026_05_08_0025.abf      TTX  center_surround        1.0          1.0
# 46  2026_05_08_0026.abf      TTX  center_surround        1.0          4.0
# 47  2026_05_08_0026.abf      TTX  center_surround        1.0          4.0
# 48  2026_05_08_0026.abf      TTX  center_surround        1.0          4.0
# 50  2026_05_08_0028.abf      TTX  center_surround        1.0          0.5
# 51  2026_05_08_0028.abf      TTX  center_surround        1.0          0.5
# 52  2026_05_08_0028.abf      TTX  center_surround        1.0          0.5
# 54  2026_05_08_0029.abf      TTX  center_surround        1.0         32.0
# 55  2026_05_08_0029.abf      TTX  center_surround        1.0         32.0
# 56  2026_05_08_0029.abf      TTX  center_surround        1.0         32.0
# 58  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 59  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 60  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 62  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
# 63  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
# 64  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
#
#    sweeps  clamp_mV                                     notes  peak_inward_pA  \
# 0       0       -70  simple spot diameter 200um contrast 4090     -268.241974
# 2   0;1;2       -70   center contrast 20 surround contrast 50     -164.769745
# 3   0;1;2       -70   center contrast 20 surround contrast 50     -157.755768
# 4   0;1;2       -70   center contrast 20 surround contrast 50     -100.425049
# 6   0;1;2       -70   center contrast 20 surround contrast 50     -135.611313
# 7   0;1;2       -70   center contrast 20 surround contrast 50     -151.516479
# 8   0;1;2       -70   center contrast 20 surround contrast 50     -140.280945
# 10  0;1;2       -70   center contrast 20 surround contrast 50     -205.515350
# 11  0;1;2       -70   center contrast 20 surround contrast 50     -131.787125
# 12  0;1;2       -70   center contrast 20 surround contrast 50     -141.847153
# 14  0;1;2       -70                               center only     -152.619736
# 15  0;1;2       -70                               center only     -213.726013
# 16  0;1;2       -70                               center only     -143.703369
# 18  0;1;2       -70   center contrast 20 surround contrast 50     -118.148506
# 19  0;1;2       -70   center contrast 20 surround contrast 50     -119.887085
# 20  0;1;2       -70   center contrast 20 surround contrast 50     -139.430908
# 22  0;1;2       -70   center contrast 20 surround contrast 50     -161.690918
# 23  0;1;2       -70   center contrast 20 surround contrast 50     -150.515060
# 24  0;1;2       -70   center contrast 20 surround contrast 50     -131.675583
# 26  0;1;2       -70   center contrast 20 surround contrast 50     -160.399094
# 27  0;1;2       -70   center contrast 20 surround contrast 50     -202.673325
# 28  0;1;2       -70   center contrast 20 surround contrast 50     -134.551346
# 30  0;1;2       -70   center contrast 20 surround contrast 50     -133.479752
# 31  0;1;2       -70   center contrast 20 surround contrast 50     -156.840912
# 32  0;1;2       -70   center contrast 20 surround contrast 50     -161.360672
# 34  0;1;2       -70                               center only     -221.468567
# 35  0;1;2       -70                               center only     -204.708221
# 36  0;1;2       -70                               center only     -182.203949
# 38  0;1;2       -70   center contrast 20 surround contrast 50     -183.574341
# 39  0;1;2       -70   center contrast 20 surround contrast 50     -197.490967
# 40  0;1;2       -70   center contrast 20 surround contrast 50     -177.189194
# 42  0;1;2       -70   center contrast 20 surround contrast 50     -171.623383
# 43  0;1;2       -70   center contrast 20 surround contrast 50     -165.571350
# 44  0;1;2       -70   center contrast 20 surround contrast 50     -134.084000
# 46  0;1;2       -70   center contrast 20 surround contrast 50     -181.153900
# 47  0;1;2       -70   center contrast 20 surround contrast 50     -162.708359
# 48  0;1;2       -70   center contrast 20 surround contrast 50     -171.525375
# 50  0;1;2       -70   center contrast 20 surround contrast 50     -162.051865
# 51  0;1;2       -70   center contrast 20 surround contrast 50     -171.553604
# 52  0;1;2       -70   center contrast 20 surround contrast 50     -132.207565
# 54  0;1;2       -70   center contrast 20 surround contrast 50     -177.423721
# 55  0;1;2       -70   center contrast 20 surround contrast 50     -144.542725
# 56  0;1;2       -70   center contrast 20 surround contrast 50     -185.239120
# 58  0;1;2       -70   center contrast 20 surround contrast 50     -171.984711
# 59  0;1;2       -70   center contrast 20 surround contrast 50     -151.740723
# 60  0;1;2       -70   center contrast 20 surround contrast 50     -162.700348
# 62  0;1;2       -70   center contrast 20 surround contrast 50     -194.428726
# 63  0;1;2       -70   center contrast 20 surround contrast 50     -168.598129
# 64  0;1;2       -70   center contrast 20 surround contrast 50     -162.345703
#
#     peak_outward_pA  ...  charge_transfer_pA_s    analysis_level  sweep  \
# 0         71.113480  ...            -96.632019  individual_sweep      0
# 2         52.515404  ...           -228.048752  individual_sweep      0
# 3         35.725681  ...           -225.070206  individual_sweep      1
# 4         22.865971  ...           -236.777634  individual_sweep      2
# 6         15.755878  ...           -268.109039  individual_sweep      0
# 7         26.706169  ...           -278.611237  individual_sweep      1
# 8         15.358704  ...           -293.207367  individual_sweep      2
# 10         9.328407  ...           -264.223267  individual_sweep      0
# 11        14.086899  ...           -292.266296  individual_sweep      1
# 12        54.686050  ...           -303.125244  individual_sweep      2
# 14        18.278702  ...           -273.405853  individual_sweep      0
# 15        34.076721  ...           -287.824371  individual_sweep      1
# 16        19.260490  ...           -288.300568  individual_sweep      2
# 18        50.918877  ...           -251.621155  individual_sweep      0
# 19        33.921513  ...           -276.681061  individual_sweep      1
# 20        10.105217  ...           -274.602264  individual_sweep      2
# 22        18.973141  ...           -268.167755  individual_sweep      0
# 23        25.876541  ...           -283.467041  individual_sweep      1
# 24        23.353714  ...           -276.384705  individual_sweep      2
# 26        39.185867  ...           -254.170593  individual_sweep      0
# 27        20.104992  ...           -251.746460  individual_sweep      1
# 28        11.933029  ...           -282.131653  individual_sweep      2
# 30        81.363998  ...           -182.348999  individual_sweep      0
# 31        18.940346  ...           -194.913300  individual_sweep      1
# 32        30.289719  ...           -196.306183  individual_sweep      2
# 34        34.268738  ...           -258.445587  individual_sweep      0
# 35        75.443153  ...           -371.323181  individual_sweep      1
# 36        26.536280  ...           -440.146851  individual_sweep      2
# 38        16.010624  ...           -469.853333  individual_sweep      0
# 39         8.807861  ...           -462.167175  individual_sweep      1
# 40        13.240490  ...           -444.203003  individual_sweep      2
# 42        16.975246  ...           -436.096680  individual_sweep      0
# 43        18.144470  ...           -441.843719  individual_sweep      1
# 44        16.062485  ...           -437.651611  individual_sweep      2
# 46        16.600002  ...           -421.255737  individual_sweep      0
# 47        13.072889  ...           -466.285034  individual_sweep      1
# 48        12.190441  ...           -442.821014  individual_sweep      2
# 50        43.026257  ...           -309.285767  individual_sweep      0
# 51        23.148550  ...           -326.112762  individual_sweep      1
# 52        59.442825  ...           -325.513794  individual_sweep      2
# 54        17.888775  ...           -369.459320  individual_sweep      0
# 55        12.317623  ...           -368.122345  individual_sweep      1
# 56        16.176891  ...           -343.790771  individual_sweep      2
# 58        11.731106  ...           -394.035797  individual_sweep      0
# 59         9.392092  ...           -407.728729  individual_sweep      1
# 60        36.274254  ...           -377.475830  individual_sweep      2
# 62        10.649399  ...           -359.695374  individual_sweep      0
# 63        13.286633  ...           -380.885162  individual_sweep      1
# 64        18.928715  ...           -341.213074  individual_sweep      2
#
#     baseline_mean_pA n_sweeps_averaged inward_mean_response_pA  \
# 0         -54.633991                 1               10.796857
# 2         -37.866966                 1               25.480600
# 3         -37.556736                 1               25.147682
# 4         -36.904057                 1               26.455841
# 6         -44.442402                 1               29.956509
# 7         -40.744255                 1               31.130041
# 8         -39.772766                 1               32.760712
# 10        -43.508095                 1               29.522486
# 11        -40.332016                 1               32.655575
# 12        -40.037613                 1               33.869144
# 14        -44.523819                 1               30.548199
# 15        -38.349182                 1               32.159500
# 16        -37.571037                 1               32.212639
# 18        -42.373955                 1               28.114401
# 19        -40.025028                 1               30.914106
# 20        -38.181389                 1               30.682171
# 22        -42.166500                 1               29.963055
# 23        -39.914627                 1               31.672485
# 24        -38.612503                 1               30.881155
# 26        -42.237625                 1               28.399197
# 27        -40.246593                 1               28.128296
# 28        -38.178146                 1               31.523369
# 30        -43.522205                 1               20.374239
# 31        -40.913002                 1               21.778118
# 32        -38.224289                 1               21.933750
# 34        -40.982605                 1               28.876820
# 35        -22.952917                 1               41.489075
# 36        -23.484522                 1               49.178989
# 38        -44.086796                 1               52.497967
# 39        -33.832275                 1               51.638988
# 40        -32.161388                 1               49.632153
# 42        -39.558254                 1               48.726166
# 43        -32.182556                 1               49.368423
# 44        -32.541977                 1               48.899960
# 46        -41.014065                 1               47.067928
# 47        -27.721327                 1               52.099312
# 48        -27.449230                 1               49.477592
# 50        -35.091686                 1               34.557014
# 51        -26.200308                 1               36.437256
# 52        -25.873491                 1               36.370319
# 54        -39.861431                 1               41.280445
# 55        -33.069576                 1               41.131424
# 56        -35.097790                 1               38.412495
# 58        -41.027981                 1               44.026691
# 59        -30.754396                 1               45.556499
# 60        -31.391443                 1               42.176292
# 62        -42.387680                 1               40.189491
# 63        -32.817883                 1               42.557198
# 64        -32.966801                 1               38.124561
#
#     inward_peak_response_pA  inward_late_response_pA  \
# 0                268.241974                 0.804809
# 2                164.769745                24.867859
# 3                157.755768                24.904470
# 4                100.425049                26.382320
# 6                135.611313                30.532520
# 7                151.516479                31.841017
# 8                140.280945                33.746643
# 10               205.515350                29.322519
# 11               131.787125                32.620895
# 12               141.847153                34.245819
# 14               152.619736                30.793705
# 15               213.726013                32.628288
# 16               143.703369                32.724792
# 18               118.148506                27.739904
# 19               119.887085                30.832836
# 20               139.430908                30.722311
# 22               161.690918                30.165695
# 23               150.515060                32.083447
# 24               131.675583                31.547377
# 26               160.399094                28.756828
# 27               202.673325                28.357687
# 28               134.551346                32.151642
# 30               133.479752                19.392521
# 31               156.840912                20.843878
# 32               161.360672                21.258871
# 34               221.468567                29.549250
# 35               204.708221                42.023975
# 36               182.203949                48.480999
# 38               183.574341                51.456581
# 39               197.490967                50.906395
# 40               177.189194                48.544895
# 42               171.623383                47.624935
# 43               165.571350                48.546219
# 44               134.084000                47.835327
# 46               181.153900                46.228458
# 47               162.708359                51.698719
# 48               171.525375                48.648193
# 50               162.051865                33.356270
# 51               171.553604                35.777565
# 52               132.207565                35.530304
# 54               177.423721                40.385143
# 55               144.542725                39.416222
# 56               185.239120                36.686890
# 58               171.984711                42.890018
# 59               151.740723                44.500584
# 60               162.700348                41.392242
# 62               194.428726                39.240517
# 63               168.598129                41.157261
# 64               162.345703                36.958149
#
#     inward_early_response_pA  inward_charge_pA_s
# 0                  69.240364           96.632019
# 2                  28.445843          228.048752
# 3                  22.469740          225.070206
# 4                  20.675131          236.777634
# 6                  23.580748          268.109039
# 7                  25.407959          278.611237
# 8                  25.996592          293.207367
# 10                 28.787300          264.223267
# 11                 32.037895          292.266296
# 12                 29.379692          303.125244
# 14                 27.166451          273.405853
# 15                 28.059727          287.824371
# 16                 28.567230          288.300568
# 18                 28.329855          251.621155
# 19                 30.391369          276.681061
# 20                 30.471066          274.602264
# 22                 26.372208          268.167755
# 23                 26.357656          283.467041
# 24                 25.443251          276.384705
# 26                 23.710197          254.170593
# 27                 23.904602          251.746460
# 28                 26.447865          282.131653
# 30                 23.702105          182.348999
# 31                 28.344578          194.913300
# 32                 25.098648          196.306183
# 34                 20.452188          258.445587
# 35                 34.346912          371.323181
# 36                 50.702072          440.146851
# 38                 59.915936          469.853333
# 39                 52.724552          462.167175
# 40                 50.927494          444.203003
# 42                 50.131180          436.096680
# 43                 43.777122          441.843719
# 44                 49.209171          437.651611
# 46                 48.682556          421.255737
# 47                 45.923988          466.285034
# 48                 50.835281          442.821014
# 50                 37.251427          309.285767
# 51                 29.783157          326.112762
# 52                 33.444145          325.513794
# 54                 42.005215          369.459320
# 55                 46.648090          368.122345
# 56                 46.752731          343.790771
# 58                 45.097397          394.035797
# 59                 50.333458          407.728729
# 60                 47.937702          377.475830
# 62                 41.169907          359.695374
# 63                 45.930550          380.885162
# 64                 43.474670          341.213074
#
# [49 rows x 23 columns]

# %% [markdown]
# ### For final tuning curves use: average results
# ### For checking variability use: individual_results

# %% [markdown]
# ## Plot center-only spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_only"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="center_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Center spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center-only spatial frequency tuning")
plt.show()

# %% [markdown]
# ## Plot center+surround spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_surround"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="surround_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Surround spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center+surround response vs surround spatial frequency")
plt.show()

# %% [markdown]
# ## Plot control vs TTX at one condition

# %%
df = average_results[
    (average_results["stimulus_type"] == "center_surround") &
    (average_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.barplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar=None
)

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center_Surround SF 1: control vs TTX")
plt.show()

# %% [markdown]
# ## Show individual sweep variability

# %%
df = individual_results[
    (individual_results["stimulus_type"] == "center_surround") &
    (individual_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8,
    jitter=True
)

sns.pointplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar="se",
    color="red",
    markers="D"
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Individual sweeps: center_surround SF 1")
plt.show()

# %% [markdown]
# ## Overlay control and TTX average traces

# %%
def get_average_trace_for_row(row, baseline_window=(0.2, 1.0)):
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        row["file"],
        sweeps,
        baseline_window=baseline_window
    )

    return time, average_trace


def overlay_average_traces(
    metadata,
    stimulus_type,
    center_sf=None,
    surround_sf=None,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0)
):
    df = metadata[metadata["stimulus_type"] == stimulus_type].copy()

    if center_sf is not None:
        df = df[df["center_sf"] == center_sf]

    if surround_sf is not None:
        df = df[df["surround_sf"] == surround_sf]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['drug']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(f"{stimulus_type}, center SF={center_sf}, surround SF={surround_sf}")
    plt.legend()
    plt.show()

# %%
overlay_average_traces(
    metadata,
    stimulus_type="center_only",
    center_sf=1,
    surround_sf=100,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %% [markdown]
# ## Calculate surround modulation index

# %% [markdown]
# SMI = (Rc+s - Rc) / (Rc+s + Rc)

# %%
def calculate_smi(average_results, response_column="inward_mean_response_pA"):
    """
    Calculates surround modulation index for center+surround rows.

    This assumes matching center_only rows exist for the same:
    - drug
    - center_sf
    """

    center_only = average_results[
        average_results["stimulus_type"] == "center_only"
    ].copy()

    center_surround = average_results[
        average_results["stimulus_type"] == "center_surround"
    ].copy()

    smi_rows = []

    for _, cs_row in center_surround.iterrows():
        matching_center = center_only[
            (center_only["drug"] == cs_row["drug"]) &
            (center_only["center_sf"] == cs_row["center_sf"])
        ]

        if len(matching_center) == 0:
            continue

        r_center = matching_center.iloc[0][response_column]
        r_cs = cs_row[response_column]

        smi = (r_cs - r_center) / (r_cs + r_center)

        output = cs_row.to_dict()
        output["R_center"] = r_center
        output["R_center_surround"] = r_cs
        output["SMI"] = smi

        smi_rows.append(output)

    return pd.DataFrame(smi_rows)

# %%
smi_results = calculate_smi(
    average_results,
    response_column="inward_mean_response_pA"
)

smi_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_08_0010.abf  control  center_surround        1.0          1.0
# 1   2026_05_08_0011.abf  control  center_surround        1.0         32.0
# 2   2026_05_08_0012.abf  control  center_surround        1.0          2.0
# 3   2026_05_08_0014.abf  control  center_surround        1.0          4.0
# 4   2026_05_08_0015.abf  control  center_surround        1.0          8.0
# 5   2026_05_08_0016.abf  control  center_surround        1.0         16.0
# 6   2026_05_08_0017.abf  control  center_surround        1.0          0.5
# 7   2026_05_08_0024.abf      TTX  center_surround        1.0         16.0
# 8   2026_05_08_0025.abf      TTX  center_surround        1.0          1.0
# 9   2026_05_08_0026.abf      TTX  center_surround        1.0          4.0
# 10  2026_05_08_0028.abf      TTX  center_surround        1.0          0.5
# 11  2026_05_08_0029.abf      TTX  center_surround        1.0         32.0
# 12  2026_05_08_0030.abf      TTX  center_surround        1.0          2.0
# 13  2026_05_08_0031.abf      TTX  center_surround        1.0          8.0
#
#    sweeps  clamp_mV                                    notes  peak_inward_pA  \
# 0   0;1;2       -70  center contrast 20 surround contrast 50      -85.848427
# 1   0;1;2       -70  center contrast 20 surround contrast 50      -86.317238
# 2   0;1;2       -70  center contrast 20 surround contrast 50     -100.919342
# 3   0;1;2       -70  center contrast 20 surround contrast 50      -70.890526
# 4   0;1;2       -70  center contrast 20 surround contrast 50      -78.583893
# 5   0;1;2       -70  center contrast 20 surround contrast 50      -95.480713
# 6   0;1;2       -70  center contrast 20 surround contrast 50      -71.621635
# 7   0;1;2       -70  center contrast 20 surround contrast 50     -155.363815
# 8   0;1;2       -70  center contrast 20 surround contrast 50     -148.547989
# 9   0;1;2       -70  center contrast 20 surround contrast 50     -144.126602
# 10  0;1;2       -70  center contrast 20 surround contrast 50     -114.987816
# 11  0;1;2       -70  center contrast 20 surround contrast 50     -125.530113
# 12  0;1;2       -70  center contrast 20 surround contrast 50     -130.607101
# 13  0;1;2       -70  center contrast 20 surround contrast 50     -106.357910
#
#     peak_outward_pA  ...  baseline_mean_pA  n_sweeps_averaged  \
# 0         10.587117  ...        -37.442585                  3
# 1          7.066553  ...        -41.653141                  3
# 2          4.264580  ...        -41.292576                  3
# 3         10.896583  ...        -40.193459                  3
# 4          6.865324  ...        -40.231213                  3
# 5          6.448002  ...        -40.220791                  3
# 6         26.848412  ...        -40.886501                  3
# 7          9.024216  ...        -36.693485                  3
# 8          5.870955  ...        -34.760929                  3
# 9          6.223324  ...        -32.061539                  3
# 10        11.761868  ...        -29.055161                  3
# 11         5.288570  ...        -36.009598                  3
# 12        11.808266  ...        -34.391273                  3
# 13         5.946777  ...        -36.057453                  3
#
#     inward_mean_response_pA  inward_peak_response_pA inward_late_response_pA  \
# 0                 25.694706                85.848427               25.384884
# 1                 31.282419                86.317238               32.040062
# 2                 32.015732               100.919342               32.063076
# 3                 29.903561                70.890526               29.765020
# 4                 30.838896                78.583893               31.265501
# 5                 29.350286                95.480713               29.755384
# 6                 21.362036                71.621635               20.498421
# 7                 51.256367               155.363815               50.302620
# 8                 48.998184               148.547989               48.002163
# 9                 49.548275               144.126602               48.858452
# 10                35.788197               114.987816               34.888046
# 11                40.274788               125.530113               38.829422
# 12                43.919827               130.607101               42.927608
# 13                40.290421               106.357910               39.118641
#
#    inward_early_response_pA  inward_charge_pA_s   R_center  R_center_surround  \
# 0                 23.863569          229.965530  31.640112          25.694706
# 1                 24.995100          279.975891  31.640112          31.282419
# 2                 30.068296          286.538269  31.640112          32.015732
# 3                 29.730766          267.634827  31.640112          29.903561
# 4                 26.057703          276.006500  31.640112          30.838896
# 5                 24.687553          262.682922  31.640112          29.350286
# 6                 25.715111          191.189484  31.640112          21.362036
# 7                 54.522659          458.741150  39.848297          51.256367
# 8                 47.705826          438.530731  39.848297          48.998184
# 9                 48.480598          443.453949  39.848297          49.548275
# 10                33.492908          320.304077  39.848297          35.788197
# 11                45.135342          360.457489  39.848297          40.274788
# 12                47.789516          393.080078  39.848297          43.919827
# 13                43.525040          360.597870  39.848297          40.290421
#
#          SMI
# 0  -0.103696
# 1  -0.005685
# 2   0.005901
# 3  -0.028217
# 4  -0.012824
# 5  -0.037544
# 6  -0.193918
# 7   0.125219
# 8   0.102985
# 9   0.108505
# 10 -0.053679
# 11  0.005323
# 12  0.048605
# 13  0.005517
#
# [14 rows x 26 columns]

# %%
plt.figure(figsize=(8, 5))

sns.lineplot(
    data=smi_results,
    x="surround_sf",
    y="SMI",
    hue="drug",
    marker="o"
)

plt.axhline(0, color="black", lw=1)
plt.xlabel("Surround spatial frequency")
plt.ylabel("Surround modulation index")
plt.title("Surround modulation vs spatial frequency")
plt.show()

# %% [markdown]
# ## SAVE FIGURES

# %% [markdown]
# any plot can be saved by adding this code before plt.show()

# %%
#plt.savefig(FIG_DIR / "my_figure_name.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Things to double check
#
# 1. Are the stimulus windows correct?
# 2. Are the baseline windows quiet?
# 3. Do the three sweeps look similar?
# 4. Are inward currents plotted as positive?
# 5. Are control and TTX labels entered consistently?
# 6. Are spatial frequencies numeric?

# %%
##Checking the averaged trace
row = average_results.iloc[1]
row
# Out:
# file                                            2026_05_08_0010.abf
# drug                                                        control
# stimulus_type                                       center_surround
# center_sf                                                       1.0
# surround_sf                                                     1.0
# sweeps                                                        0;1;2
# clamp_mV                                                        -70
# notes                       center contrast 20 surround contrast 50
# peak_inward_pA                                           -85.848427
# peak_outward_pA                                           10.587117
# mean_response_pA                                         -25.694706
# early_mean_response_pA                                   -23.863569
# late_mean_response_pA                                    -25.384884
# charge_transfer_pA_s                                     -229.96553
# analysis_level                                        average_trace
# sweep                                                           avg
# baseline_mean_pA                                         -37.442585
# n_sweeps_averaged                                                 3
# inward_mean_response_pA                                   25.694706
# inward_peak_response_pA                                   85.848427
# inward_late_response_pA                                   25.384884
# inward_early_response_pA                                  23.863569
# inward_charge_pA_s                                        229.96553
# Name: 5, dtype: object
