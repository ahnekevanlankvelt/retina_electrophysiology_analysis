# %% [markdown]
# ## Import Packages

# %%
from pathlib import Path

import pyabf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.integrate import trapezoid

import ipywidgets as widgets
from IPython.display import display

sns.set_context("talk")
sns.set_style("whitegrid")

# %% [markdown]
# ## Set folder paths

# %%
PROJECT = Path("/Volumes/My Passport for Mac/retina_project")

DATA_DIR = PROJECT / "data"
META_DIR = PROJECT / "metadata"
NOTEBOOK_DIR = PROJECT / "notebooks"
RESULTS_DIR = PROJECT / "results"
FIG_DIR = RESULTS_DIR / "figures"

META_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)
FIG_DIR.mkdir(exist_ok=True)

print("Project folder:", PROJECT)
print("Data folder:", DATA_DIR)
print("Metadata folder:", META_DIR)
print("Results folder:", RESULTS_DIR)
# Out:
# Project folder: /Volumes/My Passport for Mac/retina_project
# Data folder: /Volumes/My Passport for Mac/retina_project/data
# Metadata folder: /Volumes/My Passport for Mac/retina_project/metadata
# Results folder: /Volumes/My Passport for Mac/retina_project/results

# %% [markdown]
# ## Create metadata table

# %%
META_FILE = META_DIR / "experiment_cell4_metadata.csv"

metadata = pd.DataFrame([
    {
        "file": "2026_05_12_0001.abf",
        "drug": "control",
        "stimulus_type": "spot",
        "center_sf": np.nan,
        "surround_sf": np.nan,
        "sweeps": "0",
        "clamp_mV": -70,
        "notes": "ID5, ON sustained"
    },
    # {
    #     "file": "2026_05_12_0002.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "ID6,center contrast 25 surround 50"
    # },
    # {
    #     "file": "2026_05_12_0003.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "ID7,center contrast 30 surround contrast 50"
    # },
    # {
    #     "file": "2026_05_12_0004.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 1,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "ID8, center contrast 30 surround contrast 50"
    # },
    # {
    #     "file": "2026_05_12_0005.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 16,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "ID9, center contrast 30 surround contrast 50"
    # },
    # {
    #     "file": "2026_05_12_0006.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "ID10, center contrast 30 surround contrast 50"
    # },
    {
        "file": "2026_05_12_0007.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "ID11, center contrast 40 surround contrast 50"
    },
    {
        "file": "2026_05_12_0008.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "ID12, center contrast 40 surround contrast 50"
    },
    {
        "file": "2026_05_12_0009.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 40 surround contrast 50"
    },
    {
        "file": "2026_05_12_0010.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 8,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 40 surround contrast 50"
    },
    {
        "file": "2026_05_12_0011.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 40 surround contrast 50"
    }
    
])

metadata.to_csv(META_FILE, index=False)
metadata
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_12_0001.abf  control             spot        NaN          NaN
# 1  2026_05_12_0007.abf  control      center_only        1.0        100.0
# 2  2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 3  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 4  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 5  2026_05_12_0011.abf  control  center_surround        1.0          2.0
#
#   sweeps  clamp_mV                                          notes
# 0      0       -70                              ID5, ON sustained
# 1  0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 2  0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 3  0;1;2       -70        center contrast 40 surround contrast 50
# 4  0;1;2       -70        center contrast 40 surround contrast 50
# 5  0;1;2       -70        center contrast 40 surround contrast 50

# %% [markdown]
# ## Load Metadata

# %%
META_FILE = META_DIR / "experiment_cell4_metadata.csv"

metadata = pd.read_csv(META_FILE)

metadata
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_12_0001.abf  control             spot        NaN          NaN
# 1  2026_05_12_0007.abf  control      center_only        1.0        100.0
# 2  2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 3  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 4  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 5  2026_05_12_0011.abf  control  center_surround        1.0          2.0
#
#   sweeps  clamp_mV                                          notes
# 0      0       -70                              ID5, ON sustained
# 1  0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 2  0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 3  0;1;2       -70        center contrast 40 surround contrast 50
# 4  0;1;2       -70        center contrast 40 surround contrast 50
# 5  0;1;2       -70        center contrast 40 surround contrast 50

# %% [markdown]
# ## Define helper functions to load ABF files

# %%
def parse_sweeps(sweep_string):
    """
    Converts a sweep string like '0;1;2' into a list: [0, 1, 2].
    """
    return [int(s.strip()) for s in str(sweep_string).split(";")]


def load_sweeps(file_name, sweeps):
    """
    Loads multiple sweeps from one ABF file.

    Parameters
    ----------
    file_name : str
        Name of the ABF file.
    sweeps : list
        List of sweep numbers, for example [0, 1, 2].

    Returns
    -------
    time : array
        Time values in seconds.
    traces : array
        Shape is number of sweeps x number of timepoints.
    """

    file_path = DATA_DIR / file_name

    if not file_path.exists():
        raise FileNotFoundError(f"Could not find file: {file_path}")

    abf = pyabf.ABF(str(file_path))

    traces = []
    time = None

    for sweep in sweeps:
        abf.setSweep(int(sweep))

        if time is None:
            time = abf.sweepX

        traces.append(abf.sweepY)

    traces = np.array(traces)

    return time, traces

# %% [markdown]
# ## load and plot one file's three sweeps

# %%
test_file = metadata.loc[1, "file"]
test_sweeps = parse_sweeps(metadata.loc[1, "sweeps"])

time, traces = load_sweeps(test_file, test_sweeps)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, traces):
    plt.plot(time, trace, alpha=0.7, label=f"Sweep {sweep_number}")

plt.xlabel("Time (s)")
plt.ylabel("Current (pA)")
plt.title(test_file)
plt.legend()
plt.show()

# %% [markdown]
# ## Baseline-subtract each sweep

# %%
def baseline_subtract_traces(time, traces, baseline_window=(0.2, 1.0)):
    """
    Baseline-subtracts each sweep independently.

    Parameters
    ----------
    time : array
        Time values.
    traces : array
        Shape is number of sweeps x number of timepoints.
    baseline_window : tuple
        Start and end of baseline window in seconds.

    Returns
    -------
    corrected_traces : array
        Baseline-subtracted traces.
    baselines : array
        Baseline mean for each sweep.
    """

    baseline_mask = (time >= baseline_window[0]) & (time <= baseline_window[1])

    corrected_traces = []
    baselines = []

    for trace in traces:
        baseline = np.mean(trace[baseline_mask])
        baselines.append(baseline)
        corrected_traces.append(trace - baseline)

    corrected_traces = np.array(corrected_traces)
    baselines = np.array(baselines)

    return corrected_traces, baselines

# %%
baseline_window = (0.2, 1.0)

corrected_traces, baselines = baseline_subtract_traces(
    time,
    traces,
    baseline_window=baseline_window
)

print("Baseline values for each sweep:", baselines)
# Out:
# Baseline values for each sweep: [-29.093  -29.7964 -28.8619]

# %% [markdown]
# ## Average the baseline-subtracted sweeps

# %%
def average_baseline_corrected_sweeps(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0)
):
    """
    Loads sweeps, baseline-subtracts each sweep, then averages them.
    """

    time, traces = load_sweeps(file_name, sweeps)

    corrected_traces, baselines = baseline_subtract_traces(
        time,
        traces,
        baseline_window=baseline_window
    )

    average_trace = np.mean(corrected_traces, axis=0)

    return time, corrected_traces, average_trace, baselines

# %%
time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
    test_file,
    test_sweeps,
    baseline_window=(0.2, 1.0)
)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, corrected_traces):
    plt.plot(time, trace, alpha=0.35, label=f"Sweep {sweep_number}")

plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

plt.axhline(0, color="black", lw=1)
plt.xlabel("Time (s)")
plt.ylabel("Baseline-subtracted current (pA)")
plt.title(f"{test_file}: baseline-subtracted sweeps and average")
plt.legend()
plt.show()

# %% [markdown]
# ## Make a reusable plotting function

# %%
def plot_condition_average(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    title=None
):
    """
    Plots individual baseline-subtracted sweeps and their average.
    """

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    plt.figure(figsize=(12, 5))

    for sweep_number, trace in zip(sweeps, corrected_traces):
        plt.plot(time, trace, alpha=0.35, lw=1, label=f"Sweep {sweep_number}")

    plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

    plt.axvspan(
        baseline_window[0],
        baseline_window[1],
        color="gray",
        alpha=0.15,
        label="baseline"
    )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    if title is None:
        title = f"{file_name}, sweeps {sweeps}"

    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_condition_average(
    file_name=test_file,
    sweeps=test_sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0)
)

# %% [markdown]
# ## Add interactive viewer

# %%
file_dropdown = widgets.Dropdown(
    options=metadata["file"].tolist(),
    description="File:",
    layout=widgets.Layout(width="400px")
)

baseline_start_widget = widgets.FloatText(value=0.2, description="Base start")
baseline_end_widget = widgets.FloatText(value=1.0, description="Base end")

stim_start_widget = widgets.FloatText(value=1.2, description="Stim start")
stim_end_widget = widgets.FloatText(value=10.0, description="Stim end")


def interactive_average_plot(file_name, b0, b1, s0, s1):
    row = metadata[metadata["file"] == file_name].iloc[0]
    sweeps = parse_sweeps(row["sweeps"])

    title = (
        f"{file_name} | {row['drug']} | {row['stimulus_type']} | "
        f"center SF={row['center_sf']} | surround SF={row['surround_sf']}"
    )

    plot_condition_average(
        file_name=file_name,
        sweeps=sweeps,
        baseline_window=(b0, b1),
        stim_window=(s0, s1),
        title=title
    )


widgets.interact(
    interactive_average_plot,
    file_name=file_dropdown,
    b0=baseline_start_widget,
    b1=baseline_end_widget,
    s0=stim_start_widget,
    s1=stim_end_widget
);
# Out:
# interactive(children=(Dropdown(description='File:', layout=Layout(width='400px'), options=('2026_05_12_0001.ab…

# %% [markdown]
# ## Define response windows

# %%
baseline_window = (0.2, 1.0)
stim_window = (2, 10.0)
early_window = (2, 3)
late_window = (3, 10.0)

# %% [markdown]
# ## Analyze one trace

# %%
def analyze_trace(
    time,
    trace,
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes a baseline-subtracted trace.

    Because the trace is already baseline-subtracted:
    - baseline is approximately 0
    - inward currents at -70 mV are negative
    """

    stim_mask = (time >= stim_window[0]) & (time <= stim_window[1])
    early_mask = (time >= early_window[0]) & (time <= early_window[1])
    late_mask = (time >= late_window[0]) & (time <= late_window[1])

    stim_current = trace[stim_mask]
    stim_time = time[stim_mask]

    early_current = trace[early_mask]
    late_current = trace[late_mask]

    cleaned_stim = stim_current.copy()
    cleaned_stim[np.abs(cleaned_stim) > artifact_threshold_pA] = np.nan

    peak_inward = np.nanmin(cleaned_stim)
    peak_outward = np.nanmax(cleaned_stim)

    mean_response = np.nanmean(cleaned_stim)
    early_mean_response = np.nanmean(early_current)
    late_mean_response = np.nanmean(late_current)

    charge_transfer = trapezoid(stim_current, stim_time)

    return {
        "peak_inward_pA": peak_inward,
        "peak_outward_pA": peak_outward,
        "mean_response_pA": mean_response,
        "early_mean_response_pA": early_mean_response,
        "late_mean_response_pA": late_mean_response,
        "charge_transfer_pA_s": charge_transfer
    }

# %% [markdown]
# ## Analyze individual sweeps and the averaged trace
# It will produce
# - one row for sweep 0
# - one row for sweep 1
# - one row for sweep 2
# - one row for the average trace

# %%
def analyze_condition_row(
    row,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes all sweeps for one stimulus condition.

    Each metadata row represents one condition/file.
    """

    file_name = row["file"]
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    output_rows = []

    # Analyze individual sweeps
    for sweep_number, trace, baseline in zip(sweeps, corrected_traces, baselines):
        result = analyze_trace(
            time=time,
            trace=trace,
            stim_window=stim_window,
            early_window=early_window,
            late_window=late_window,
            artifact_threshold_pA=artifact_threshold_pA
        )

        output = row.to_dict()
        output.update(result)

        output["analysis_level"] = "individual_sweep"
        output["sweep"] = sweep_number
        output["baseline_mean_pA"] = baseline
        output["n_sweeps_averaged"] = 1

        output_rows.append(output)

    # Analyze averaged trace
    avg_result = analyze_trace(
        time=time,
        trace=average_trace,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=artifact_threshold_pA
    )

    output = row.to_dict()
    output.update(avg_result)

    output["analysis_level"] = "average_trace"
    output["sweep"] = "avg"
    output["baseline_mean_pA"] = np.mean(baselines)
    output["n_sweeps_averaged"] = len(sweeps)

    output_rows.append(output)

    return output_rows

# %% [markdown]
# ## Analyze the whole experiment
# everything is multiplied by -1 because at -70mV, excitatory inward currents are negative. Turning them positive makes graphs easier to interpret: bigger response = higher value

# %%
all_results = []

for _, row in metadata.iterrows():
    condition_results = analyze_condition_row(
        row,
        baseline_window=baseline_window,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=500
    )

    all_results.extend(condition_results)

results = pd.DataFrame(all_results)

results["inward_mean_response_pA"] = -results["mean_response_pA"]
results["inward_peak_response_pA"] = -results["peak_inward_pA"]
results["inward_late_response_pA"] = -results["late_mean_response_pA"]
results["inward_early_response_pA"] = -results["early_mean_response_pA"]
results["inward_charge_pA_s"] = -results["charge_transfer_pA_s"]

results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_12_0001.abf  control             spot        NaN          NaN
# 1   2026_05_12_0001.abf  control             spot        NaN          NaN
# 2   2026_05_12_0007.abf  control      center_only        1.0        100.0
# 3   2026_05_12_0007.abf  control      center_only        1.0        100.0
# 4   2026_05_12_0007.abf  control      center_only        1.0        100.0
# 5   2026_05_12_0007.abf  control      center_only        1.0        100.0
# 6   2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 7   2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 8   2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 9   2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 10  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 11  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 12  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 13  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 14  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 15  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 16  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 17  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 18  2026_05_12_0011.abf  control  center_surround        1.0          2.0
# 19  2026_05_12_0011.abf  control  center_surround        1.0          2.0
# 20  2026_05_12_0011.abf  control  center_surround        1.0          2.0
# 21  2026_05_12_0011.abf  control  center_surround        1.0          2.0
#
#    sweeps  clamp_mV                                          notes  \
# 0       0       -70                              ID5, ON sustained
# 1       0       -70                              ID5, ON sustained
# 2   0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 3   0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 4   0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 5   0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 6   0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 7   0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 8   0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 9   0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 10  0;1;2       -70        center contrast 40 surround contrast 50
# 11  0;1;2       -70        center contrast 40 surround contrast 50
# 12  0;1;2       -70        center contrast 40 surround contrast 50
# 13  0;1;2       -70        center contrast 40 surround contrast 50
# 14  0;1;2       -70        center contrast 40 surround contrast 50
# 15  0;1;2       -70        center contrast 40 surround contrast 50
# 16  0;1;2       -70        center contrast 40 surround contrast 50
# 17  0;1;2       -70        center contrast 40 surround contrast 50
# 18  0;1;2       -70        center contrast 40 surround contrast 50
# 19  0;1;2       -70        center contrast 40 surround contrast 50
# 20  0;1;2       -70        center contrast 40 surround contrast 50
# 21  0;1;2       -70        center contrast 40 surround contrast 50
#
#     peak_inward_pA  peak_outward_pA  ...  charge_transfer_pA_s  \
# 0      -158.755463        32.894920  ...            -10.969418
# 1      -158.755463        32.894920  ...            -10.969418
# 2      -131.429413        21.768824  ...           -223.688660
# 3      -136.219177        23.082579  ...           -161.991257
# 4      -102.363647        22.758427  ...           -160.234192
# 5       -89.971527        10.939930  ...           -181.971359
# 6       -85.253967        70.996033  ...            -73.937500
# 7      -111.476585        82.615211  ...            -70.469284
# 8       -53.082851        77.532379  ...            -62.470284
# 9       -47.463848        26.592148  ...            -68.959015
# 10     -160.520355        15.871239  ...           -151.463409
# 11     -122.059631        48.228451  ...           -160.266479
# 12     -153.019775        19.709724  ...           -188.310715
# 13      -75.619843        13.491485  ...           -166.680191
# 14     -104.325500        64.741882  ...           -100.845703
# 15      -68.290932        67.207115  ...           -161.527802
# 16      -79.812477        26.388695  ...            -88.854004
# 17      -57.287495        19.209894  ...           -117.075844
# 18      -89.186073        30.442833  ...             -6.146725
# 19      -91.916351        28.933254  ...             12.890918
# 20      -80.192688        19.904972  ...           -124.520470
# 21      -42.746155        15.033791  ...            -39.258759
#
#       analysis_level  sweep  baseline_mean_pA n_sweeps_averaged  \
# 0   individual_sweep      0        -35.946678                 1
# 1      average_trace    avg        -35.946678                 1
# 2   individual_sweep      0        -29.093042                 1
# 3   individual_sweep      1        -29.796446                 1
# 4   individual_sweep      2        -28.861942                 1
# 5      average_trace    avg        -29.250479                 3
# 6   individual_sweep      0        -33.764584                 1
# 7   individual_sweep      1        -34.397438                 1
# 8   individual_sweep      2        -37.859531                 1
# 9      average_trace    avg        -35.340515                 3
# 10  individual_sweep      0        -41.506004                 1
# 11  individual_sweep      1        -46.397396                 1
# 12  individual_sweep      2        -49.616951                 1
# 13     average_trace    avg        -45.840118                 3
# 14  individual_sweep      0        -69.624695                 1
# 15  individual_sweep      1        -65.376060                 1
# 16  individual_sweep      2        -82.541039                 1
# 17     average_trace    avg        -72.513939                 3
# 18  individual_sweep      0        -43.870567                 1
# 19  individual_sweep      1        -42.971340                 1
# 20  individual_sweep      2        -36.994816                 1
# 21     average_trace    avg        -41.278904                 3
#
#    inward_mean_response_pA  inward_peak_response_pA  inward_late_response_pA  \
# 0                 1.372448               158.755463                 1.010218
# 1                 1.372448               158.755463                 1.010218
# 2                27.961157               131.429413                27.365767
# 3                20.248911               136.219177                20.001898
# 4                20.029144               102.363647                19.936014
# 5                22.746403                89.971527                22.434559
# 6                 9.242141                85.253967                 8.926869
# 7                 8.808455               111.476585                 8.976892
# 8                 7.808786                53.082851                 7.940640
# 9                 8.619793                47.463848                 8.614800
# 10               18.933123               160.520355                18.817699
# 11               20.033459               122.059631                20.375999
# 12               23.538855               153.019775                23.133991
# 13               20.835144                75.619843                20.775898
# 14               12.605758               104.325500                12.515460
# 15               20.191069                68.290932                21.125879
# 16               11.106668                79.812477                10.881114
# 17               14.634500                57.287495                14.840819
# 18                0.768142                89.186073                 0.460138
# 19               -1.611688                91.916351                -2.518003
# 20               15.564886                80.192688                15.011214
# 21                4.907113                42.746155                 4.317784
#
#     inward_early_response_pA  inward_charge_pA_s
# 0                   3.906793           10.969418
# 1                   3.906793           10.969418
# 2                  32.121063          223.688660
# 3                  21.968870          161.991257
# 4                  20.674778          160.234192
# 5                  24.921566          181.971359
# 6                  11.446891           73.937500
# 7                   7.627427           70.469284
# 8                   6.883312           62.470284
# 9                   8.652543           68.959015
# 10                 19.735550          151.463409
# 11                 17.632311          160.266479
# 12                 26.366556          188.310715
# 13                 21.244806          166.680191
# 14                 13.233925          100.845703
# 15                 13.644862          161.527802
# 16                 12.682193           88.854004
# 17                 13.186996          117.075844
# 18                  2.921781            6.146725
# 19                  4.729898          -12.890918
# 20                 19.438219          124.520470
# 21                  9.029967           39.258759
#
# [22 rows x 23 columns]

# %% [markdown]
# ## Save Results

# %%
RESULTS_FILE = RESULTS_DIR / "response_summary_cell4.csv"

results.to_csv(RESULTS_FILE, index=False)

print("Saved results to:", RESULTS_FILE)
# Out:
# Saved results to: /Volumes/My Passport for Mac/retina_project/results/response_summary_cell4.csv

# %% [markdown]
# ## Separate individual sweeps from average traces

# %%
individual_results = results[results["analysis_level"] == "individual_sweep"].copy()
average_results = results[results["analysis_level"] == "average_trace"].copy()

average_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 1   2026_05_12_0001.abf  control             spot        NaN          NaN
# 5   2026_05_12_0007.abf  control      center_only        1.0        100.0
# 9   2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 13  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 17  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 21  2026_05_12_0011.abf  control  center_surround        1.0          2.0
#
#    sweeps  clamp_mV                                          notes  \
# 1       0       -70                              ID5, ON sustained
# 5   0;1;2       -70  ID11, center contrast 40 surround contrast 50
# 9   0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 13  0;1;2       -70        center contrast 40 surround contrast 50
# 17  0;1;2       -70        center contrast 40 surround contrast 50
# 21  0;1;2       -70        center contrast 40 surround contrast 50
#
#     peak_inward_pA  peak_outward_pA  ...  charge_transfer_pA_s  \
# 1      -158.755463        32.894920  ...            -10.969418
# 5       -89.971527        10.939930  ...           -181.971359
# 9       -47.463848        26.592148  ...            -68.959015
# 13      -75.619843        13.491485  ...           -166.680191
# 17      -57.287495        19.209894  ...           -117.075844
# 21      -42.746155        15.033791  ...            -39.258759
#
#     analysis_level  sweep  baseline_mean_pA n_sweeps_averaged  \
# 1    average_trace    avg        -35.946678                 1
# 5    average_trace    avg        -29.250479                 3
# 9    average_trace    avg        -35.340515                 3
# 13   average_trace    avg        -45.840118                 3
# 17   average_trace    avg        -72.513939                 3
# 21   average_trace    avg        -41.278904                 3
#
#    inward_mean_response_pA  inward_peak_response_pA  inward_late_response_pA  \
# 1                 1.372448               158.755463                 1.010218
# 5                22.746403                89.971527                22.434559
# 9                 8.619793                47.463848                 8.614800
# 13               20.835144                75.619843                20.775898
# 17               14.634500                57.287495                14.840819
# 21                4.907113                42.746155                 4.317784
#
#     inward_early_response_pA  inward_charge_pA_s
# 1                   3.906793           10.969418
# 5                  24.921566          181.971359
# 9                   8.652543           68.959015
# 13                 21.244806          166.680191
# 17                 13.186996          117.075844
# 21                  9.029967           39.258759
#
# [6 rows x 23 columns]

# %% [markdown]
# ### For final tuning curves use: average results
# ### For checking variability use: individual_results

# %% [markdown]
# ## Plot center-only spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_only"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="center_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Center spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center-only spatial frequency tuning")
plt.show()

# %% [markdown]
# ## Plot center+surround spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_surround"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="surround_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Surround spatial frequency")
plt.ylabel("Mean EPSC response magnitude (pA)")
plt.title("Center+surround response vs surround spatial frequency")
plt.show()

# %% [markdown]
# ## Plot control vs TTX at one condition

# %%
df = average_results[
    (average_results["stimulus_type"] == "center_surround") &
    (average_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.barplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar=None
)

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center_Surround SF 1: control vs TTX")
plt.show()

# %% [markdown]
# ## Show individual sweep variability

# %%
df = individual_results[
    (individual_results["stimulus_type"] == "center_surround") &
    (individual_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8,
    jitter=True
)

sns.pointplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar="se",
    color="red",
    markers="D"
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Individual sweeps: center_surround SF 1")
plt.show()

# %% [markdown]
# ## Overlay control and TTX average traces

# %%
def get_average_trace_for_row(row, baseline_window=(0.2, 1.0)):
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        row["file"],
        sweeps,
        baseline_window=baseline_window
    )

    return time, average_trace


def overlay_average_traces(
    metadata,
    stimulus_type,
    center_sf=None,
    surround_sf=None,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0)
):
    df = metadata[metadata["stimulus_type"] == stimulus_type].copy()

    if center_sf is not None:
        df = df[df["center_sf"] == center_sf]

    if surround_sf is not None:
        df = df[df["surround_sf"] == surround_sf]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['drug']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(f"{stimulus_type}, center SF={center_sf}, surround SF={surround_sf}")
    plt.legend()
    plt.show()

# %%
overlay_average_traces(
    metadata,
    stimulus_type="center_surround",
    center_sf=1,
    surround_sf=1,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %%
def overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=1,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0)
):
    df = metadata[
        (metadata["drug"] == drug) &
        (
            (
                (metadata["stimulus_type"] == "center_only") &
                (metadata["center_sf"] == center_sf)
            )
            |
            (
                (metadata["stimulus_type"] == "center_surround") &
                (metadata["center_sf"] == center_sf) &
                (metadata["surround_sf"] == surround_sf)
            )
        )
    ].copy()

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['stimulus_type']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(
        f"{drug}: center_only vs center_surround | "
        f"center SF={center_sf}, surround SF={surround_sf}"
    )
    plt.legend()
    plt.show()

# %%
overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=16,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %% [markdown]
# ## Calculate surround modulation index

# %% [markdown]
# SMI = (Rc+s - Rc) / (Rc+s + Rc)

# %%
def calculate_smi(average_results, response_column="inward_mean_response_pA"):
    """
    Calculates surround modulation index for center+surround rows.

    This assumes matching center_only rows exist for the same:
    - drug
    - center_sf
    """

    center_only = average_results[
        average_results["stimulus_type"] == "center_only"
    ].copy()

    center_surround = average_results[
        average_results["stimulus_type"] == "center_surround"
    ].copy()

    smi_rows = []

    for _, cs_row in center_surround.iterrows():
        matching_center = center_only[
            (center_only["drug"] == cs_row["drug"]) &
            (center_only["center_sf"] == cs_row["center_sf"])
        ]

        if len(matching_center) == 0:
            continue

        r_center = matching_center.iloc[0][response_column]
        r_cs = cs_row[response_column]

        smi = (r_cs - r_center) / (r_cs + r_center)

        output = cs_row.to_dict()
        output["R_center"] = r_center
        output["R_center_surround"] = r_cs
        output["SMI"] = smi

        smi_rows.append(output)

    return pd.DataFrame(smi_rows)

# %%
smi_results = calculate_smi(
    average_results,
    response_column="inward_mean_response_pA"
)

smi_results
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_12_0008.abf  control  center_surround        1.0          1.0
# 1  2026_05_12_0009.abf  control  center_surround        1.0         16.0
# 2  2026_05_12_0010.abf  control  center_surround        1.0          8.0
# 3  2026_05_12_0011.abf  control  center_surround        1.0          2.0
#
#   sweeps  clamp_mV                                          notes  \
# 0  0;1;2       -70  ID12, center contrast 40 surround contrast 50
# 1  0;1;2       -70        center contrast 40 surround contrast 50
# 2  0;1;2       -70        center contrast 40 surround contrast 50
# 3  0;1;2       -70        center contrast 40 surround contrast 50
#
#    peak_inward_pA  peak_outward_pA  ...  baseline_mean_pA  n_sweeps_averaged  \
# 0      -47.463848        26.592148  ...        -35.340515                  3
# 1      -75.619843        13.491485  ...        -45.840118                  3
# 2      -57.287495        19.209894  ...        -72.513939                  3
# 3      -42.746155        15.033791  ...        -41.278904                  3
#
#    inward_mean_response_pA  inward_peak_response_pA inward_late_response_pA  \
# 0                 8.619793                47.463848                8.614800
# 1                20.835144                75.619843               20.775898
# 2                14.634500                57.287495               14.840819
# 3                 4.907113                42.746155                4.317784
#
#   inward_early_response_pA  inward_charge_pA_s   R_center  R_center_surround  \
# 0                 8.652543           68.959015  22.746403           8.619793
# 1                21.244806          166.680191  22.746403          20.835144
# 2                13.186996          117.075844  22.746403          14.634500
# 3                 9.029967           39.258759  22.746403           4.907113
#
#         SMI
# 0 -0.450377
# 1 -0.043855
# 2 -0.217007
# 3 -0.645100
#
# [4 rows x 26 columns]

# %%
plt.figure(figsize=(8, 5))

sns.lineplot(
    data=smi_results,
    x="surround_sf",
    y="SMI",
    hue="drug",
    marker="o"
)

plt.axhline(0, color="black", lw=1)
plt.xlabel("Surround spatial frequency")
plt.ylabel("Surround modulation index")
plt.title("Surround modulation vs spatial frequency")
plt.show()

# %% [markdown]
# ## SAVE FIGURES

# %% [markdown]
# any plot can be saved by adding this code before plt.show()

# %%
#plt.savefig(FIG_DIR / "my_figure_name.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Things to double check
#
# 1. Are the stimulus windows correct?
# 2. Are the baseline windows quiet?
# 3. Do the three sweeps look similar?
# 4. Are inward currents plotted as positive?
# 5. Are control and TTX labels entered consistently?
# 6. Are spatial frequencies numeric?

# %%
##Checking the averaged trace
row = average_results.iloc[1]
row
# Out:
# file                                                  2026_05_12_0007.abf
# drug                                                              control
# stimulus_type                                                 center_only
# center_sf                                                             1.0
# surround_sf                                                         100.0
# sweeps                                                              0;1;2
# clamp_mV                                                              -70
# notes                       ID11, center contrast 40 surround contrast 50
# peak_inward_pA                                                 -89.971527
# peak_outward_pA                                                  10.93993
# mean_response_pA                                               -22.746403
# early_mean_response_pA                                         -24.921566
# late_mean_response_pA                                          -22.434559
# charge_transfer_pA_s                                          -181.971359
# analysis_level                                              average_trace
# sweep                                                                 avg
# baseline_mean_pA                                               -29.250479
# n_sweeps_averaged                                                       3
# inward_mean_response_pA                                         22.746403
# inward_peak_response_pA                                         89.971527
# inward_late_response_pA                                         22.434559
# inward_early_response_pA                                        24.921566
# inward_charge_pA_s                                             181.971359
# Name: 5, dtype: object
