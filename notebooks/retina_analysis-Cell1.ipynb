# %% [markdown]
# ## Import Packages

# %%
from pathlib import Path

import pyabf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.integrate import trapezoid

import ipywidgets as widgets
from IPython.display import display

sns.set_context("talk")
sns.set_style("whitegrid")

# %% [markdown]
# ## Set folder paths

# %%
PROJECT = Path.home() / "Desktop" / "retina_project"

DATA_DIR = PROJECT / "data"
META_DIR = PROJECT / "metadata"
NOTEBOOK_DIR = PROJECT / "notebooks"
RESULTS_DIR = PROJECT / "results"
FIG_DIR = RESULTS_DIR / "figures"

META_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)
FIG_DIR.mkdir(exist_ok=True)

print("Project folder:", PROJECT)
print("Data folder:", DATA_DIR)
print("Metadata folder:", META_DIR)
print("Results folder:", RESULTS_DIR)
# Out:
# Project folder: /Users/ahnekevanlankvelt/Desktop/retina_project
# Data folder: /Users/ahnekevanlankvelt/Desktop/retina_project/data
# Metadata folder: /Users/ahnekevanlankvelt/Desktop/retina_project/metadata
# Results folder: /Users/ahnekevanlankvelt/Desktop/retina_project/results

# %% [markdown]
# ## Create metadata table

# %%
META_FILE = META_DIR / "experiment_cell1_metadata.csv"

metadata = pd.DataFrame([
    # {
    #     "file": "2026_05_07_0017.abf",
    #     "drug": "control",
    #     "stimulus_type": "spot",
    #     "center_sf": np.nan,
    #     "surround_sf": np.nan,
    #     "sweeps": "0",
    #     "clamp_mV": -70,
    #     "notes": "simple spot"
    # },
    # {
    #     "file": "2026_05_07_0018.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "na"
    # },
    #{
        #"file": "2026_05_07_0019.abf",
        #"drug": "control",
        #"stimulus_type": "center_surround",
        #"center_sf": 1,
        #"surround_sf": 1,
        #"sweeps": "0;1;2",
        #"clamp_mV": -70,
        #"notes": "na"
   # },
    # {
    #     "file": "2026_05_07_0020.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "na"
    # },
    # {
    #     "file": "2026_05_07_0021.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 1,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": "na"
    # },
    # {
    #     "file": "2026_05_07_0022.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 4,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "notes": ""
    # },
    {
        "file": "2026_05_07_0025.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    },
    {
        "file": "2026_05_07_0026.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 4,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    },
    {
        "file": "2026_05_07_0027.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 6,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    },
    {
        "file": "2026_05_07_0028.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center only"
    },
    {
        "file": "2026_05_07_0030.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 4,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    },
    {
        "file": "2026_05_07_0032.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    },
    {
        "file": "2026_05_07_0033.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 6,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    },
    {
        "file": "2026_05_07_0034.abf",
        "drug": "TTX",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "notes": "center contrast 50 surround contrast 255"
    }

])

metadata.to_csv(META_FILE, index=False)
metadata
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_07_0025.abf  control  center_surround          1            1
# 1  2026_05_07_0026.abf  control  center_surround          1            4
# 2  2026_05_07_0027.abf  control  center_surround          1            6
# 3  2026_05_07_0028.abf  control      center_only          1          100
# 4  2026_05_07_0030.abf      TTX  center_surround          1            4
# 5  2026_05_07_0032.abf      TTX  center_surround          1            1
# 6  2026_05_07_0033.abf      TTX  center_surround          1            6
# 7  2026_05_07_0034.abf      TTX  center_surround          1            2
#
#   sweeps  clamp_mV                                     notes
# 0  0;1;2       -70  center contrast 50 surround contrast 255
# 1  0;1;2       -70  center contrast 50 surround contrast 255
# 2  0;1;2       -70  center contrast 50 surround contrast 255
# 3  0;1;2       -70                               center only
# 4  0;1;2       -70  center contrast 50 surround contrast 255
# 5  0;1;2       -70  center contrast 50 surround contrast 255
# 6  0;1;2       -70  center contrast 50 surround contrast 255
# 7  0;1;2       -70  center contrast 50 surround contrast 255

# %% [markdown]
# ## Load Metadata

# %%
META_FILE = META_DIR / "experiment_cell1_metadata.csv"

metadata = pd.read_csv(META_FILE)

metadata
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_07_0025.abf  control  center_surround          1            1
# 1  2026_05_07_0026.abf  control  center_surround          1            4
# 2  2026_05_07_0027.abf  control  center_surround          1            6
# 3  2026_05_07_0028.abf  control      center_only          1          100
# 4  2026_05_07_0030.abf      TTX  center_surround          1            4
# 5  2026_05_07_0032.abf      TTX  center_surround          1            1
# 6  2026_05_07_0033.abf      TTX  center_surround          1            6
# 7  2026_05_07_0034.abf      TTX  center_surround          1            2
#
#   sweeps  clamp_mV                                     notes
# 0  0;1;2       -70  center contrast 50 surround contrast 255
# 1  0;1;2       -70  center contrast 50 surround contrast 255
# 2  0;1;2       -70  center contrast 50 surround contrast 255
# 3  0;1;2       -70                               center only
# 4  0;1;2       -70  center contrast 50 surround contrast 255
# 5  0;1;2       -70  center contrast 50 surround contrast 255
# 6  0;1;2       -70  center contrast 50 surround contrast 255
# 7  0;1;2       -70  center contrast 50 surround contrast 255

# %% [markdown]
# ## Define helper functions to load ABF files

# %%
def parse_sweeps(sweep_string):
    """
    Converts a sweep string like '0;1;2' into a list: [0, 1, 2].
    """
    return [int(s.strip()) for s in str(sweep_string).split(";")]


def load_sweeps(file_name, sweeps):
    """
    Loads multiple sweeps from one ABF file.

    Parameters
    ----------
    file_name : str
        Name of the ABF file.
    sweeps : list
        List of sweep numbers, for example [0, 1, 2].

    Returns
    -------
    time : array
        Time values in seconds.
    traces : array
        Shape is number of sweeps x number of timepoints.
    """

    file_path = DATA_DIR / file_name

    if not file_path.exists():
        raise FileNotFoundError(f"Could not find file: {file_path}")

    abf = pyabf.ABF(str(file_path))

    traces = []
    time = None

    for sweep in sweeps:
        abf.setSweep(int(sweep))

        if time is None:
            time = abf.sweepX

        traces.append(abf.sweepY)

    traces = np.array(traces)

    return time, traces

# %% [markdown]
# ## load and plot one file's three sweeps

# %%
test_file = metadata.loc[6, "file"]
test_sweeps = parse_sweeps(metadata.loc[6, "sweeps"])

time, traces = load_sweeps(test_file, test_sweeps)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, traces):
    plt.plot(time, trace, alpha=0.7, label=f"Sweep {sweep_number}")

plt.xlabel("Time (s)")
plt.ylabel("Current (pA)")
plt.title(test_file)
plt.legend()
plt.show()

# %% [markdown]
# ## Baseline-subtract each sweep

# %%
def baseline_subtract_traces(time, traces, baseline_window=(0.2, 1.0)):
    """
    Baseline-subtracts each sweep independently.

    Parameters
    ----------
    time : array
        Time values.
    traces : array
        Shape is number of sweeps x number of timepoints.
    baseline_window : tuple
        Start and end of baseline window in seconds.

    Returns
    -------
    corrected_traces : array
        Baseline-subtracted traces.
    baselines : array
        Baseline mean for each sweep.
    """

    baseline_mask = (time >= baseline_window[0]) & (time <= baseline_window[1])

    corrected_traces = []
    baselines = []

    for trace in traces:
        baseline = np.mean(trace[baseline_mask])
        baselines.append(baseline)
        corrected_traces.append(trace - baseline)

    corrected_traces = np.array(corrected_traces)
    baselines = np.array(baselines)

    return corrected_traces, baselines

# %%
baseline_window = (0.2, 1.0)

corrected_traces, baselines = baseline_subtract_traces(
    time,
    traces,
    baseline_window=baseline_window
)

print("Baseline values for each sweep:", baselines)
# Out:
# Baseline values for each sweep: [-88.3776 -85.281  -85.0229]

# %% [markdown]
# ## Average the baseline-subtracted sweeps

# %%
def average_baseline_corrected_sweeps(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0)
):
    """
    Loads sweeps, baseline-subtracts each sweep, then averages them.
    """

    time, traces = load_sweeps(file_name, sweeps)

    corrected_traces, baselines = baseline_subtract_traces(
        time,
        traces,
        baseline_window=baseline_window
    )

    average_trace = np.mean(corrected_traces, axis=0)

    return time, corrected_traces, average_trace, baselines

# %%
time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
    test_file,
    test_sweeps,
    baseline_window=(0.2, 1.0)
)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, corrected_traces):
    plt.plot(time, trace, alpha=0.35, label=f"Sweep {sweep_number}")

plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

plt.axhline(0, color="black", lw=1)
plt.xlabel("Time (s)")
plt.ylabel("Baseline-subtracted current (pA)")
plt.title(f"{test_file}: baseline-subtracted sweeps and average")
plt.legend()
plt.show()

# %% [markdown]
# ## Make a reusable plotting function

# %%
def plot_condition_average(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(1.2, 10.0),
    title=None
):
    """
    Plots individual baseline-subtracted sweeps and their average.
    """

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    plt.figure(figsize=(12, 5))

    for sweep_number, trace in zip(sweeps, corrected_traces):
        plt.plot(time, trace, alpha=0.35, lw=1, label=f"Sweep {sweep_number}")

    plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

    plt.axvspan(
        baseline_window[0],
        baseline_window[1],
        color="gray",
        alpha=0.15,
        label="baseline"
    )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    if title is None:
        title = f"{file_name}, sweeps {sweeps}"

    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_condition_average(
    file_name=test_file,
    sweeps=test_sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(1.2, 10.0)
)

# %% [markdown]
# ## Add interactive viewer

# %%
file_dropdown = widgets.Dropdown(
    options=metadata["file"].tolist(),
    description="File:",
    layout=widgets.Layout(width="400px")
)

baseline_start_widget = widgets.FloatText(value=0.2, description="Base start")
baseline_end_widget = widgets.FloatText(value=1.0, description="Base end")

stim_start_widget = widgets.FloatText(value=1.2, description="Stim start")
stim_end_widget = widgets.FloatText(value=10.0, description="Stim end")


def interactive_average_plot(file_name, b0, b1, s0, s1):
    row = metadata[metadata["file"] == file_name].iloc[0]
    sweeps = parse_sweeps(row["sweeps"])

    title = (
        f"{file_name} | {row['drug']} | {row['stimulus_type']} | "
        f"center SF={row['center_sf']} | surround SF={row['surround_sf']}"
    )

    plot_condition_average(
        file_name=file_name,
        sweeps=sweeps,
        baseline_window=(b0, b1),
        stim_window=(s0, s1),
        title=title
    )


widgets.interact(
    interactive_average_plot,
    file_name=file_dropdown,
    b0=baseline_start_widget,
    b1=baseline_end_widget,
    s0=stim_start_widget,
    s1=stim_end_widget
);
# Out:
# interactive(children=(Dropdown(description='File:', layout=Layout(width='400px'), options=('2026_05_07_0025.ab…

# %% [markdown]
# ## Define response windows

# %%
baseline_window = (0.1, 1.1)
stim_window = (1.5, 10.0)
early_window = (1.5, 2.2)
late_window = (2.2, 10.0)

# %% [markdown]
# ## Analyze one trace

# %%
def analyze_trace(
    time,
    trace,
    stim_window=(1.5, 10.0),
    early_window=(1.5, 2.2),
    late_window=(2.2, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes a baseline-subtracted trace.

    Because the trace is already baseline-subtracted:
    - baseline is approximately 0
    - inward currents at -70 mV are negative
    """

    stim_mask = (time >= stim_window[0]) & (time <= stim_window[1])
    early_mask = (time >= early_window[0]) & (time <= early_window[1])
    late_mask = (time >= late_window[0]) & (time <= late_window[1])

    stim_current = trace[stim_mask]
    stim_time = time[stim_mask]

    early_current = trace[early_mask]
    late_current = trace[late_mask]

    cleaned_stim = stim_current.copy()
    cleaned_stim[np.abs(cleaned_stim) > artifact_threshold_pA] = np.nan

    peak_inward = np.nanmin(cleaned_stim)
    peak_outward = np.nanmax(cleaned_stim)

    mean_response = np.nanmean(cleaned_stim)
    early_mean_response = np.nanmean(early_current)
    late_mean_response = np.nanmean(late_current)

    charge_transfer = trapezoid(stim_current, stim_time)

    return {
        "peak_inward_pA": peak_inward,
        "peak_outward_pA": peak_outward,
        "mean_response_pA": mean_response,
        "early_mean_response_pA": early_mean_response,
        "late_mean_response_pA": late_mean_response,
        "charge_transfer_pA_s": charge_transfer
    }

# %% [markdown]
# ## Analyze individual sweeps and the averaged trace
# It will produce
# - one row for sweep 0
# - one row for sweep 1
# - one row for sweep 2
# - one row for the average trace

# %%
def analyze_condition_row(
    row,
    baseline_window=(0.1, 1.1),
    stim_window=(1.5, 10.0),
    early_window=(1.5, 2.2),
    late_window=(2.2, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes all sweeps for one stimulus condition.

    Each metadata row represents one condition/file.
    """

    file_name = row["file"]
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    output_rows = []

    # Analyze individual sweeps
    for sweep_number, trace, baseline in zip(sweeps, corrected_traces, baselines):
        result = analyze_trace(
            time=time,
            trace=trace,
            stim_window=stim_window,
            early_window=early_window,
            late_window=late_window,
            artifact_threshold_pA=artifact_threshold_pA
        )

        output = row.to_dict()
        output.update(result)

        output["analysis_level"] = "individual_sweep"
        output["sweep"] = sweep_number
        output["baseline_mean_pA"] = baseline
        output["n_sweeps_averaged"] = 1

        output_rows.append(output)

    # Analyze averaged trace
    avg_result = analyze_trace(
        time=time,
        trace=average_trace,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=artifact_threshold_pA
    )

    output = row.to_dict()
    output.update(avg_result)

    output["analysis_level"] = "average_trace"
    output["sweep"] = "avg"
    output["baseline_mean_pA"] = np.mean(baselines)
    output["n_sweeps_averaged"] = len(sweeps)

    output_rows.append(output)

    return output_rows

# %% [markdown]
# ## Analyze the whole experiment
# everything is multiplied by -1 because at -70mV, excitatory inward currents are negative. Turning them positive makes graphs easier to interpret: bigger response = higher value

# %%
all_results = []

for _, row in metadata.iterrows():
    condition_results = analyze_condition_row(
        row,
        baseline_window=baseline_window,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=500
    )

    all_results.extend(condition_results)

results = pd.DataFrame(all_results)

results["inward_mean_response_pA"] = -results["mean_response_pA"]
results["inward_peak_response_pA"] = -results["peak_inward_pA"]
results["inward_late_response_pA"] = -results["late_mean_response_pA"]
results["inward_early_response_pA"] = -results["early_mean_response_pA"]
results["inward_charge_pA_s"] = -results["charge_transfer_pA_s"]

results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_07_0025.abf  control  center_surround          1            1
# 1   2026_05_07_0025.abf  control  center_surround          1            1
# 2   2026_05_07_0025.abf  control  center_surround          1            1
# 3   2026_05_07_0025.abf  control  center_surround          1            1
# 4   2026_05_07_0026.abf  control  center_surround          1            4
# 5   2026_05_07_0026.abf  control  center_surround          1            4
# 6   2026_05_07_0026.abf  control  center_surround          1            4
# 7   2026_05_07_0026.abf  control  center_surround          1            4
# 8   2026_05_07_0027.abf  control  center_surround          1            6
# 9   2026_05_07_0027.abf  control  center_surround          1            6
# 10  2026_05_07_0027.abf  control  center_surround          1            6
# 11  2026_05_07_0027.abf  control  center_surround          1            6
# 12  2026_05_07_0028.abf  control      center_only          1          100
# 13  2026_05_07_0028.abf  control      center_only          1          100
# 14  2026_05_07_0028.abf  control      center_only          1          100
# 15  2026_05_07_0028.abf  control      center_only          1          100
# 16  2026_05_07_0030.abf      TTX  center_surround          1            4
# 17  2026_05_07_0030.abf      TTX  center_surround          1            4
# 18  2026_05_07_0030.abf      TTX  center_surround          1            4
# 19  2026_05_07_0030.abf      TTX  center_surround          1            4
# 20  2026_05_07_0032.abf      TTX  center_surround          1            1
# 21  2026_05_07_0032.abf      TTX  center_surround          1            1
# 22  2026_05_07_0032.abf      TTX  center_surround          1            1
# 23  2026_05_07_0032.abf      TTX  center_surround          1            1
# 24  2026_05_07_0033.abf      TTX  center_surround          1            6
# 25  2026_05_07_0033.abf      TTX  center_surround          1            6
# 26  2026_05_07_0033.abf      TTX  center_surround          1            6
# 27  2026_05_07_0033.abf      TTX  center_surround          1            6
# 28  2026_05_07_0034.abf      TTX  center_surround          1            2
# 29  2026_05_07_0034.abf      TTX  center_surround          1            2
# 30  2026_05_07_0034.abf      TTX  center_surround          1            2
# 31  2026_05_07_0034.abf      TTX  center_surround          1            2
#
#    sweeps  clamp_mV                                     notes  peak_inward_pA  \
# 0   0;1;2       -70  center contrast 50 surround contrast 255      -72.215988
# 1   0;1;2       -70  center contrast 50 surround contrast 255     -113.524170
# 2   0;1;2       -70  center contrast 50 surround contrast 255     -105.329811
# 3   0;1;2       -70  center contrast 50 surround contrast 255      -52.264210
# 4   0;1;2       -70  center contrast 50 surround contrast 255     -126.634293
# 5   0;1;2       -70  center contrast 50 surround contrast 255     -118.948235
# 6   0;1;2       -70  center contrast 50 surround contrast 255     -140.709457
# 7   0;1;2       -70  center contrast 50 surround contrast 255      -90.718750
# 8   0;1;2       -70  center contrast 50 surround contrast 255     -179.101501
# 9   0;1;2       -70  center contrast 50 surround contrast 255     -185.529022
# 10  0;1;2       -70  center contrast 50 surround contrast 255     -113.595558
# 11  0;1;2       -70  center contrast 50 surround contrast 255     -139.877441
# 12  0;1;2       -70                               center only     -248.498520
# 13  0;1;2       -70                               center only     -257.574158
# 14  0;1;2       -70                               center only     -169.493607
# 15  0;1;2       -70                               center only     -197.112595
# 16  0;1;2       -70  center contrast 50 surround contrast 255     -194.431824
# 17  0;1;2       -70  center contrast 50 surround contrast 255     -187.773346
# 18  0;1;2       -70  center contrast 50 surround contrast 255     -196.298126
# 19  0;1;2       -70  center contrast 50 surround contrast 255     -144.616653
# 20  0;1;2       -70  center contrast 50 surround contrast 255     -117.042580
# 21  0;1;2       -70  center contrast 50 surround contrast 255     -117.376511
# 22  0;1;2       -70  center contrast 50 surround contrast 255      -72.984825
# 23  0;1;2       -70  center contrast 50 surround contrast 255      -63.608929
# 24  0;1;2       -70  center contrast 50 surround contrast 255     -112.826256
# 25  0;1;2       -70  center contrast 50 surround contrast 255      -94.958862
# 26  0;1;2       -70  center contrast 50 surround contrast 255      -85.911133
# 27  0;1;2       -70  center contrast 50 surround contrast 255      -66.974274
# 28  0;1;2       -70  center contrast 50 surround contrast 255     -125.280418
# 29  0;1;2       -70  center contrast 50 surround contrast 255     -134.730865
# 30  0;1;2       -70  center contrast 50 surround contrast 255      -81.703659
# 31  0;1;2       -70  center contrast 50 surround contrast 255      -65.076859
#
#     peak_outward_pA  ...  charge_transfer_pA_s    analysis_level  sweep  \
# 0          2.246902  ...           -193.995209  individual_sweep      0
# 1          6.104736  ...           -182.243256  individual_sweep      1
# 2         11.857689  ...           -189.297302  individual_sweep      2
# 3         -5.877490  ...           -188.511917     average_trace    avg
# 4         -3.953629  ...           -297.160797  individual_sweep      0
# 5          6.173836  ...           -285.751862  individual_sweep      1
# 6         -7.652817  ...           -308.706665  individual_sweep      2
# 7        -14.831703  ...           -297.206421     average_trace    avg
# 8         -1.489197  ...           -362.110138  individual_sweep      0
# 9         -3.644257  ...           -312.896790  individual_sweep      1
# 10        -3.121925  ...           -324.451324  individual_sweep      2
# 11       -16.382978  ...           -333.152740     average_trace    avg
# 12        18.835464  ...           -588.373657  individual_sweep      0
# 13        14.642639  ...           -503.463715  individual_sweep      1
# 14        14.832565  ...           -370.637543  individual_sweep      2
# 15        -5.055298  ...           -487.491638     average_trace    avg
# 16        -3.391792  ...           -411.588104  individual_sweep      0
# 17        -5.888573  ...           -468.446533  individual_sweep      1
# 18        -4.037384  ...           -507.222290  individual_sweep      2
# 19       -14.611775  ...           -462.418976     average_trace    avg
# 20         3.807030  ...           -309.028290  individual_sweep      0
# 21         9.576614  ...           -237.891266  individual_sweep      1
# 22        22.230019  ...           -169.104034  individual_sweep      2
# 23        -3.794469  ...           -238.674530     average_trace    avg
# 24         3.140541  ...           -329.090973  individual_sweep      0
# 25        -0.354370  ...           -233.966431  individual_sweep      1
# 26         5.641602  ...           -180.204971  individual_sweep      2
# 27        -5.125313  ...           -247.754166     average_trace    avg
# 28        -4.430809  ...           -328.504669  individual_sweep      0
# 29        -1.674225  ...           -279.402771  individual_sweep      1
# 30         2.524857  ...           -226.846222  individual_sweep      2
# 31       -11.162468  ...           -278.251221     average_trace    avg
#
#     baseline_mean_pA n_sweeps_averaged inward_mean_response_pA  \
# 0         -69.385574                 1               22.823595
# 1         -68.970947                 1               21.441130
# 2         -69.841087                 1               22.270779
# 3         -69.399200                 3               22.178501
# 4         -82.716293                 1               34.960938
# 5         -81.247078                 1               33.618698
# 6         -76.575699                 1               36.319397
# 7         -80.179695                 3               34.966347
# 8         -86.401428                 1               42.602028
# 9         -83.025665                 1               36.812271
# 10        -80.496239                 1               38.171661
# 11        -83.307777                 3               39.195320
# 12        -92.077652                 1               69.223282
# 13        -86.664124                 1               59.232487
# 14        -88.685104                 1               43.604717
# 15        -89.142296                 3               57.353493
# 16        -89.381645                 1               48.423119
# 17        -85.664162                 1               55.112419
# 18        -88.125702                 1               59.674335
# 19        -87.723839                 3               54.403294
# 20        -86.814842                 1               36.356937
# 21        -86.480911                 1               27.988085
# 22        -85.096230                 1               19.895390
# 23        -86.130653                 3               28.080135
# 24        -87.979408                 1               38.717403
# 25        -84.484497                 1               27.526466
# 26        -84.376953                 1               21.201033
# 27        -85.613617                 3               29.148302
# 28        -83.459816                 1               38.648624
# 29        -81.943939                 1               32.871464
# 30        -80.649857                 1               26.688278
# 31        -82.017868                 3               32.736118
#
#     inward_peak_response_pA  inward_late_response_pA  \
# 0                 72.215988                22.454887
# 1                113.524170                20.789291
# 2                105.329811                21.746115
# 3                 52.264210                21.663429
# 4                126.634293                34.409851
# 5                118.948235                33.028854
# 6                140.709457                36.008839
# 7                 90.718750                34.482513
# 8                179.101501                41.575993
# 9                185.529022                35.938843
# 10               113.595558                38.000992
# 11               139.877441                38.505272
# 12               248.498520                68.597931
# 13               257.574158                58.428833
# 14               169.493607                43.923397
# 15               197.112595                56.983387
# 16               194.431824                48.394535
# 17               187.773346                55.961876
# 18               196.298126                58.929146
# 19               144.616653                54.428524
# 20               117.042580                35.365723
# 21               117.376511                27.436420
# 22                72.984825                19.076075
# 23                63.608929                27.292736
# 24               112.826256                37.849594
# 25                94.958862                26.891537
# 26                85.911133                20.873575
# 27                66.974274                28.538237
# 28               125.280418                38.277443
# 29               134.730865                32.836170
# 30                81.703659                26.446775
# 31                65.076859                32.520126
#
#     inward_early_response_pA  inward_charge_pA_s
# 0                  26.933393          193.995209
# 1                  28.703823          182.243256
# 2                  28.120878          189.297302
# 3                  27.919367          188.511917
# 4                  41.106625          297.160797
# 5                  40.210052          285.751862
# 6                  39.786163          308.706665
# 7                  40.367615          297.206421
# 8                  54.069427          362.110138
# 9                  46.580891          312.896790
# 10                 40.080769          324.451324
# 11                 46.910362          333.152740
# 12                 76.234261          588.373657
# 13                 68.245331          503.463715
# 14                 40.089268          370.637543
# 15                 61.522949          487.491638
# 16                 48.770485          411.588104
# 17                 45.650551          468.446533
# 18                 67.984177          507.222290
# 19                 54.135075          462.418976
# 20                 47.404320          309.028290
# 21                 34.133362          237.891266
# 22                 29.025354          169.104034
# 23                 36.854343          238.674530
# 24                 48.387211          329.090973
# 25                 34.602699          233.966431
# 26                 24.852879          180.204971
# 27                 35.947598          247.754166
# 28                 42.787518          328.504669
# 29                 33.269997          279.402771
# 30                 29.377291          226.846222
# 31                 35.144936          278.251221
#
# [32 rows x 23 columns]

# %% [markdown]
# ## Save Results

# %%
RESULTS_FILE = RESULTS_DIR / "response_summary_cell1.csv"

results.to_csv(RESULTS_FILE, index=False)

print("Saved results to:", RESULTS_FILE)
# Out:
# Saved results to: /Users/ahnekevanlankvelt/Desktop/retina_project/results/response_summary_cell1.csv

# %% [markdown]
# ## Separate individual sweeps from average traces

# %%
individual_results = results[results["analysis_level"] == "individual_sweep"].copy()
average_results = results[results["analysis_level"] == "average_trace"].copy()

average_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 3   2026_05_07_0025.abf  control  center_surround          1            1
# 7   2026_05_07_0026.abf  control  center_surround          1            4
# 11  2026_05_07_0027.abf  control  center_surround          1            6
# 15  2026_05_07_0028.abf  control      center_only          1          100
# 19  2026_05_07_0030.abf      TTX  center_surround          1            4
# 23  2026_05_07_0032.abf      TTX  center_surround          1            1
# 27  2026_05_07_0033.abf      TTX  center_surround          1            6
# 31  2026_05_07_0034.abf      TTX  center_surround          1            2
#
#    sweeps  clamp_mV                                     notes  peak_inward_pA  \
# 3   0;1;2       -70  center contrast 50 surround contrast 255      -52.264210
# 7   0;1;2       -70  center contrast 50 surround contrast 255      -90.718750
# 11  0;1;2       -70  center contrast 50 surround contrast 255     -139.877441
# 15  0;1;2       -70                               center only     -197.112595
# 19  0;1;2       -70  center contrast 50 surround contrast 255     -144.616653
# 23  0;1;2       -70  center contrast 50 surround contrast 255      -63.608929
# 27  0;1;2       -70  center contrast 50 surround contrast 255      -66.974274
# 31  0;1;2       -70  center contrast 50 surround contrast 255      -65.076859
#
#     peak_outward_pA  ...  charge_transfer_pA_s  analysis_level  sweep  \
# 3         -5.877490  ...           -188.511917   average_trace    avg
# 7        -14.831703  ...           -297.206421   average_trace    avg
# 11       -16.382978  ...           -333.152740   average_trace    avg
# 15        -5.055298  ...           -487.491638   average_trace    avg
# 19       -14.611775  ...           -462.418976   average_trace    avg
# 23        -3.794469  ...           -238.674530   average_trace    avg
# 27        -5.125313  ...           -247.754166   average_trace    avg
# 31       -11.162468  ...           -278.251221   average_trace    avg
#
#     baseline_mean_pA n_sweeps_averaged inward_mean_response_pA  \
# 3         -69.399200                 3               22.178501
# 7         -80.179695                 3               34.966347
# 11        -83.307777                 3               39.195320
# 15        -89.142296                 3               57.353493
# 19        -87.723839                 3               54.403294
# 23        -86.130653                 3               28.080135
# 27        -85.613617                 3               29.148302
# 31        -82.017868                 3               32.736118
#
#     inward_peak_response_pA  inward_late_response_pA  \
# 3                 52.264210                21.663429
# 7                 90.718750                34.482513
# 11               139.877441                38.505272
# 15               197.112595                56.983387
# 19               144.616653                54.428524
# 23                63.608929                27.292736
# 27                66.974274                28.538237
# 31                65.076859                32.520126
#
#     inward_early_response_pA  inward_charge_pA_s
# 3                  27.919367          188.511917
# 7                  40.367615          297.206421
# 11                 46.910362          333.152740
# 15                 61.522949          487.491638
# 19                 54.135075          462.418976
# 23                 36.854343          238.674530
# 27                 35.947598          247.754166
# 31                 35.144936          278.251221
#
# [8 rows x 23 columns]

# %% [markdown]
# ### For final tuning curves use: average results
# ### For checking variability use: individual_results

# %% [markdown]
# ## Plot center-only spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_only"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="center_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Center spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center-only spatial frequency tuning")
plt.show()

# %% [markdown]
# ## Plot center+surround spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_surround"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="surround_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Surround spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center+surround response vs surround spatial frequency")
plt.show()

# %% [markdown]
# ## Plot control vs TTX at one condition

# %%
df = average_results[
    (average_results["stimulus_type"] == "center_surround") &
    (average_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.barplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar=None
)

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center_Surround SF 1: control vs TTX")
plt.show()

# %% [markdown]
# ## Show individual sweep variability

# %%
df = individual_results[
    (individual_results["stimulus_type"] == "center_surround") &
    (individual_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8,
    jitter=True
)

sns.pointplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar="se",
    color="red",
    markers="D"
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Individual sweeps: center_surround SF 1")
plt.show()

# %% [markdown]
# ## Overlay control and TTX average traces

# %%
def get_average_trace_for_row(row, baseline_window=(0.2, 1.0)):
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        row["file"],
        sweeps,
        baseline_window=baseline_window
    )

    return time, average_trace


def overlay_average_traces(
    metadata,
    stimulus_type,
    center_sf=None,
    surround_sf=None,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0)
):
    df = metadata[metadata["stimulus_type"] == stimulus_type].copy()

    if center_sf is not None:
        df = df[df["center_sf"] == center_sf]

    if surround_sf is not None:
        df = df[df["surround_sf"] == surround_sf]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['drug']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(f"{stimulus_type}, center SF={center_sf}, surround SF={surround_sf}")
    plt.legend()
    plt.show()

# %%
overlay_average_traces(
    metadata,
    stimulus_type="center_surround",
    center_sf=1,
    surround_sf=6,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %%
def overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=1,
    baseline_window=(0.2, 1.0),
    stim_window=(1.2, 10.0)
):
    df = metadata[
        (metadata["drug"] == drug) &
        (
            (
                (metadata["stimulus_type"] == "center_only") &
                (metadata["center_sf"] == center_sf)
            )
            |
            (
                (metadata["stimulus_type"] == "center_surround") &
                (metadata["center_sf"] == center_sf) &
                (metadata["surround_sf"] == surround_sf)
            )
        )
    ].copy()

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['stimulus_type']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(
        f"{drug}: center_only vs center_surround | "
        f"center SF={center_sf}, surround SF={surround_sf}"
    )
    plt.legend()
    plt.show()

# %%
overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=6,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %% [markdown]
# ## Calculate surround modulation index

# %% [markdown]
# SMI = (Rc+s - Rc) / (Rc+s + Rc)

# %%
# def calculate_smi(average_results, response_column="inward_mean_response_pA"):
#     """
#     Calculates surround modulation index for center+surround rows.

#     This assumes matching center_only rows exist for the same:
#     - drug
#     - center_sf
#     """

#     center_only = average_results[
#         average_results["stimulus_type"] == "center_only"
#     ].copy()

#     center_surround = average_results[
#         average_results["stimulus_type"] == "center_surround"
#     ].copy()

#     smi_rows = []

#     for _, cs_row in center_surround.iterrows():
#         matching_center = center_only[
#             (center_only["drug"] == cs_row["drug"]) &
#             (center_only["center_sf"] == cs_row["center_sf"])
#         ]

#         if len(matching_center) == 0:
#             continue

#         r_center = matching_center.iloc[0][response_column]
#         r_cs = cs_row[response_column]

#         smi = (r_cs - r_center) / (r_cs + r_center)

#         output = cs_row.to_dict()
#         output["R_center"] = r_center
#         output["R_center_surround"] = r_cs
#         output["SMI"] = smi

#         smi_rows.append(output)

#     return pd.DataFrame(smi_rows)

# %%
# smi_results = calculate_smi(
#     average_results,
#     response_column="inward_mean_response_pA"
# )

# smi_results

# %%
# plt.figure(figsize=(8, 5))

# sns.lineplot(
#     data=smi_results,
#     x="surround_sf",
#     y="SMI",
#     hue="drug",
#     marker="o"
# )

# plt.axhline(0, color="black", lw=1)
# plt.xlabel("Surround spatial frequency")
# plt.ylabel("Surround modulation index")
# plt.title("Surround modulation vs spatial frequency")
# plt.show()

# %% [markdown]
# ## SAVE FIGURES

# %% [markdown]
# any plot can be saved by adding this code before plt.show()

# %%
#plt.savefig(FIG_DIR / "my_figure_name.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Things to double check
#
# 1. Are the stimulus windows correct?
# 2. Are the baseline windows quiet?
# 3. Do the three sweeps look similar?
# 4. Are inward currents plotted as positive?
# 5. Are control and TTX labels entered consistently?
# 6. Are spatial frequencies numeric?

# %%
# ##Checking the averaged trace
# row = average_results.iloc[1]
# row
