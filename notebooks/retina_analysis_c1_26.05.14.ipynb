# %% [markdown]
# ## Import Packages

# %%
from pathlib import Path

import pyabf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.integrate import trapezoid

import ipywidgets as widgets
from IPython.display import display

sns.set_context("talk")
sns.set_style("whitegrid")

# %% [markdown]
# ## Set folder paths

# %%
PROJECT = Path("/Volumes/My Passport for Mac/retina_project")

DATA_DIR = PROJECT / "data"
META_DIR = PROJECT / "metadata"
NOTEBOOK_DIR = PROJECT / "notebooks"
RESULTS_DIR = PROJECT / "results"
FIG_DIR = RESULTS_DIR / "figures"

META_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)
FIG_DIR.mkdir(exist_ok=True)

print("Project folder:", PROJECT)
print("Data folder:", DATA_DIR)
print("Metadata folder:", META_DIR)
print("Results folder:", RESULTS_DIR)
# Out:
# Project folder: /Volumes/My Passport for Mac/retina_project
# Data folder: /Volumes/My Passport for Mac/retina_project/data
# Metadata folder: /Volumes/My Passport for Mac/retina_project/metadata
# Results folder: /Volumes/My Passport for Mac/retina_project/results

# %% [markdown]
# ## Create metadata table

# %%
META_FILE = META_DIR / "experiment_c1_26.05.14_metadata.csv"

metadata = pd.DataFrame([
    {
        "file": "2026_05_14_0002.abf",
        "drug": "control",
        "stimulus_type": "spot",
        "center_sf": np.nan,
        "surround_sf": np.nan,
        "sweeps": "0",
        "clamp_mV": -70,
        "stimID": 4,
        "notes": "200um, WAC?"
    },
    {
        "file": "2026_05_14_0006.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 7,
        "notes": "center 400um diameter"
    },
    {
        "file": "2026_05_14_0007.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 8,
        "notes": "center 400um diameter"
    },
    {
        "file": "2026_05_14_0008.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 9,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0010.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 10,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0011.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 11,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0012.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 12,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0013.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 13,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0014.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 4,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 14,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0015.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 15,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0016.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 16,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0017.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 8,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 17,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0018.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 18,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0019.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 0.5,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 19,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0020.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 20,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0021.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 21,
        "notes": "center 300um diameter"
    },
    {
        "file": "2026_05_14_0022.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 22,
        "notes": "center 300um diameter"
    }
    
])

metadata.to_csv(META_FILE, index=False)
metadata
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_14_0002.abf  control             spot        NaN          NaN
# 1   2026_05_14_0006.abf  control  center_surround        1.0          1.0
# 2   2026_05_14_0007.abf  control      center_only        1.0        100.0
# 3   2026_05_14_0008.abf  control      center_only        1.0        100.0
# 4   2026_05_14_0010.abf  control  center_surround        1.0          2.0
# 5   2026_05_14_0011.abf  control      center_only        1.0        100.0
# 6   2026_05_14_0012.abf  control      center_only        1.0        100.0
# 7   2026_05_14_0013.abf  control  center_surround        1.0          1.0
# 8   2026_05_14_0014.abf  control  center_surround        1.0          4.0
# 9   2026_05_14_0015.abf  control      center_only        1.0        100.0
# 10  2026_05_14_0016.abf  control  center_surround        1.0          2.0
# 11  2026_05_14_0017.abf  control  center_surround        1.0          8.0
# 12  2026_05_14_0018.abf  control      center_only        1.0        100.0
# 13  2026_05_14_0019.abf  control  center_surround        1.0          0.5
# 14  2026_05_14_0020.abf  control  center_surround        1.0         16.0
# 15  2026_05_14_0021.abf  control  center_surround        1.0          1.0
# 16  2026_05_14_0022.abf  control      center_only        1.0        100.0
#
#    sweeps  clamp_mV  stimID                  notes
# 0       0       -70       4            200um, WAC?
# 1   0;1;2       -70       7  center 400um diameter
# 2   0;1;2       -70       8  center 400um diameter
# 3   0;1;2       -70       9  center 300um diameter
# 4   0;1;2       -70      10  center 300um diameter
# 5   0;1;2       -70      11  center 300um diameter
# 6   0;1;2       -70      12  center 300um diameter
# 7   0;1;2       -70      13  center 300um diameter
# 8   0;1;2       -70      14  center 300um diameter
# 9   0;1;2       -70      15  center 300um diameter
# 10  0;1;2       -70      16  center 300um diameter
# 11  0;1;2       -70      17  center 300um diameter
# 12  0;1;2       -70      18  center 300um diameter
# 13  0;1;2       -70      19  center 300um diameter
# 14  0;1;2       -70      20  center 300um diameter
# 15  0;1;2       -70      21  center 300um diameter
# 16  0;1;2       -70      22  center 300um diameter

# %% [markdown]
# ## Load Metadata

# %%
META_FILE = META_DIR / "experiment_c1_26.05.14_metadata.csv"

metadata = pd.read_csv(META_FILE)

metadata
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_14_0002.abf  control             spot        NaN          NaN
# 1   2026_05_14_0006.abf  control  center_surround        1.0          1.0
# 2   2026_05_14_0007.abf  control      center_only        1.0        100.0
# 3   2026_05_14_0008.abf  control      center_only        1.0        100.0
# 4   2026_05_14_0010.abf  control  center_surround        1.0          2.0
# 5   2026_05_14_0011.abf  control      center_only        1.0        100.0
# 6   2026_05_14_0012.abf  control      center_only        1.0        100.0
# 7   2026_05_14_0013.abf  control  center_surround        1.0          1.0
# 8   2026_05_14_0014.abf  control  center_surround        1.0          4.0
# 9   2026_05_14_0015.abf  control      center_only        1.0        100.0
# 10  2026_05_14_0016.abf  control  center_surround        1.0          2.0
# 11  2026_05_14_0017.abf  control  center_surround        1.0          8.0
# 12  2026_05_14_0018.abf  control      center_only        1.0        100.0
# 13  2026_05_14_0019.abf  control  center_surround        1.0          0.5
# 14  2026_05_14_0020.abf  control  center_surround        1.0         16.0
# 15  2026_05_14_0021.abf  control  center_surround        1.0          1.0
# 16  2026_05_14_0022.abf  control      center_only        1.0        100.0
#
#    sweeps  clamp_mV  stimID                  notes
# 0       0       -70       4            200um, WAC?
# 1   0;1;2       -70       7  center 400um diameter
# 2   0;1;2       -70       8  center 400um diameter
# 3   0;1;2       -70       9  center 300um diameter
# 4   0;1;2       -70      10  center 300um diameter
# 5   0;1;2       -70      11  center 300um diameter
# 6   0;1;2       -70      12  center 300um diameter
# 7   0;1;2       -70      13  center 300um diameter
# 8   0;1;2       -70      14  center 300um diameter
# 9   0;1;2       -70      15  center 300um diameter
# 10  0;1;2       -70      16  center 300um diameter
# 11  0;1;2       -70      17  center 300um diameter
# 12  0;1;2       -70      18  center 300um diameter
# 13  0;1;2       -70      19  center 300um diameter
# 14  0;1;2       -70      20  center 300um diameter
# 15  0;1;2       -70      21  center 300um diameter
# 16  0;1;2       -70      22  center 300um diameter

# %% [markdown]
# ## Define helper functions to load ABF files

# %%
def parse_sweeps(sweep_string):
    """
    Converts a sweep string like '0;1;2' into a list: [0, 1, 2].
    """
    return [int(s.strip()) for s in str(sweep_string).split(";")]


def load_sweeps(file_name, sweeps):
    """
    Loads multiple sweeps from one ABF file.

    Parameters
    ----------
    file_name : str
        Name of the ABF file.
    sweeps : list
        List of sweep numbers, for example [0, 1, 2].

    Returns
    -------
    time : array
        Time values in seconds.
    traces : array
        Shape is number of sweeps x number of timepoints.
    """

    file_path = DATA_DIR / file_name

    if not file_path.exists():
        raise FileNotFoundError(f"Could not find file: {file_path}")

    abf = pyabf.ABF(str(file_path))

    traces = []
    time = None

    for sweep in sweeps:
        abf.setSweep(int(sweep))

        if time is None:
            time = abf.sweepX

        traces.append(abf.sweepY)

    traces = np.array(traces)

    return time, traces

# %% [markdown]
# ## load and plot one file's three sweeps

# %%
test_file = metadata.loc[1, "file"]
test_sweeps = parse_sweeps(metadata.loc[1, "sweeps"])

time, traces = load_sweeps(test_file, test_sweeps)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, traces):
    plt.plot(time, trace, alpha=0.7, label=f"Sweep {sweep_number}")

plt.xlabel("Time (s)")
plt.ylabel("Current (pA)")
plt.title(test_file)
plt.legend()
plt.show()

# %% [markdown]
# ## Baseline-subtract each sweep

# %%
def baseline_subtract_traces(time, traces, baseline_window=(0.2, 1.0)):
    """
    Baseline-subtracts each sweep independently.

    Parameters
    ----------
    time : array
        Time values.
    traces : array
        Shape is number of sweeps x number of timepoints.
    baseline_window : tuple
        Start and end of baseline window in seconds.

    Returns
    -------
    corrected_traces : array
        Baseline-subtracted traces.
    baselines : array
        Baseline mean for each sweep.
    """

    baseline_mask = (time >= baseline_window[0]) & (time <= baseline_window[1])

    corrected_traces = []
    baselines = []

    for trace in traces:
        baseline = np.mean(trace[baseline_mask])
        baselines.append(baseline)
        corrected_traces.append(trace - baseline)

    corrected_traces = np.array(corrected_traces)
    baselines = np.array(baselines)

    return corrected_traces, baselines

# %%
baseline_window = (0.2, 1.0)

corrected_traces, baselines = baseline_subtract_traces(
    time,
    traces,
    baseline_window=baseline_window
)

print("Baseline values for each sweep:", baselines)
# Out:
# Baseline values for each sweep: [-75.7965 -87.7059 -86.8019]

# %% [markdown]
# ## Average the baseline-subtracted sweeps

# %%
def average_baseline_corrected_sweeps(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0)
):
    """
    Loads sweeps, baseline-subtracts each sweep, then averages them.
    """

    time, traces = load_sweeps(file_name, sweeps)

    corrected_traces, baselines = baseline_subtract_traces(
        time,
        traces,
        baseline_window=baseline_window
    )

    average_trace = np.mean(corrected_traces, axis=0)

    return time, corrected_traces, average_trace, baselines

# %%
time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
    test_file,
    test_sweeps,
    baseline_window=(0.2, 1.0)
)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, corrected_traces):
    plt.plot(time, trace, alpha=0.35, label=f"Sweep {sweep_number}")

plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

plt.axhline(0, color="black", lw=1)
plt.xlabel("Time (s)")
plt.ylabel("Baseline-subtracted current (pA)")
plt.title(f"{test_file}: baseline-subtracted sweeps and average")
plt.legend()
plt.show()

# %% [markdown]
# ## Make a reusable plotting function

# %%
def plot_condition_average(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    title=None
):
    """
    Plots individual baseline-subtracted sweeps and their average.
    """

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    plt.figure(figsize=(12, 5))

    for sweep_number, trace in zip(sweeps, corrected_traces):
        plt.plot(time, trace, alpha=0.35, lw=1, label=f"Sweep {sweep_number}")

    plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

    plt.axvspan(
        baseline_window[0],
        baseline_window[1],
        color="gray",
        alpha=0.15,
        label="baseline"
    )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    if title is None:
        title = f"{file_name}, sweeps {sweeps}"

    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_condition_average(
    file_name=test_file,
    sweeps=test_sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0)
)

# %% [markdown]
# ## Add interactive viewer

# %%
file_dropdown = widgets.Dropdown(
    options=metadata["file"].tolist(),
    description="File:",
    layout=widgets.Layout(width="400px")
)

baseline_start_widget = widgets.FloatText(value=0.2, description="Base start")
baseline_end_widget = widgets.FloatText(value=1.0, description="Base end")

stim_start_widget = widgets.FloatText(value=1.2, description="Stim start")
stim_end_widget = widgets.FloatText(value=10.0, description="Stim end")


def interactive_average_plot(file_name, b0, b1, s0, s1):
    row = metadata[metadata["file"] == file_name].iloc[0]
    sweeps = parse_sweeps(row["sweeps"])

    title = (
        f"{file_name} | {row['drug']} | {row['stimulus_type']} | "
        f"center SF={row['center_sf']} | surround SF={row['surround_sf']}"
    )

    plot_condition_average(
        file_name=file_name,
        sweeps=sweeps,
        baseline_window=(b0, b1),
        stim_window=(s0, s1),
        title=title
    )


widgets.interact(
    interactive_average_plot,
    file_name=file_dropdown,
    b0=baseline_start_widget,
    b1=baseline_end_widget,
    s0=stim_start_widget,
    s1=stim_end_widget
);
# Out:
# interactive(children=(Dropdown(description='File:', layout=Layout(width='400px'), options=('2026_05_14_0002.ab…

# %% [markdown]
# ## Define response windows

# %%
baseline_window = (0.2, 1.0)
stim_window = (2, 10.0)
early_window = (2, 3)
late_window = (3, 10.0)

# %% [markdown]
# ## Analyze one trace

# %%
def analyze_trace(
    time,
    trace,
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes a baseline-subtracted trace.

    Because the trace is already baseline-subtracted:
    - baseline is approximately 0
    - inward currents at -70 mV are negative
    """

    stim_mask = (time >= stim_window[0]) & (time <= stim_window[1])
    early_mask = (time >= early_window[0]) & (time <= early_window[1])
    late_mask = (time >= late_window[0]) & (time <= late_window[1])

    stim_current = trace[stim_mask]
    stim_time = time[stim_mask]

    early_current = trace[early_mask]
    late_current = trace[late_mask]

    cleaned_stim = stim_current.copy()
    cleaned_stim[np.abs(cleaned_stim) > artifact_threshold_pA] = np.nan

    peak_inward = np.nanmin(cleaned_stim)
    peak_outward = np.nanmax(cleaned_stim)

    mean_response = np.nanmean(cleaned_stim)
    early_mean_response = np.nanmean(early_current)
    late_mean_response = np.nanmean(late_current)

    charge_transfer = trapezoid(stim_current, stim_time)

    return {
        "peak_inward_pA": peak_inward,
        "peak_outward_pA": peak_outward,
        "mean_response_pA": mean_response,
        "early_mean_response_pA": early_mean_response,
        "late_mean_response_pA": late_mean_response,
        "charge_transfer_pA_s": charge_transfer
    }

# %% [markdown]
# ## Analyze individual sweeps and the averaged trace
# It will produce
# - one row for sweep 0
# - one row for sweep 1
# - one row for sweep 2
# - one row for the average trace

# %%
def analyze_condition_row(
    row,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes all sweeps for one stimulus condition.

    Each metadata row represents one condition/file.
    """

    file_name = row["file"]
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    output_rows = []

    # Analyze individual sweeps
    for sweep_number, trace, baseline in zip(sweeps, corrected_traces, baselines):
        result = analyze_trace(
            time=time,
            trace=trace,
            stim_window=stim_window,
            early_window=early_window,
            late_window=late_window,
            artifact_threshold_pA=artifact_threshold_pA
        )

        output = row.to_dict()
        output.update(result)

        output["analysis_level"] = "individual_sweep"
        output["sweep"] = sweep_number
        output["baseline_mean_pA"] = baseline
        output["n_sweeps_averaged"] = 1

        output_rows.append(output)

    # Analyze averaged trace
    avg_result = analyze_trace(
        time=time,
        trace=average_trace,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=artifact_threshold_pA
    )

    output = row.to_dict()
    output.update(avg_result)

    output["analysis_level"] = "average_trace"
    output["sweep"] = "avg"
    output["baseline_mean_pA"] = np.mean(baselines)
    output["n_sweeps_averaged"] = len(sweeps)

    output_rows.append(output)

    return output_rows

# %% [markdown]
# ## Analyze the whole experiment
# everything is multiplied by -1 because at -70mV, excitatory inward currents are negative. Turning them positive makes graphs easier to interpret: bigger response = higher value

# %%
all_results = []

for _, row in metadata.iterrows():
    condition_results = analyze_condition_row(
        row,
        baseline_window=baseline_window,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=500
    )

    all_results.extend(condition_results)

results = pd.DataFrame(all_results)

results["inward_mean_response_pA"] = -results["mean_response_pA"]
results["inward_peak_response_pA"] = -results["peak_inward_pA"]
results["inward_late_response_pA"] = -results["late_mean_response_pA"]
results["inward_early_response_pA"] = -results["early_mean_response_pA"]
results["inward_charge_pA_s"] = -results["charge_transfer_pA_s"]

results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_14_0002.abf  control             spot        NaN          NaN
# 1   2026_05_14_0002.abf  control             spot        NaN          NaN
# 2   2026_05_14_0006.abf  control  center_surround        1.0          1.0
# 3   2026_05_14_0006.abf  control  center_surround        1.0          1.0
# 4   2026_05_14_0006.abf  control  center_surround        1.0          1.0
# ..                  ...      ...              ...        ...          ...
# 61  2026_05_14_0021.abf  control  center_surround        1.0          1.0
# 62  2026_05_14_0022.abf  control      center_only        1.0        100.0
# 63  2026_05_14_0022.abf  control      center_only        1.0        100.0
# 64  2026_05_14_0022.abf  control      center_only        1.0        100.0
# 65  2026_05_14_0022.abf  control      center_only        1.0        100.0
#
#    sweeps  clamp_mV  stimID                  notes  peak_inward_pA  ...  \
# 0       0       -70       4            200um, WAC?     -261.622681  ...
# 1       0       -70       4            200um, WAC?     -261.622681  ...
# 2   0;1;2       -70       7  center 400um diameter     -175.668365  ...
# 3   0;1;2       -70       7  center 400um diameter     -154.603699  ...
# 4   0;1;2       -70       7  center 400um diameter     -183.583862  ...
# ..    ...       ...     ...                    ...             ...  ...
# 61  0;1;2       -70      21  center 300um diameter     -113.614441  ...
# 62  0;1;2       -70      22  center 300um diameter     -201.455292  ...
# 63  0;1;2       -70      22  center 300um diameter     -197.275879  ...
# 64  0;1;2       -70      22  center 300um diameter     -221.531677  ...
# 65  0;1;2       -70      22  center 300um diameter     -141.446671  ...
#
#     charge_transfer_pA_s    analysis_level  sweep  baseline_mean_pA  \
# 0            -151.947098  individual_sweep      0        -77.732780
# 1            -151.947098     average_trace    avg        -77.732780
# 2            -315.972168  individual_sweep      0        -75.796478
# 3            -180.887482  individual_sweep      1        -87.705864
# 4            -209.775665  individual_sweep      2        -86.801880
# ..                   ...               ...    ...               ...
# 61           -314.005280     average_trace    avg        -70.915184
# 62           -397.746796  individual_sweep      0        -62.826935
# 63           -335.502289  individual_sweep      1        -68.837402
# 64           -296.553406  individual_sweep      2        -70.826714
# 65           -343.267517     average_trace    avg        -67.497017
#
#     n_sweeps_averaged inward_mean_response_pA inward_peak_response_pA  \
# 0                   1               18.995867              261.622681
# 1                   1               18.995867              261.622681
# 2                   1               39.497517              175.668365
# 3                   1               22.611935              154.603699
# 4                   1               26.222527              183.583862
# ..                ...                     ...                     ...
# 61                  3               39.251530              113.614441
# 62                  1               49.719517              201.455292
# 63                  1               41.938564              197.275879
# 64                  1               37.069008              221.531677
# 65                  3               42.909023              141.446671
#
#     inward_late_response_pA  inward_early_response_pA  inward_charge_pA_s
# 0                 18.702721                 21.043333          151.947098
# 1                 18.702721                 21.043333          151.947098
# 2                 38.917984                 43.549896          315.972168
# 3                 22.359026                 24.381285          180.887482
# 4                 26.766495                 22.420235          209.775665
# ..                      ...                       ...                 ...
# 61                38.892143                 41.763401          314.005280
# 62                48.326351                 59.460316          397.746796
# 63                41.291470                 46.458332          335.502289
# 64                36.382431                 41.867893          296.553406
# 65                42.000080                 49.262173          343.267517
#
# [66 rows x 24 columns]

# %% [markdown]
# ## Save Results

# %%
RESULTS_FILE = RESULTS_DIR / "response_summary_c1_26.05.14.csv"

results.to_csv(RESULTS_FILE, index=False)

print("Saved results to:", RESULTS_FILE)
# Out:
# Saved results to: /Volumes/My Passport for Mac/retina_project/results/response_summary_c1_26.05.14.csv

# %% [markdown]
# ## Separate individual sweeps from average traces

# %%
individual_results = results[results["analysis_level"] == "individual_sweep"].copy()
average_results = results[results["analysis_level"] == "average_trace"].copy()

average_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 1   2026_05_14_0002.abf  control             spot        NaN          NaN
# 5   2026_05_14_0006.abf  control  center_surround        1.0          1.0
# 9   2026_05_14_0007.abf  control      center_only        1.0        100.0
# 13  2026_05_14_0008.abf  control      center_only        1.0        100.0
# 17  2026_05_14_0010.abf  control  center_surround        1.0          2.0
# 21  2026_05_14_0011.abf  control      center_only        1.0        100.0
# 25  2026_05_14_0012.abf  control      center_only        1.0        100.0
# 29  2026_05_14_0013.abf  control  center_surround        1.0          1.0
# 33  2026_05_14_0014.abf  control  center_surround        1.0          4.0
# 37  2026_05_14_0015.abf  control      center_only        1.0        100.0
# 41  2026_05_14_0016.abf  control  center_surround        1.0          2.0
# 45  2026_05_14_0017.abf  control  center_surround        1.0          8.0
# 49  2026_05_14_0018.abf  control      center_only        1.0        100.0
# 53  2026_05_14_0019.abf  control  center_surround        1.0          0.5
# 57  2026_05_14_0020.abf  control  center_surround        1.0         16.0
# 61  2026_05_14_0021.abf  control  center_surround        1.0          1.0
# 65  2026_05_14_0022.abf  control      center_only        1.0        100.0
#
#    sweeps  clamp_mV  stimID                  notes  peak_inward_pA  ...  \
# 1       0       -70       4            200um, WAC?     -261.622681  ...
# 5   0;1;2       -70       7  center 400um diameter     -117.574371  ...
# 9   0;1;2       -70       8  center 400um diameter     -153.247375  ...
# 13  0;1;2       -70       9  center 300um diameter     -122.037193  ...
# 17  0;1;2       -70      10  center 300um diameter      -74.916504  ...
# 21  0;1;2       -70      11  center 300um diameter      -86.337456  ...
# 25  0;1;2       -70      12  center 300um diameter     -100.632378  ...
# 29  0;1;2       -70      13  center 300um diameter      -79.869865  ...
# 33  0;1;2       -70      14  center 300um diameter      -93.723885  ...
# 37  0;1;2       -70      15  center 300um diameter     -101.007874  ...
# 41  0;1;2       -70      16  center 300um diameter      -82.480080  ...
# 45  0;1;2       -70      17  center 300um diameter      -88.161957  ...
# 49  0;1;2       -70      18  center 300um diameter      -93.217461  ...
# 53  0;1;2       -70      19  center 300um diameter      -84.117157  ...
# 57  0;1;2       -70      20  center 300um diameter     -143.529922  ...
# 61  0;1;2       -70      21  center 300um diameter     -113.614441  ...
# 65  0;1;2       -70      22  center 300um diameter     -141.446671  ...
#
#     charge_transfer_pA_s  analysis_level  sweep  baseline_mean_pA  \
# 1            -151.947098   average_trace    avg        -77.732780
# 5            -235.545090   average_trace    avg        -83.434746
# 9            -275.507935   average_trace    avg        -82.755234
# 13           -294.599121   average_trace    avg        -65.544189
# 17           -225.088898   average_trace    avg        -66.888512
# 21           -225.328354   average_trace    avg        -53.026154
# 25           -226.646973   average_trace    avg        -50.327911
# 29           -187.262527   average_trace    avg        -55.628178
# 33           -258.492859   average_trace    avg        -62.119213
# 37           -226.838882   average_trace    avg        -61.345638
# 41           -298.930237   average_trace    avg        -51.797256
# 45           -324.834991   average_trace    avg        -53.032703
# 49           -243.138565   average_trace    avg        -52.249664
# 53           -219.081085   average_trace    avg        -53.415394
# 57           -435.102631   average_trace    avg        -69.889671
# 61           -314.005280   average_trace    avg        -70.915184
# 65           -343.267517   average_trace    avg        -67.497017
#
#     n_sweeps_averaged inward_mean_response_pA inward_peak_response_pA  \
# 1                   1               18.995867              261.622681
# 5                   3               29.443993              117.574371
# 9                   3               34.439251              153.247375
# 13                  3               36.825542              122.037193
# 17                  3               28.136942               74.916504
# 21                  3               28.166481               86.337456
# 25                  3               28.331398              100.632378
# 29                  3               23.408382               79.869865
# 33                  3               32.312382               93.723885
# 37                  3               28.355398              101.007874
# 41                  3               37.367283               82.480080
# 45                  3               40.605522               88.161957
# 49                  3               30.392698               93.217461
# 53                  3               27.385262               84.117157
# 57                  3               54.389153              143.529922
# 61                  3               39.251530              113.614441
# 65                  3               42.909023              141.446671
#
#     inward_late_response_pA  inward_early_response_pA  inward_charge_pA_s
# 1                 18.702721                 21.043333          151.947098
# 5                 29.347836                 30.117142          235.545090
# 9                 33.202766                 43.087334          275.507935
# 13                36.229252                 40.992954          294.599121
# 17                27.716719                 31.076706          225.088898
# 21                28.024313                 29.158398          225.328354
# 25                27.869295                 31.559826          226.646973
# 29                23.243021                 24.564278          187.262527
# 33                31.670156                 36.805187          258.492859
# 37                27.571995                 33.833454          226.838882
# 41                36.982883                 40.055744          298.930237
# 45                40.043446                 44.536846          324.834991
# 49                29.867878                 34.060955          243.138565
# 53                27.237093                 28.416719          219.081085
# 57                53.370235                 61.514698          435.102631
# 61                38.892143                 41.763401          314.005280
# 65                42.000080                 49.262173          343.267517
#
# [17 rows x 24 columns]

# %% [markdown]
# ### For final tuning curves use: average results
# ### For checking variability use: individual_results

# %% [markdown]
# ## Plot center-only spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_only"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="center_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Center spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center-only spatial frequency tuning")
plt.show()

# %% [markdown]
# ## Plot center+surround spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_surround"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="surround_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Surround spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center+surround response vs surround spatial frequency")
plt.show()

# %% [markdown]
# ## Plot control vs TTX at one condition

# %%
df = average_results[
    (average_results["stimulus_type"] == "center_surround") &
    (average_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.barplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar=None
)

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center_Surround SF 1: control vs TTX")
plt.show()

# %% [markdown]
# ## Show individual sweep variability

# %%
df = individual_results[
    (individual_results["stimulus_type"] == "center_surround") &
    (individual_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8,
    jitter=True
)

sns.pointplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar="se",
    color="red",
    markers="D"
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Individual sweeps: center_surround SF 1")
plt.show()

# %% [markdown]
# ## Overlay control and TTX average traces

# %%
def get_average_trace_for_row(row, baseline_window=(0.2, 1.0)):

    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        row["file"],
        sweeps,
        baseline_window=baseline_window
    )

    return time, average_trace


def overlay_average_traces(
    metadata,
    stimulus_type,
    center_sf=None,
    surround_sf=None,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0),
    exclude_files=None
):

    df = metadata[metadata["stimulus_type"] == stimulus_type].copy()

    if center_sf is not None:
        df = df[df["center_sf"] == center_sf]

    if surround_sf is not None:
        df = df[df["surround_sf"] == surround_sf]

    # ---------- EXCLUDE FILES ----------
    if exclude_files is not None:
        df = df[~df["file"].isin(exclude_files)]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():

        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['drug']} | {row['file']}"

        plt.plot(
            time,
            average_trace,
            lw=2,
            label=label
        )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    plt.title(
        f"{stimulus_type}, center SF={center_sf}, surround SF={surround_sf}"
    )

    plt.legend()
    plt.show()

# %%
overlay_average_traces(
    metadata,
    stimulus_type="center_surround",
    center_sf=1,
    surround_sf=4,
    baseline_window=baseline_window,
    stim_window=stim_window,

   # exclude_files=[
    
   # ]
)

# %%
def overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=1,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    exclude_files=None
):

    df = metadata[
        (metadata["drug"] == drug) &
        (
            (
                (metadata["stimulus_type"] == "center_only") &
                (metadata["center_sf"] == center_sf)
            )
            |
            (
                (metadata["stimulus_type"] == "center_surround") &
                (metadata["center_sf"] == center_sf) &
                (metadata["surround_sf"] == surround_sf)
            )
        )
    ].copy()

    # ---------- EXCLUDE FILES ----------
    if exclude_files is not None:
        df = df[~df["file"].isin(exclude_files)]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():

        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['stimulus_type']} | {row['file']}"

        plt.plot(
            time,
            average_trace,
            lw=2,
            label=label
        )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    plt.title(
        f"{drug}: center_only vs center_surround | "
        f"center SF={center_sf}, surround SF={surround_sf}"
    )

    plt.legend()
    plt.show()

# %%
overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=4,
    baseline_window=baseline_window,
    stim_window=stim_window,

    # exclude_files=[
    #     "2026_05_12_0046.abf",
    #     "2026_05_12_0049.abf"
    # ]
)

# %% [markdown]
# ## Calculate surround modulation index

# %% [markdown]
# SMI = (Rc+s - Rc) / (Rc+s + Rc)

# %%
def calculate_smi(average_results, response_column="inward_mean_response_pA"):
    """
    Calculates surround modulation index for center+surround rows.

    This assumes matching center_only rows exist for the same:
    - drug
    - center_sf
    """

    center_only = average_results[
        average_results["stimulus_type"] == "center_only"
    ].copy()

    center_surround = average_results[
        average_results["stimulus_type"] == "center_surround"
    ].copy()

    smi_rows = []

    for _, cs_row in center_surround.iterrows():
        matching_center = center_only[
            (center_only["drug"] == cs_row["drug"]) &
            (center_only["center_sf"] == cs_row["center_sf"])
        ]

        if len(matching_center) == 0:
            continue

        r_center = matching_center.iloc[0][response_column]
        r_cs = cs_row[response_column]

        smi = (r_cs - r_center) / (r_cs + r_center)

        output = cs_row.to_dict()
        output["R_center"] = r_center
        output["R_center_surround"] = r_cs
        output["SMI"] = smi

        smi_rows.append(output)

    return pd.DataFrame(smi_rows)

# %%
smi_results = calculate_smi(
    average_results,
    response_column="inward_mean_response_pA"
)

smi_results
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_14_0006.abf  control  center_surround        1.0          1.0
# 1  2026_05_14_0010.abf  control  center_surround        1.0          2.0
# 2  2026_05_14_0013.abf  control  center_surround        1.0          1.0
# 3  2026_05_14_0014.abf  control  center_surround        1.0          4.0
# 4  2026_05_14_0016.abf  control  center_surround        1.0          2.0
# 5  2026_05_14_0017.abf  control  center_surround        1.0          8.0
# 6  2026_05_14_0019.abf  control  center_surround        1.0          0.5
# 7  2026_05_14_0020.abf  control  center_surround        1.0         16.0
# 8  2026_05_14_0021.abf  control  center_surround        1.0          1.0
#
#   sweeps  clamp_mV  stimID                  notes  peak_inward_pA  ...  \
# 0  0;1;2       -70       7  center 400um diameter     -117.574371  ...
# 1  0;1;2       -70      10  center 300um diameter      -74.916504  ...
# 2  0;1;2       -70      13  center 300um diameter      -79.869865  ...
# 3  0;1;2       -70      14  center 300um diameter      -93.723885  ...
# 4  0;1;2       -70      16  center 300um diameter      -82.480080  ...
# 5  0;1;2       -70      17  center 300um diameter      -88.161957  ...
# 6  0;1;2       -70      19  center 300um diameter      -84.117157  ...
# 7  0;1;2       -70      20  center 300um diameter     -143.529922  ...
# 8  0;1;2       -70      21  center 300um diameter     -113.614441  ...
#
#    baseline_mean_pA  n_sweeps_averaged  inward_mean_response_pA  \
# 0        -83.434746                  3                29.443993
# 1        -66.888512                  3                28.136942
# 2        -55.628178                  3                23.408382
# 3        -62.119213                  3                32.312382
# 4        -51.797256                  3                37.367283
# 5        -53.032703                  3                40.605522
# 6        -53.415394                  3                27.385262
# 7        -69.889671                  3                54.389153
# 8        -70.915184                  3                39.251530
#
#    inward_peak_response_pA  inward_late_response_pA inward_early_response_pA  \
# 0               117.574371                29.347836                30.117142
# 1                74.916504                27.716719                31.076706
# 2                79.869865                23.243021                24.564278
# 3                93.723885                31.670156                36.805187
# 4                82.480080                36.982883                40.055744
# 5                88.161957                40.043446                44.536846
# 6                84.117157                27.237093                28.416719
# 7               143.529922                53.370235                61.514698
# 8               113.614441                38.892143                41.763401
#
#   inward_charge_pA_s   R_center  R_center_surround       SMI
# 0         235.545090  34.439251          29.443993 -0.078194
# 1         225.088898  34.439251          28.136942 -0.100714
# 2         187.262527  34.439251          23.408382 -0.190688
# 3         258.492859  34.439251          32.312382 -0.031862
# 4         298.930237  34.439251          37.367283  0.040777
# 5         324.834991  34.439251          40.605522  0.082168
# 6         219.081085  34.439251          27.385262 -0.114097
# 7         435.102631  34.439251          54.389153  0.224589
# 8         314.005280  34.439251          39.251530  0.065304
#
# [9 rows x 27 columns]

# %%
plt.figure(figsize=(8, 5))

sns.lineplot(
    data=smi_results,
    x="surround_sf",
    y="SMI",
    hue="drug",
    marker="o"
)

plt.axhline(0, color="black", lw=1)
plt.xlabel("Surround spatial frequency")
plt.ylabel("Surround modulation index")
plt.title("Surround modulation vs spatial frequency")
plt.show()

# %% [markdown]
# ## SAVE FIGURES

# %% [markdown]
# any plot can be saved by adding this code before plt.show()

# %%
#plt.savefig(FIG_DIR / "my_figure_name.png", dpi=300, bbox_inches="tight")

# %%
##Checking the averaged trace
row = average_results.iloc[2]
row
# Out:
# file                          2026_05_14_0007.abf
# drug                                      control
# stimulus_type                         center_only
# center_sf                                     1.0
# surround_sf                                 100.0
# sweeps                                      0;1;2
# clamp_mV                                      -70
# stimID                                          8
# notes                       center 400um diameter
# peak_inward_pA                        -153.247375
# peak_outward_pA                         11.750999
# mean_response_pA                       -34.439251
# early_mean_response_pA                 -43.087334
# late_mean_response_pA                  -33.202766
# charge_transfer_pA_s                  -275.507935
# analysis_level                      average_trace
# sweep                                         avg
# baseline_mean_pA                       -82.755234
# n_sweeps_averaged                               3
# inward_mean_response_pA                 34.439251
# inward_peak_response_pA                153.247375
# inward_late_response_pA                 33.202766
# inward_early_response_pA                43.087334
# inward_charge_pA_s                     275.507935
# Name: 9, dtype: object
