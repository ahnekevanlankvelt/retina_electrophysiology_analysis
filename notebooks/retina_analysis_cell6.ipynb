# %% [markdown]
# ## Import Packages

# %%
from pathlib import Path

import pyabf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.integrate import trapezoid

import ipywidgets as widgets
from IPython.display import display

sns.set_context("talk")
sns.set_style("whitegrid")

# %% [markdown]
# ## Set folder paths

# %%
PROJECT = Path("/Volumes/My Passport for Mac/retina_project")

DATA_DIR = PROJECT / "data"
META_DIR = PROJECT / "metadata"
NOTEBOOK_DIR = PROJECT / "notebooks"
RESULTS_DIR = PROJECT / "results"
FIG_DIR = RESULTS_DIR / "figures"

META_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)
FIG_DIR.mkdir(exist_ok=True)

print("Project folder:", PROJECT)
print("Data folder:", DATA_DIR)
print("Metadata folder:", META_DIR)
print("Results folder:", RESULTS_DIR)
# Out:
# Project folder: /Volumes/My Passport for Mac/retina_project
# Data folder: /Volumes/My Passport for Mac/retina_project/data
# Metadata folder: /Volumes/My Passport for Mac/retina_project/metadata
# Results folder: /Volumes/My Passport for Mac/retina_project/results

# %% [markdown]
# ## Create metadata table

# %%
META_FILE = META_DIR / "experiment_cell6_metadata.csv"

metadata = pd.DataFrame([
    {
        "file": "2026_05_12_0031.abf",
        "drug": "control",
        "stimulus_type": "spot",
        "center_sf": np.nan,
        "surround_sf": np.nan,
        "sweeps": "0",
        "clamp_mV": -70,
        "stimID": 34,
        "notes": "ON OFF transient?"
    },
    {
        "file": "2026_05_12_0032.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0",
        "clamp_mV": -70,
        "stimID": 35,
        "notes": "center contrast 25 surround 50"
    },
    {
        "file": "2026_05_12_0033.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 36,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0034.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 8,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 37,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0035.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 38,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0036.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 39,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0037.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 40,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0038.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 4,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 41,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0039.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 32,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 42,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0040.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 0.5,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 43,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0041.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 44,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0042.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 45,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0043.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 46,
        "notes": "center contrast 25 surround contrast 50, right before ttx"
    },
    {
        "file": "2026_05_12_0044.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 47,
        "notes": "center contrast 25 surround contrast 50, as ttx is being added"
    },
    {
        "file": "2026_05_12_0045.abf",
        "drug": "ttx",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 48,
        "notes": "center contrast 25 surround contrast 50, 1st rec after ttx"
    },
    {
        "file": "2026_05_12_0046.abf",
        "drug": "ttx",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 49,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0047.abf",
        "drug": "ttx",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 0.5,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 50,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0048.abf",
        "drug": "ttx",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 51,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0049.abf",
        "drug": "ttx",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 52,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0050.abf",
        "drug": "ttx",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 53,
        "notes": "center contrast 25 surround contrast 50"
    }#,
    # {
    #     "file": "2026_05_12_0051.abf",
    #     "drug": "ttx",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 8,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 54,
    #     "notes": "center contrast 25 surround contrast 50"
    # },
    # {
    #     "file": "2026_05_12_0052.abf",
    #     "drug": "ttx",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 55,
    #     "notes": "center contrast 25 surround contrast 50, responses not looking great anymore"
    # },
    # {
    #     "file": "2026_05_12_0053.abf",
    #     "drug": "ttx",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 56,
    #     "notes": "center contrast 25 surround contrast 50, resp not great"
    # },
    # {
    #     "file": "2026_05_12_0054.abf",
    #     "drug": "ttx",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 4,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 57,
    #     "notes": "center contrast 25 surround contrast 50, resp not great"
    # },
    # {
    #     "file": "2026_05_12_0055.abf",
    #     "drug": "ttx",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 2,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 58,
    #     "notes": "center contrast 25 surround contrast 50, resp not great"
    # }
    
])

metadata.to_csv(META_FILE, index=False)
metadata
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_12_0031.abf  control             spot        NaN          NaN
# 1   2026_05_12_0032.abf  control      center_only        1.0        100.0
# 2   2026_05_12_0033.abf  control  center_surround        1.0          1.0
# 3   2026_05_12_0034.abf  control  center_surround        1.0          8.0
# 4   2026_05_12_0035.abf  control  center_surround        1.0         16.0
# 5   2026_05_12_0036.abf  control      center_only        1.0        100.0
# 6   2026_05_12_0037.abf  control  center_surround        1.0          2.0
# 7   2026_05_12_0038.abf  control  center_surround        1.0          4.0
# 8   2026_05_12_0039.abf  control  center_surround        1.0         32.0
# 9   2026_05_12_0040.abf  control  center_surround        1.0          0.5
# 10  2026_05_12_0041.abf  control      center_only        1.0        100.0
# 11  2026_05_12_0042.abf  control      center_only        1.0        100.0
# 12  2026_05_12_0043.abf  control      center_only        1.0        100.0
# 13  2026_05_12_0044.abf  control      center_only        1.0        100.0
# 14  2026_05_12_0045.abf      ttx      center_only        1.0        100.0
# 15  2026_05_12_0046.abf      ttx      center_only        1.0        100.0
# 16  2026_05_12_0047.abf      ttx  center_surround        1.0          0.5
# 17  2026_05_12_0048.abf      ttx  center_surround        1.0         16.0
# 18  2026_05_12_0049.abf      ttx      center_only        1.0        100.0
# 19  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
#
#    sweeps  clamp_mV  stimID                                              notes
# 0       0       -70      34                                  ON OFF transient?
# 1       0       -70      35                     center contrast 25 surround 50
# 2   0;1;2       -70      36            center contrast 25 surround contrast 50
# 3   0;1;2       -70      37            center contrast 25 surround contrast 50
# 4   0;1;2       -70      38            center contrast 25 surround contrast 50
# 5   0;1;2       -70      39            center contrast 25 surround contrast 50
# 6   0;1;2       -70      40            center contrast 25 surround contrast 50
# 7   0;1;2       -70      41            center contrast 25 surround contrast 50
# 8   0;1;2       -70      42            center contrast 25 surround contrast 50
# 9   0;1;2       -70      43            center contrast 25 surround contrast 50
# 10  0;1;2       -70      44            center contrast 25 surround contrast 50
# 11  0;1;2       -70      45            center contrast 25 surround contrast 50
# 12  0;1;2       -70      46  center contrast 25 surround contrast 50, right...
# 13  0;1;2       -70      47  center contrast 25 surround contrast 50, as tt...
# 14  0;1;2       -70      48  center contrast 25 surround contrast 50, 1st r...
# 15  0;1;2       -70      49            center contrast 25 surround contrast 50
# 16  0;1;2       -70      50            center contrast 25 surround contrast 50
# 17  0;1;2       -70      51            center contrast 25 surround contrast 50
# 18  0;1;2       -70      52            center contrast 25 surround contrast 50
# 19  0;1;2       -70      53            center contrast 25 surround contrast 50

# %% [markdown]
# ## Load Metadata

# %%
META_FILE = META_DIR / "experiment_cell6_metadata.csv"

metadata = pd.read_csv(META_FILE)

metadata
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_12_0031.abf  control             spot        NaN          NaN
# 1   2026_05_12_0032.abf  control      center_only        1.0        100.0
# 2   2026_05_12_0033.abf  control  center_surround        1.0          1.0
# 3   2026_05_12_0034.abf  control  center_surround        1.0          8.0
# 4   2026_05_12_0035.abf  control  center_surround        1.0         16.0
# 5   2026_05_12_0036.abf  control      center_only        1.0        100.0
# 6   2026_05_12_0037.abf  control  center_surround        1.0          2.0
# 7   2026_05_12_0038.abf  control  center_surround        1.0          4.0
# 8   2026_05_12_0039.abf  control  center_surround        1.0         32.0
# 9   2026_05_12_0040.abf  control  center_surround        1.0          0.5
# 10  2026_05_12_0041.abf  control      center_only        1.0        100.0
# 11  2026_05_12_0042.abf  control      center_only        1.0        100.0
# 12  2026_05_12_0043.abf  control      center_only        1.0        100.0
# 13  2026_05_12_0044.abf  control      center_only        1.0        100.0
# 14  2026_05_12_0045.abf      ttx      center_only        1.0        100.0
# 15  2026_05_12_0046.abf      ttx      center_only        1.0        100.0
# 16  2026_05_12_0047.abf      ttx  center_surround        1.0          0.5
# 17  2026_05_12_0048.abf      ttx  center_surround        1.0         16.0
# 18  2026_05_12_0049.abf      ttx      center_only        1.0        100.0
# 19  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
#
#    sweeps  clamp_mV  stimID                                              notes
# 0       0       -70      34                                  ON OFF transient?
# 1       0       -70      35                     center contrast 25 surround 50
# 2   0;1;2       -70      36            center contrast 25 surround contrast 50
# 3   0;1;2       -70      37            center contrast 25 surround contrast 50
# 4   0;1;2       -70      38            center contrast 25 surround contrast 50
# 5   0;1;2       -70      39            center contrast 25 surround contrast 50
# 6   0;1;2       -70      40            center contrast 25 surround contrast 50
# 7   0;1;2       -70      41            center contrast 25 surround contrast 50
# 8   0;1;2       -70      42            center contrast 25 surround contrast 50
# 9   0;1;2       -70      43            center contrast 25 surround contrast 50
# 10  0;1;2       -70      44            center contrast 25 surround contrast 50
# 11  0;1;2       -70      45            center contrast 25 surround contrast 50
# 12  0;1;2       -70      46  center contrast 25 surround contrast 50, right...
# 13  0;1;2       -70      47  center contrast 25 surround contrast 50, as tt...
# 14  0;1;2       -70      48  center contrast 25 surround contrast 50, 1st r...
# 15  0;1;2       -70      49            center contrast 25 surround contrast 50
# 16  0;1;2       -70      50            center contrast 25 surround contrast 50
# 17  0;1;2       -70      51            center contrast 25 surround contrast 50
# 18  0;1;2       -70      52            center contrast 25 surround contrast 50
# 19  0;1;2       -70      53            center contrast 25 surround contrast 50

# %% [markdown]
# ## Define helper functions to load ABF files

# %%
def parse_sweeps(sweep_string):
    """
    Converts a sweep string like '0;1;2' into a list: [0, 1, 2].
    """
    return [int(s.strip()) for s in str(sweep_string).split(";")]


def load_sweeps(file_name, sweeps):
    """
    Loads multiple sweeps from one ABF file.

    Parameters
    ----------
    file_name : str
        Name of the ABF file.
    sweeps : list
        List of sweep numbers, for example [0, 1, 2].

    Returns
    -------
    time : array
        Time values in seconds.
    traces : array
        Shape is number of sweeps x number of timepoints.
    """

    file_path = DATA_DIR / file_name

    if not file_path.exists():
        raise FileNotFoundError(f"Could not find file: {file_path}")

    abf = pyabf.ABF(str(file_path))

    traces = []
    time = None

    for sweep in sweeps:
        abf.setSweep(int(sweep))

        if time is None:
            time = abf.sweepX

        traces.append(abf.sweepY)

    traces = np.array(traces)

    return time, traces

# %% [markdown]
# ## load and plot one file's three sweeps

# %%
test_file = metadata.loc[1, "file"]
test_sweeps = parse_sweeps(metadata.loc[1, "sweeps"])

time, traces = load_sweeps(test_file, test_sweeps)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, traces):
    plt.plot(time, trace, alpha=0.7, label=f"Sweep {sweep_number}")

plt.xlabel("Time (s)")
plt.ylabel("Current (pA)")
plt.title(test_file)
plt.legend()
plt.show()

# %% [markdown]
# ## Baseline-subtract each sweep

# %%
def baseline_subtract_traces(time, traces, baseline_window=(0.2, 1.0)):
    """
    Baseline-subtracts each sweep independently.

    Parameters
    ----------
    time : array
        Time values.
    traces : array
        Shape is number of sweeps x number of timepoints.
    baseline_window : tuple
        Start and end of baseline window in seconds.

    Returns
    -------
    corrected_traces : array
        Baseline-subtracted traces.
    baselines : array
        Baseline mean for each sweep.
    """

    baseline_mask = (time >= baseline_window[0]) & (time <= baseline_window[1])

    corrected_traces = []
    baselines = []

    for trace in traces:
        baseline = np.mean(trace[baseline_mask])
        baselines.append(baseline)
        corrected_traces.append(trace - baseline)

    corrected_traces = np.array(corrected_traces)
    baselines = np.array(baselines)

    return corrected_traces, baselines

# %%
baseline_window = (0.2, 1.0)

corrected_traces, baselines = baseline_subtract_traces(
    time,
    traces,
    baseline_window=baseline_window
)

print("Baseline values for each sweep:", baselines)
# Out:
# Baseline values for each sweep: [-49.0954]

# %% [markdown]
# ## Average the baseline-subtracted sweeps

# %%
def average_baseline_corrected_sweeps(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0)
):
    """
    Loads sweeps, baseline-subtracts each sweep, then averages them.
    """

    time, traces = load_sweeps(file_name, sweeps)

    corrected_traces, baselines = baseline_subtract_traces(
        time,
        traces,
        baseline_window=baseline_window
    )

    average_trace = np.mean(corrected_traces, axis=0)

    return time, corrected_traces, average_trace, baselines

# %%
time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
    test_file,
    test_sweeps,
    baseline_window=(0.2, 1.0)
)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, corrected_traces):
    plt.plot(time, trace, alpha=0.35, label=f"Sweep {sweep_number}")

plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

plt.axhline(0, color="black", lw=1)
plt.xlabel("Time (s)")
plt.ylabel("Baseline-subtracted current (pA)")
plt.title(f"{test_file}: baseline-subtracted sweeps and average")
plt.legend()
plt.show()

# %% [markdown]
# ## Make a reusable plotting function

# %%
def plot_condition_average(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    title=None
):
    """
    Plots individual baseline-subtracted sweeps and their average.
    """

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    plt.figure(figsize=(12, 5))

    for sweep_number, trace in zip(sweeps, corrected_traces):
        plt.plot(time, trace, alpha=0.35, lw=1, label=f"Sweep {sweep_number}")

    plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

    plt.axvspan(
        baseline_window[0],
        baseline_window[1],
        color="gray",
        alpha=0.15,
        label="baseline"
    )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    if title is None:
        title = f"{file_name}, sweeps {sweeps}"

    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_condition_average(
    file_name=test_file,
    sweeps=test_sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0)
)

# %% [markdown]
# ## Add interactive viewer

# %%
file_dropdown = widgets.Dropdown(
    options=metadata["file"].tolist(),
    description="File:",
    layout=widgets.Layout(width="400px")
)

baseline_start_widget = widgets.FloatText(value=0.2, description="Base start")
baseline_end_widget = widgets.FloatText(value=1.0, description="Base end")

stim_start_widget = widgets.FloatText(value=1.2, description="Stim start")
stim_end_widget = widgets.FloatText(value=10.0, description="Stim end")


def interactive_average_plot(file_name, b0, b1, s0, s1):
    row = metadata[metadata["file"] == file_name].iloc[0]
    sweeps = parse_sweeps(row["sweeps"])

    title = (
        f"{file_name} | {row['drug']} | {row['stimulus_type']} | "
        f"center SF={row['center_sf']} | surround SF={row['surround_sf']}"
    )

    plot_condition_average(
        file_name=file_name,
        sweeps=sweeps,
        baseline_window=(b0, b1),
        stim_window=(s0, s1),
        title=title
    )


widgets.interact(
    interactive_average_plot,
    file_name=file_dropdown,
    b0=baseline_start_widget,
    b1=baseline_end_widget,
    s0=stim_start_widget,
    s1=stim_end_widget
);
# Out:
# interactive(children=(Dropdown(description='File:', layout=Layout(width='400px'), options=('2026_05_12_0031.ab…

# %% [markdown]
# ## Define response windows

# %%
baseline_window = (0.2, 1.0)
stim_window = (2, 10.0)
early_window = (2, 3)
late_window = (3, 10.0)

# %% [markdown]
# ## Analyze one trace

# %%
def analyze_trace(
    time,
    trace,
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes a baseline-subtracted trace.

    Because the trace is already baseline-subtracted:
    - baseline is approximately 0
    - inward currents at -70 mV are negative
    """

    stim_mask = (time >= stim_window[0]) & (time <= stim_window[1])
    early_mask = (time >= early_window[0]) & (time <= early_window[1])
    late_mask = (time >= late_window[0]) & (time <= late_window[1])

    stim_current = trace[stim_mask]
    stim_time = time[stim_mask]

    early_current = trace[early_mask]
    late_current = trace[late_mask]

    cleaned_stim = stim_current.copy()
    cleaned_stim[np.abs(cleaned_stim) > artifact_threshold_pA] = np.nan

    peak_inward = np.nanmin(cleaned_stim)
    peak_outward = np.nanmax(cleaned_stim)

    mean_response = np.nanmean(cleaned_stim)
    early_mean_response = np.nanmean(early_current)
    late_mean_response = np.nanmean(late_current)

    charge_transfer = trapezoid(stim_current, stim_time)

    return {
        "peak_inward_pA": peak_inward,
        "peak_outward_pA": peak_outward,
        "mean_response_pA": mean_response,
        "early_mean_response_pA": early_mean_response,
        "late_mean_response_pA": late_mean_response,
        "charge_transfer_pA_s": charge_transfer
    }

# %% [markdown]
# ## Analyze individual sweeps and the averaged trace
# It will produce
# - one row for sweep 0
# - one row for sweep 1
# - one row for sweep 2
# - one row for the average trace

# %%
def analyze_condition_row(
    row,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes all sweeps for one stimulus condition.

    Each metadata row represents one condition/file.
    """

    file_name = row["file"]
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    output_rows = []

    # Analyze individual sweeps
    for sweep_number, trace, baseline in zip(sweeps, corrected_traces, baselines):
        result = analyze_trace(
            time=time,
            trace=trace,
            stim_window=stim_window,
            early_window=early_window,
            late_window=late_window,
            artifact_threshold_pA=artifact_threshold_pA
        )

        output = row.to_dict()
        output.update(result)

        output["analysis_level"] = "individual_sweep"
        output["sweep"] = sweep_number
        output["baseline_mean_pA"] = baseline
        output["n_sweeps_averaged"] = 1

        output_rows.append(output)

    # Analyze averaged trace
    avg_result = analyze_trace(
        time=time,
        trace=average_trace,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=artifact_threshold_pA
    )

    output = row.to_dict()
    output.update(avg_result)

    output["analysis_level"] = "average_trace"
    output["sweep"] = "avg"
    output["baseline_mean_pA"] = np.mean(baselines)
    output["n_sweeps_averaged"] = len(sweeps)

    output_rows.append(output)

    return output_rows

# %% [markdown]
# ## Analyze the whole experiment
# everything is multiplied by -1 because at -70mV, excitatory inward currents are negative. Turning them positive makes graphs easier to interpret: bigger response = higher value

# %%
all_results = []

for _, row in metadata.iterrows():
    condition_results = analyze_condition_row(
        row,
        baseline_window=baseline_window,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=500
    )

    all_results.extend(condition_results)

results = pd.DataFrame(all_results)

results["inward_mean_response_pA"] = -results["mean_response_pA"]
results["inward_peak_response_pA"] = -results["peak_inward_pA"]
results["inward_late_response_pA"] = -results["late_mean_response_pA"]
results["inward_early_response_pA"] = -results["early_mean_response_pA"]
results["inward_charge_pA_s"] = -results["charge_transfer_pA_s"]

results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_12_0031.abf  control             spot        NaN          NaN
# 1   2026_05_12_0031.abf  control             spot        NaN          NaN
# 2   2026_05_12_0032.abf  control      center_only        1.0        100.0
# 3   2026_05_12_0032.abf  control      center_only        1.0        100.0
# 4   2026_05_12_0033.abf  control  center_surround        1.0          1.0
# ..                  ...      ...              ...        ...          ...
# 71  2026_05_12_0049.abf      ttx      center_only        1.0        100.0
# 72  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
# 73  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
# 74  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
# 75  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
#
#    sweeps  clamp_mV  stimID                                    notes  \
# 0       0       -70      34                        ON OFF transient?
# 1       0       -70      34                        ON OFF transient?
# 2       0       -70      35           center contrast 25 surround 50
# 3       0       -70      35           center contrast 25 surround 50
# 4   0;1;2       -70      36  center contrast 25 surround contrast 50
# ..    ...       ...     ...                                      ...
# 71  0;1;2       -70      52  center contrast 25 surround contrast 50
# 72  0;1;2       -70      53  center contrast 25 surround contrast 50
# 73  0;1;2       -70      53  center contrast 25 surround contrast 50
# 74  0;1;2       -70      53  center contrast 25 surround contrast 50
# 75  0;1;2       -70      53  center contrast 25 surround contrast 50
#
#     peak_inward_pA  ...  charge_transfer_pA_s    analysis_level  sweep  \
# 0      -477.196899  ...             32.535004  individual_sweep      0
# 1      -477.196899  ...             32.535004     average_trace    avg
# 2      -485.572510  ...           -415.705872  individual_sweep      0
# 3      -485.572510  ...           -415.705872     average_trace    avg
# 4      -464.904663  ...           -105.810013  individual_sweep      0
# ..             ...  ...                   ...               ...    ...
# 71      -70.735191  ...           -105.933731     average_trace    avg
# 72     -110.738861  ...            -73.323929  individual_sweep      0
# 73     -192.099243  ...            -49.864101  individual_sweep      1
# 74      -60.625965  ...            -52.860535  individual_sweep      2
# 75      -66.629951  ...            -58.682854     average_trace    avg
#
#     baseline_mean_pA  n_sweeps_averaged inward_mean_response_pA  \
# 0         -50.146839                  1               -4.104778
# 1         -50.146839                  1               -4.104778
# 2         -49.095448                  1               51.878101
# 3         -49.095448                  1               51.878101
# 4         -45.959602                  1               13.105757
# ..               ...                ...                     ...
# 71        -34.245281                  3               13.241717
# 72        -35.745514                  1                9.165623
# 73        -36.782597                  1                6.233056
# 74        -36.419933                  1                6.607620
# 75        -36.316013                  3                7.335433
#
#    inward_peak_response_pA  inward_late_response_pA  inward_early_response_pA  \
# 0               477.196899                -9.873508                 36.565491
# 1               477.196899                -9.873508                 36.565491
# 2               485.572510                48.182404                 78.406853
# 3               485.572510                48.182404                 78.406853
# 4               464.904663                13.798852                  9.217340
# ..                     ...                      ...                       ...
# 71               70.735191                12.675672                 17.200243
# 72              110.738861                 8.838444                 11.453226
# 73              192.099243                 6.456452                  4.667155
# 74               60.625965                 6.483247                  7.476715
# 75               66.629951                 7.259381                  7.865699
#
#     inward_charge_pA_s
# 0           -32.535004
# 1           -32.535004
# 2           415.705872
# 3           415.705872
# 4           105.810013
# ..                 ...
# 71          105.933731
# 72           73.323929
# 73           49.864101
# 74           52.860535
# 75           58.682854
#
# [76 rows x 24 columns]

# %% [markdown]
# ## Save Results

# %%
RESULTS_FILE = RESULTS_DIR / "response_summary_cell6.csv"

results.to_csv(RESULTS_FILE, index=False)

print("Saved results to:", RESULTS_FILE)
# Out:
# Saved results to: /Volumes/My Passport for Mac/retina_project/results/response_summary_cell6.csv

# %% [markdown]
# ## Separate individual sweeps from average traces

# %%
individual_results = results[results["analysis_level"] == "individual_sweep"].copy()
average_results = results[results["analysis_level"] == "average_trace"].copy()

average_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 1   2026_05_12_0031.abf  control             spot        NaN          NaN
# 3   2026_05_12_0032.abf  control      center_only        1.0        100.0
# 7   2026_05_12_0033.abf  control  center_surround        1.0          1.0
# 11  2026_05_12_0034.abf  control  center_surround        1.0          8.0
# 15  2026_05_12_0035.abf  control  center_surround        1.0         16.0
# 19  2026_05_12_0036.abf  control      center_only        1.0        100.0
# 23  2026_05_12_0037.abf  control  center_surround        1.0          2.0
# 27  2026_05_12_0038.abf  control  center_surround        1.0          4.0
# 31  2026_05_12_0039.abf  control  center_surround        1.0         32.0
# 35  2026_05_12_0040.abf  control  center_surround        1.0          0.5
# 39  2026_05_12_0041.abf  control      center_only        1.0        100.0
# 43  2026_05_12_0042.abf  control      center_only        1.0        100.0
# 47  2026_05_12_0043.abf  control      center_only        1.0        100.0
# 51  2026_05_12_0044.abf  control      center_only        1.0        100.0
# 55  2026_05_12_0045.abf      ttx      center_only        1.0        100.0
# 59  2026_05_12_0046.abf      ttx      center_only        1.0        100.0
# 63  2026_05_12_0047.abf      ttx  center_surround        1.0          0.5
# 67  2026_05_12_0048.abf      ttx  center_surround        1.0         16.0
# 71  2026_05_12_0049.abf      ttx      center_only        1.0        100.0
# 75  2026_05_12_0050.abf      ttx  center_surround        1.0          1.0
#
#    sweeps  clamp_mV  stimID  \
# 1       0       -70      34
# 3       0       -70      35
# 7   0;1;2       -70      36
# 11  0;1;2       -70      37
# 15  0;1;2       -70      38
# 19  0;1;2       -70      39
# 23  0;1;2       -70      40
# 27  0;1;2       -70      41
# 31  0;1;2       -70      42
# 35  0;1;2       -70      43
# 39  0;1;2       -70      44
# 43  0;1;2       -70      45
# 47  0;1;2       -70      46
# 51  0;1;2       -70      47
# 55  0;1;2       -70      48
# 59  0;1;2       -70      49
# 63  0;1;2       -70      50
# 67  0;1;2       -70      51
# 71  0;1;2       -70      52
# 75  0;1;2       -70      53
#
#                                                 notes  peak_inward_pA  ...  \
# 1                                   ON OFF transient?     -477.196899  ...
# 3                      center contrast 25 surround 50     -485.572510  ...
# 7             center contrast 25 surround contrast 50     -358.008087  ...
# 11            center contrast 25 surround contrast 50     -383.153107  ...
# 15            center contrast 25 surround contrast 50     -222.942810  ...
# 19            center contrast 25 surround contrast 50     -272.948730  ...
# 23            center contrast 25 surround contrast 50     -112.113892  ...
# 27            center contrast 25 surround contrast 50     -130.369263  ...
# 31            center contrast 25 surround contrast 50     -181.588760  ...
# 35            center contrast 25 surround contrast 50      -72.606926  ...
# 39            center contrast 25 surround contrast 50     -250.898987  ...
# 43            center contrast 25 surround contrast 50     -173.719421  ...
# 47  center contrast 25 surround contrast 50, right...     -136.744873  ...
# 51  center contrast 25 surround contrast 50, as tt...     -109.842438  ...
# 55  center contrast 25 surround contrast 50, 1st r...     -150.948135  ...
# 59            center contrast 25 surround contrast 50      -99.481392  ...
# 63            center contrast 25 surround contrast 50      -88.396233  ...
# 67            center contrast 25 surround contrast 50      -83.721703  ...
# 71            center contrast 25 surround contrast 50      -70.735191  ...
# 75            center contrast 25 surround contrast 50      -66.629951  ...
#
#     charge_transfer_pA_s  analysis_level  sweep  baseline_mean_pA  \
# 1              32.535004   average_trace    avg        -50.146839
# 3            -415.705872   average_trace    avg        -49.095448
# 7            -116.793564   average_trace    avg        -45.230846
# 11           -185.569458   average_trace    avg        -41.041199
# 15           -260.012817   average_trace    avg        -39.508362
# 19           -287.757263   average_trace    avg        -39.754715
# 23           -138.102707   average_trace    avg        -40.270554
# 27           -159.588501   average_trace    avg        -40.122272
# 31           -248.743195   average_trace    avg        -39.561939
# 35           -109.519379   average_trace    avg        -42.546078
# 39           -319.904419   average_trace    avg        -39.628361
# 43           -318.588501   average_trace    avg        -26.679346
# 47           -246.776703   average_trace    avg        -28.050049
# 51           -276.160156   average_trace    avg        -26.265963
# 55           -247.028244   average_trace    avg        -31.546968
# 59           -184.262848   average_trace    avg        -34.592499
# 63            -82.270088   average_trace    avg        -35.301685
# 67           -118.297440   average_trace    avg        -35.296856
# 71           -105.933731   average_trace    avg        -34.245281
# 75            -58.682854   average_trace    avg        -36.316013
#
#     n_sweeps_averaged inward_mean_response_pA inward_peak_response_pA  \
# 1                   1               -4.104778              477.196899
# 3                   1               51.878101              485.572510
# 7                   3               14.599350              358.008087
# 11                  3               23.196198              383.153107
# 15                  3               32.501659              222.942810
# 19                  3               35.969868              272.948730
# 23                  3               17.262901              112.113892
# 27                  3               19.948610              130.369263
# 31                  3               31.093016              181.588760
# 35                  3               13.689969               72.606926
# 39                  3               39.988186              250.898987
# 43                  3               39.823750              173.719421
# 47                  3               30.847235              136.744873
# 51                  3               34.520355              109.842438
# 55                  3               30.878719              150.948135
# 59                  3               23.032961               99.481392
# 63                  3               10.283727               88.396233
# 67                  3               14.787248               83.721703
# 71                  3               13.241717               70.735191
# 75                  3                7.335433               66.629951
#
#     inward_late_response_pA  inward_early_response_pA  inward_charge_pA_s
# 1                 -9.873508                 36.565491          -32.535004
# 3                 48.182404                 78.406853          415.705872
# 7                 14.136003                 17.839325          116.793564
# 11                22.349716                 29.115314          185.569458
# 15                30.801821                 44.390034          260.012817
# 19                33.449108                 53.602985          287.757263
# 23                16.513626                 22.502195          138.102707
# 27                19.542971                 22.781567          159.588501
# 31                28.899969                 46.433250          248.743195
# 35                12.986389                 18.610409          109.519379
# 39                37.151257                 59.831997          319.904419
# 43                37.200344                 58.176197          318.588501
# 47                28.644228                 46.258560          246.776703
# 51                33.069290                 44.670486          276.160156
# 55                29.194956                 42.656227          247.028244
# 59                21.755964                 31.964451          184.262848
# 63                 9.776186                 13.833777           82.270088
# 67                14.257503                 18.492037          118.297440
# 71                12.675672                 17.200243          105.933731
# 75                 7.259381                  7.865699           58.682854
#
# [20 rows x 24 columns]

# %% [markdown]
# ### For final tuning curves use: average results
# ### For checking variability use: individual_results

# %% [markdown]
# ## Plot center-only spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_only"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="center_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Center spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center-only spatial frequency tuning")
plt.show()

# %% [markdown]
# ## Plot center+surround spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_surround"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="surround_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Surround spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center+surround response vs surround spatial frequency")
plt.show()

# %% [markdown]
# ## Plot control vs TTX at one condition

# %%
df = average_results[
    (average_results["stimulus_type"] == "center_surround") &
    (average_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.barplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar=None
)

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center_Surround SF 1: control vs TTX")
plt.show()

# %% [markdown]
# ## Show individual sweep variability

# %%
df = individual_results[
    (individual_results["stimulus_type"] == "center_surround") &
    (individual_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8,
    jitter=True
)

sns.pointplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar="se",
    color="red",
    markers="D"
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Individual sweeps: center_surround SF 1")
plt.show()

# %% [markdown]
# ## Overlay control and TTX average traces

# %%
def get_average_trace_for_row(row, baseline_window=(0.2, 1.0)):
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        row["file"],
        sweeps,
        baseline_window=baseline_window
    )

    return time, average_trace


def overlay_average_traces(
    metadata,
    stimulus_type,
    center_sf=None,
    surround_sf=None,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0)
):
    df = metadata[metadata["stimulus_type"] == stimulus_type].copy()

    if center_sf is not None:
        df = df[df["center_sf"] == center_sf]

    if surround_sf is not None:
        df = df[df["surround_sf"] == surround_sf]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['drug']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(f"{stimulus_type}, center SF={center_sf}, surround SF={surround_sf}")
    plt.legend()
    plt.show()

# %%
overlay_average_traces(
    metadata,
    stimulus_type="center_surround",
    center_sf=1,
    surround_sf=16,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %%
def overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=1,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    exclude_files=None
):

    df = metadata[
        (metadata["drug"] == drug) &
        (
            (
                (metadata["stimulus_type"] == "center_only") &
                (metadata["center_sf"] == center_sf)
            )
            |
            (
                (metadata["stimulus_type"] == "center_surround") &
                (metadata["center_sf"] == center_sf) &
                (metadata["surround_sf"] == surround_sf)
            )
        )
    ].copy()

    # ---------- EXCLUDE FILES ----------
    if exclude_files is not None:
        df = df[~df["file"].isin(exclude_files)]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():

        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['stimulus_type']} | {row['file']}"

        plt.plot(
            time,
            average_trace,
            lw=2,
            label=label
        )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    plt.title(
        f"{drug}: center_only vs center_surround | "
        f"center SF={center_sf}, surround SF={surround_sf}"
    )

    plt.legend()
    plt.show()

# %%
overlay_center_vs_center_surround(
    metadata,
    drug="ttx",
    center_sf=1,
    surround_sf=0.5,
    baseline_window=baseline_window,
    stim_window=stim_window,

    exclude_files=[
        "2026_05_12_0046.abf",
        "2026_05_12_0049.abf"
    ]
)

# %% [markdown]
# ## Calculate surround modulation index

# %% [markdown]
# SMI = (Rc+s - Rc) / (Rc+s + Rc)

# %%
def calculate_smi(average_results, response_column="inward_mean_response_pA"):
    """
    Calculates surround modulation index for center+surround rows.

    This assumes matching center_only rows exist for the same:
    - drug
    - center_sf
    """

    center_only = average_results[
        average_results["stimulus_type"] == "center_only"
    ].copy()

    center_surround = average_results[
        average_results["stimulus_type"] == "center_surround"
    ].copy()

    smi_rows = []

    for _, cs_row in center_surround.iterrows():
        matching_center = center_only[
            (center_only["drug"] == cs_row["drug"]) &
            (center_only["center_sf"] == cs_row["center_sf"])
        ]

        if len(matching_center) == 0:
            continue

        r_center = matching_center.iloc[0][response_column]
        r_cs = cs_row[response_column]

        smi = (r_cs - r_center) / (r_cs + r_center)

        output = cs_row.to_dict()
        output["R_center"] = r_center
        output["R_center_surround"] = r_cs
        output["SMI"] = smi

        smi_rows.append(output)

    return pd.DataFrame(smi_rows)

# %%
smi_results = calculate_smi(
    average_results,
    response_column="inward_mean_response_pA"
)

smi_results

# %%
plt.figure(figsize=(8, 5))

sns.lineplot(
    data=smi_results,
    x="surround_sf",
    y="SMI",
    hue="drug",
    marker="o"
)

plt.axhline(0, color="black", lw=1)
plt.xlabel("Surround spatial frequency")
plt.ylabel("Surround modulation index")
plt.title("Surround modulation vs spatial frequency")
plt.show()

# %% [markdown]
# ## SAVE FIGURES

# %% [markdown]
# any plot can be saved by adding this code before plt.show()

# %%
#plt.savefig(FIG_DIR / "my_figure_name.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Things to double check
#
# 1. Are the stimulus windows correct?
# 2. Are the baseline windows quiet?
# 3. Do the three sweeps look similar?
# 4. Are inward currents plotted as positive?
# 5. Are control and TTX labels entered consistently?
# 6. Are spatial frequencies numeric?

# %%
##Checking the averaged trace
row = average_results.iloc[1]
row
