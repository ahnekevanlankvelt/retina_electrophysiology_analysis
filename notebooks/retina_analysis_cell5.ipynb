# %% [markdown]
# ## Import Packages

# %%
from pathlib import Path

import pyabf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.integrate import trapezoid

import ipywidgets as widgets
from IPython.display import display

sns.set_context("talk")
sns.set_style("whitegrid")

# %% [markdown]
# ## Set folder paths

# %%
PROJECT = Path("/Volumes/My Passport for Mac/retina_project")

DATA_DIR = PROJECT / "data"
META_DIR = PROJECT / "metadata"
NOTEBOOK_DIR = PROJECT / "notebooks"
RESULTS_DIR = PROJECT / "results"
FIG_DIR = RESULTS_DIR / "figures"

META_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)
FIG_DIR.mkdir(exist_ok=True)

print("Project folder:", PROJECT)
print("Data folder:", DATA_DIR)
print("Metadata folder:", META_DIR)
print("Results folder:", RESULTS_DIR)
# Out:
# Project folder: /Volumes/My Passport for Mac/retina_project
# Data folder: /Volumes/My Passport for Mac/retina_project/data
# Metadata folder: /Volumes/My Passport for Mac/retina_project/metadata
# Results folder: /Volumes/My Passport for Mac/retina_project/results

# %% [markdown]
# ## Create metadata table

# %%
META_FILE = META_DIR / "experiment_cell5_metadata.csv"

metadata = pd.DataFrame([
    {
        "file": "2026_05_12_0013.abf",
        "drug": "control",
        "stimulus_type": "spot",
        "center_sf": np.nan,
        "surround_sf": np.nan,
        "sweeps": "0",
        "clamp_mV": -70,
        "stimID": 17,
        "notes": "ON sustained"
    },
    {
        "file": "2026_05_12_0014.abf",
        "drug": "control",
        "stimulus_type": "spot",
        "center_sf": np.nan,
        "surround_sf": np.nan,
        "sweeps": "0",
        "clamp_mV": -70,
        "stimID": 18,
        "notes": "ON sustained?"
    },
    # {
    #     "file": "2026_05_12_0015.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 19,
    #     "notes": "center contrast 40 surround contrast 50"
    # },
    # {
    #     "file": "2026_05_12_0016.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 1,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 20,
    #     "notes": "center contrast 40 surround contrast 50"
    # },
    # {
    #     "file": "2026_05_12_0017.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 8,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 21,
    #     "notes": "center contrast 40 surround contrast 50"
    # },
    {
        "file": "2026_05_12_0021.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 24,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0022.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 1,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 25,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0023.abf",
        "drug": "control",
        "stimulus_type": "center_only",
        "center_sf": 1,
        "surround_sf": 100,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 26,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0024.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 8,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 27,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0025.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 16,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 28,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0026.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 0.5,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 29,
        "notes": "center contrast 25 surround contrast 50"
    },
    {
        "file": "2026_05_12_0027.abf",
        "drug": "control",
        "stimulus_type": "center_surround",
        "center_sf": 1,
        "surround_sf": 2,
        "sweeps": "0;1;2",
        "clamp_mV": -70,
        "stimID": 30,
        "notes": "center contrast 25 surround contrast 50"
     }
    # {
    #     "file": "2026_05_12_0028.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_surround",
    #     "center_sf": 1,
    #     "surround_sf": 32,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 31,
    #     "notes": "center contrast 25 surround contrast 50, cell started to run down on last sweep"
    # },
    # {
    #     "file": "2026_05_12_0029.abf",
    #     "drug": "control",
    #     "stimulus_type": "center_only",
    #     "center_sf": 1,
    #     "surround_sf": 100,
    #     "sweeps": "0;1;2",
    #     "clamp_mV": -70,
    #     "stimID": 32,
    #     "notes": "center contrast 25 surround contrast 50, cell ran down"
    # }
    
])

metadata.to_csv(META_FILE, index=False)
metadata
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_12_0013.abf  control             spot        NaN          NaN
# 1  2026_05_12_0014.abf  control             spot        NaN          NaN
# 2  2026_05_12_0021.abf  control      center_only        1.0        100.0
# 3  2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 4  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 5  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 6  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 7  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 8  2026_05_12_0027.abf  control  center_surround        1.0          2.0
#
#   sweeps  clamp_mV  stimID                                    notes
# 0      0       -70      17                             ON sustained
# 1      0       -70      18                            ON sustained?
# 2  0;1;2       -70      24  center contrast 25 surround contrast 50
# 3  0;1;2       -70      25  center contrast 25 surround contrast 50
# 4  0;1;2       -70      26  center contrast 25 surround contrast 50
# 5  0;1;2       -70      27  center contrast 25 surround contrast 50
# 6  0;1;2       -70      28  center contrast 25 surround contrast 50
# 7  0;1;2       -70      29  center contrast 25 surround contrast 50
# 8  0;1;2       -70      30  center contrast 25 surround contrast 50

# %% [markdown]
# ## Load Metadata

# %%
META_FILE = META_DIR / "experiment_cell5_metadata.csv"

metadata = pd.read_csv(META_FILE)

metadata
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_12_0013.abf  control             spot        NaN          NaN
# 1  2026_05_12_0014.abf  control             spot        NaN          NaN
# 2  2026_05_12_0021.abf  control      center_only        1.0        100.0
# 3  2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 4  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 5  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 6  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 7  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 8  2026_05_12_0027.abf  control  center_surround        1.0          2.0
#
#   sweeps  clamp_mV  stimID                                    notes
# 0      0       -70      17                             ON sustained
# 1      0       -70      18                            ON sustained?
# 2  0;1;2       -70      24  center contrast 25 surround contrast 50
# 3  0;1;2       -70      25  center contrast 25 surround contrast 50
# 4  0;1;2       -70      26  center contrast 25 surround contrast 50
# 5  0;1;2       -70      27  center contrast 25 surround contrast 50
# 6  0;1;2       -70      28  center contrast 25 surround contrast 50
# 7  0;1;2       -70      29  center contrast 25 surround contrast 50
# 8  0;1;2       -70      30  center contrast 25 surround contrast 50

# %% [markdown]
# ## Define helper functions to load ABF files

# %%
def parse_sweeps(sweep_string):
    """
    Converts a sweep string like '0;1;2' into a list: [0, 1, 2].
    """
    return [int(s.strip()) for s in str(sweep_string).split(";")]


def load_sweeps(file_name, sweeps):
    """
    Loads multiple sweeps from one ABF file.

    Parameters
    ----------
    file_name : str
        Name of the ABF file.
    sweeps : list
        List of sweep numbers, for example [0, 1, 2].

    Returns
    -------
    time : array
        Time values in seconds.
    traces : array
        Shape is number of sweeps x number of timepoints.
    """

    file_path = DATA_DIR / file_name

    if not file_path.exists():
        raise FileNotFoundError(f"Could not find file: {file_path}")

    abf = pyabf.ABF(str(file_path))

    traces = []
    time = None

    for sweep in sweeps:
        abf.setSweep(int(sweep))

        if time is None:
            time = abf.sweepX

        traces.append(abf.sweepY)

    traces = np.array(traces)

    return time, traces

# %% [markdown]
# ## load and plot one file's three sweeps

# %%
test_file = metadata.loc[1, "file"]
test_sweeps = parse_sweeps(metadata.loc[1, "sweeps"])

time, traces = load_sweeps(test_file, test_sweeps)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, traces):
    plt.plot(time, trace, alpha=0.7, label=f"Sweep {sweep_number}")

plt.xlabel("Time (s)")
plt.ylabel("Current (pA)")
plt.title(test_file)
plt.legend()
plt.show()

# %% [markdown]
# ## Baseline-subtract each sweep

# %%
def baseline_subtract_traces(time, traces, baseline_window=(0.2, 1.0)):
    """
    Baseline-subtracts each sweep independently.

    Parameters
    ----------
    time : array
        Time values.
    traces : array
        Shape is number of sweeps x number of timepoints.
    baseline_window : tuple
        Start and end of baseline window in seconds.

    Returns
    -------
    corrected_traces : array
        Baseline-subtracted traces.
    baselines : array
        Baseline mean for each sweep.
    """

    baseline_mask = (time >= baseline_window[0]) & (time <= baseline_window[1])

    corrected_traces = []
    baselines = []

    for trace in traces:
        baseline = np.mean(trace[baseline_mask])
        baselines.append(baseline)
        corrected_traces.append(trace - baseline)

    corrected_traces = np.array(corrected_traces)
    baselines = np.array(baselines)

    return corrected_traces, baselines

# %%
baseline_window = (0.2, 1.0)

corrected_traces, baselines = baseline_subtract_traces(
    time,
    traces,
    baseline_window=baseline_window
)

print("Baseline values for each sweep:", baselines)
# Out:
# Baseline values for each sweep: [-61.5469]

# %% [markdown]
# ## Average the baseline-subtracted sweeps

# %%
def average_baseline_corrected_sweeps(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0)
):
    """
    Loads sweeps, baseline-subtracts each sweep, then averages them.
    """

    time, traces = load_sweeps(file_name, sweeps)

    corrected_traces, baselines = baseline_subtract_traces(
        time,
        traces,
        baseline_window=baseline_window
    )

    average_trace = np.mean(corrected_traces, axis=0)

    return time, corrected_traces, average_trace, baselines

# %%
time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
    test_file,
    test_sweeps,
    baseline_window=(0.2, 1.0)
)

plt.figure(figsize=(12, 5))

for sweep_number, trace in zip(test_sweeps, corrected_traces):
    plt.plot(time, trace, alpha=0.35, label=f"Sweep {sweep_number}")

plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

plt.axhline(0, color="black", lw=1)
plt.xlabel("Time (s)")
plt.ylabel("Baseline-subtracted current (pA)")
plt.title(f"{test_file}: baseline-subtracted sweeps and average")
plt.legend()
plt.show()

# %% [markdown]
# ## Make a reusable plotting function

# %%
def plot_condition_average(
    file_name,
    sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    title=None
):
    """
    Plots individual baseline-subtracted sweeps and their average.
    """

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    plt.figure(figsize=(12, 5))

    for sweep_number, trace in zip(sweeps, corrected_traces):
        plt.plot(time, trace, alpha=0.35, lw=1, label=f"Sweep {sweep_number}")

    plt.plot(time, average_trace, color="black", lw=2.5, label="Average")

    plt.axvspan(
        baseline_window[0],
        baseline_window[1],
        color="gray",
        alpha=0.15,
        label="baseline"
    )

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")

    if title is None:
        title = f"{file_name}, sweeps {sweeps}"

    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_condition_average(
    file_name=test_file,
    sweeps=test_sweeps,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0)
)

# %% [markdown]
# ## Add interactive viewer

# %%
file_dropdown = widgets.Dropdown(
    options=metadata["file"].tolist(),
    description="File:",
    layout=widgets.Layout(width="400px")
)

baseline_start_widget = widgets.FloatText(value=0.2, description="Base start")
baseline_end_widget = widgets.FloatText(value=1.0, description="Base end")

stim_start_widget = widgets.FloatText(value=1.2, description="Stim start")
stim_end_widget = widgets.FloatText(value=10.0, description="Stim end")


def interactive_average_plot(file_name, b0, b1, s0, s1):
    row = metadata[metadata["file"] == file_name].iloc[0]
    sweeps = parse_sweeps(row["sweeps"])

    title = (
        f"{file_name} | {row['drug']} | {row['stimulus_type']} | "
        f"center SF={row['center_sf']} | surround SF={row['surround_sf']}"
    )

    plot_condition_average(
        file_name=file_name,
        sweeps=sweeps,
        baseline_window=(b0, b1),
        stim_window=(s0, s1),
        title=title
    )


widgets.interact(
    interactive_average_plot,
    file_name=file_dropdown,
    b0=baseline_start_widget,
    b1=baseline_end_widget,
    s0=stim_start_widget,
    s1=stim_end_widget
);
# Out:
# interactive(children=(Dropdown(description='File:', layout=Layout(width='400px'), options=('2026_05_12_0013.ab…

# %% [markdown]
# ## Define response windows

# %%
baseline_window = (0.2, 1.0)
stim_window = (2, 10.0)
early_window = (2, 3)
late_window = (3, 10.0)

# %% [markdown]
# ## Analyze one trace

# %%
def analyze_trace(
    time,
    trace,
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes a baseline-subtracted trace.

    Because the trace is already baseline-subtracted:
    - baseline is approximately 0
    - inward currents at -70 mV are negative
    """

    stim_mask = (time >= stim_window[0]) & (time <= stim_window[1])
    early_mask = (time >= early_window[0]) & (time <= early_window[1])
    late_mask = (time >= late_window[0]) & (time <= late_window[1])

    stim_current = trace[stim_mask]
    stim_time = time[stim_mask]

    early_current = trace[early_mask]
    late_current = trace[late_mask]

    cleaned_stim = stim_current.copy()
    cleaned_stim[np.abs(cleaned_stim) > artifact_threshold_pA] = np.nan

    peak_inward = np.nanmin(cleaned_stim)
    peak_outward = np.nanmax(cleaned_stim)

    mean_response = np.nanmean(cleaned_stim)
    early_mean_response = np.nanmean(early_current)
    late_mean_response = np.nanmean(late_current)

    charge_transfer = trapezoid(stim_current, stim_time)

    return {
        "peak_inward_pA": peak_inward,
        "peak_outward_pA": peak_outward,
        "mean_response_pA": mean_response,
        "early_mean_response_pA": early_mean_response,
        "late_mean_response_pA": late_mean_response,
        "charge_transfer_pA_s": charge_transfer
    }

# %% [markdown]
# ## Analyze individual sweeps and the averaged trace
# It will produce
# - one row for sweep 0
# - one row for sweep 1
# - one row for sweep 2
# - one row for the average trace

# %%
def analyze_condition_row(
    row,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0),
    early_window=(2, 3),
    late_window=(3, 10.0),
    artifact_threshold_pA=500
):
    """
    Analyzes all sweeps for one stimulus condition.

    Each metadata row represents one condition/file.
    """

    file_name = row["file"]
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        file_name,
        sweeps,
        baseline_window=baseline_window
    )

    output_rows = []

    # Analyze individual sweeps
    for sweep_number, trace, baseline in zip(sweeps, corrected_traces, baselines):
        result = analyze_trace(
            time=time,
            trace=trace,
            stim_window=stim_window,
            early_window=early_window,
            late_window=late_window,
            artifact_threshold_pA=artifact_threshold_pA
        )

        output = row.to_dict()
        output.update(result)

        output["analysis_level"] = "individual_sweep"
        output["sweep"] = sweep_number
        output["baseline_mean_pA"] = baseline
        output["n_sweeps_averaged"] = 1

        output_rows.append(output)

    # Analyze averaged trace
    avg_result = analyze_trace(
        time=time,
        trace=average_trace,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=artifact_threshold_pA
    )

    output = row.to_dict()
    output.update(avg_result)

    output["analysis_level"] = "average_trace"
    output["sweep"] = "avg"
    output["baseline_mean_pA"] = np.mean(baselines)
    output["n_sweeps_averaged"] = len(sweeps)

    output_rows.append(output)

    return output_rows

# %% [markdown]
# ## Analyze the whole experiment
# everything is multiplied by -1 because at -70mV, excitatory inward currents are negative. Turning them positive makes graphs easier to interpret: bigger response = higher value

# %%
all_results = []

for _, row in metadata.iterrows():
    condition_results = analyze_condition_row(
        row,
        baseline_window=baseline_window,
        stim_window=stim_window,
        early_window=early_window,
        late_window=late_window,
        artifact_threshold_pA=500
    )

    all_results.extend(condition_results)

results = pd.DataFrame(all_results)

results["inward_mean_response_pA"] = -results["mean_response_pA"]
results["inward_peak_response_pA"] = -results["peak_inward_pA"]
results["inward_late_response_pA"] = -results["late_mean_response_pA"]
results["inward_early_response_pA"] = -results["early_mean_response_pA"]
results["inward_charge_pA_s"] = -results["charge_transfer_pA_s"]

results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 0   2026_05_12_0013.abf  control             spot        NaN          NaN
# 1   2026_05_12_0013.abf  control             spot        NaN          NaN
# 2   2026_05_12_0014.abf  control             spot        NaN          NaN
# 3   2026_05_12_0014.abf  control             spot        NaN          NaN
# 4   2026_05_12_0021.abf  control      center_only        1.0        100.0
# 5   2026_05_12_0021.abf  control      center_only        1.0        100.0
# 6   2026_05_12_0021.abf  control      center_only        1.0        100.0
# 7   2026_05_12_0021.abf  control      center_only        1.0        100.0
# 8   2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 9   2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 10  2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 11  2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 12  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 13  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 14  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 15  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 16  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 17  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 18  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 19  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 20  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 21  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 22  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 23  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 24  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 25  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 26  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 27  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 28  2026_05_12_0027.abf  control  center_surround        1.0          2.0
# 29  2026_05_12_0027.abf  control  center_surround        1.0          2.0
# 30  2026_05_12_0027.abf  control  center_surround        1.0          2.0
# 31  2026_05_12_0027.abf  control  center_surround        1.0          2.0
#
#    sweeps  clamp_mV  stimID                                    notes  \
# 0       0       -70      17                             ON sustained
# 1       0       -70      17                             ON sustained
# 2       0       -70      18                            ON sustained?
# 3       0       -70      18                            ON sustained?
# 4   0;1;2       -70      24  center contrast 25 surround contrast 50
# 5   0;1;2       -70      24  center contrast 25 surround contrast 50
# 6   0;1;2       -70      24  center contrast 25 surround contrast 50
# 7   0;1;2       -70      24  center contrast 25 surround contrast 50
# 8   0;1;2       -70      25  center contrast 25 surround contrast 50
# 9   0;1;2       -70      25  center contrast 25 surround contrast 50
# 10  0;1;2       -70      25  center contrast 25 surround contrast 50
# 11  0;1;2       -70      25  center contrast 25 surround contrast 50
# 12  0;1;2       -70      26  center contrast 25 surround contrast 50
# 13  0;1;2       -70      26  center contrast 25 surround contrast 50
# 14  0;1;2       -70      26  center contrast 25 surround contrast 50
# 15  0;1;2       -70      26  center contrast 25 surround contrast 50
# 16  0;1;2       -70      27  center contrast 25 surround contrast 50
# 17  0;1;2       -70      27  center contrast 25 surround contrast 50
# 18  0;1;2       -70      27  center contrast 25 surround contrast 50
# 19  0;1;2       -70      27  center contrast 25 surround contrast 50
# 20  0;1;2       -70      28  center contrast 25 surround contrast 50
# 21  0;1;2       -70      28  center contrast 25 surround contrast 50
# 22  0;1;2       -70      28  center contrast 25 surround contrast 50
# 23  0;1;2       -70      28  center contrast 25 surround contrast 50
# 24  0;1;2       -70      29  center contrast 25 surround contrast 50
# 25  0;1;2       -70      29  center contrast 25 surround contrast 50
# 26  0;1;2       -70      29  center contrast 25 surround contrast 50
# 27  0;1;2       -70      29  center contrast 25 surround contrast 50
# 28  0;1;2       -70      30  center contrast 25 surround contrast 50
# 29  0;1;2       -70      30  center contrast 25 surround contrast 50
# 30  0;1;2       -70      30  center contrast 25 surround contrast 50
# 31  0;1;2       -70      30  center contrast 25 surround contrast 50
#
#     peak_inward_pA  ...  charge_transfer_pA_s    analysis_level  sweep  \
# 0      -278.018097  ...           -225.773941  individual_sweep      0
# 1      -278.018097  ...           -225.773941     average_trace    avg
# 2      -213.721619  ...            -81.596169  individual_sweep      0
# 3      -213.721619  ...            -81.596169     average_trace    avg
# 4      -383.319641  ...           -998.897217  individual_sweep      0
# 5      -359.251678  ...           -801.146484  individual_sweep      1
# 6      -346.860657  ...           -784.237854  individual_sweep      2
# 7      -297.429474  ...           -861.427124     average_trace    avg
# 8      -267.315125  ...           -342.556610  individual_sweep      0
# 9      -301.753540  ...           -324.500854  individual_sweep      1
# 10     -234.221130  ...           -337.829651  individual_sweep      2
# 11     -179.465744  ...           -334.962402     average_trace    avg
# 12     -349.444275  ...           -819.310852  individual_sweep      0
# 13     -379.481171  ...           -735.395081  individual_sweep      1
# 14     -310.148193  ...           -706.096924  individual_sweep      2
# 15     -293.867645  ...           -753.600952     average_trace    avg
# 16     -302.936096  ...           -467.262146  individual_sweep      0
# 17     -316.323975  ...           -430.627472  individual_sweep      1
# 18     -304.738373  ...           -451.607117  individual_sweep      2
# 19     -266.292145  ...           -449.832214     average_trace    avg
# 20     -317.257141  ...           -682.976074  individual_sweep      0
# 21     -310.344788  ...           -601.183105  individual_sweep      1
# 22     -275.362000  ...           -598.152588  individual_sweep      2
# 23     -251.346054  ...           -627.437256     average_trace    avg
# 24     -243.785583  ...           -276.251801  individual_sweep      0
# 25     -239.125854  ...           -247.309723  individual_sweep      1
# 26     -244.666702  ...           -267.610596  individual_sweep      2
# 27     -127.779945  ...           -263.724030     average_trace    avg
# 28     -244.873199  ...           -370.359955  individual_sweep      0
# 29     -297.212219  ...           -344.030457  individual_sweep      1
# 30     -267.685394  ...           -366.918274  individual_sweep      2
# 31     -178.574326  ...           -360.436249     average_trace    avg
#
#     baseline_mean_pA  n_sweeps_averaged inward_mean_response_pA  \
# 0         -57.675266                  1               28.224926
# 1         -57.675266                  1               28.224926
# 2         -61.546928                  1               10.202319
# 3         -61.546928                  1               10.202319
# 4         -70.781906                  1              124.863159
# 5         -72.266884                  1              100.144363
# 6         -71.230179                  1               98.030640
# 7         -71.426323                  3              107.679390
# 8         -68.378250                  1               42.819870
# 9         -66.898804                  1               40.562817
# 10        -66.682198                  1               42.228897
# 11        -67.319756                  3               41.870533
# 12        -66.205124                  1              102.414635
# 13        -70.958282                  1               91.925049
# 14        -70.711166                  1               88.262924
# 15        -69.291527                  3               94.200867
# 16        -67.547287                  1               58.408104
# 17        -65.756088                  1               53.828720
# 18        -64.524315                  1               56.451294
# 19        -65.942566                  3               56.229370
# 20        -64.212570                  1               85.372765
# 21        -65.631767                  1               75.148537
# 22        -66.434891                  1               74.769737
# 23        -65.426407                  3               78.430351
# 24        -65.052299                  1               34.531845
# 25        -65.439568                  1               30.914133
# 26        -66.002243                  1               33.451530
# 27        -65.498039                  3               32.965836
# 28        -67.016449                  1               46.295086
# 29        -73.271172                  1               43.004093
# 30        -67.397606                  1               45.864975
# 31        -69.228416                  3               45.054718
#
#    inward_peak_response_pA  inward_late_response_pA  inward_early_response_pA  \
# 0               278.018097                19.671928                 88.084633
# 1               278.018097                19.671928                 88.084633
# 2               213.721619                 1.633875                 70.171707
# 3               213.721619                 1.633875                 70.171707
# 4               383.319641               122.790627                139.346390
# 5               359.251678                97.323341                119.871368
# 6               346.860657                98.857925                 92.222450
# 7               297.429474               106.323967                117.146729
# 8               267.315125                41.539330                 51.772072
# 9               301.753540                40.910408                 38.121326
# 10              234.221130                41.632622                 46.394394
# 11              179.465744                41.360786                 45.429264
# 12              349.444275               102.577324                101.257141
# 13              379.481171                91.396904                 95.607140
# 14              310.148193                86.431206                101.067635
# 15              293.867645                93.468475                 99.310631
# 16              302.936096                58.164204                 60.103752
# 17              316.323975                54.518307                 48.991833
# 18              304.738373                56.322987                 57.338829
# 19              266.292145                56.335167                 55.478138
# 20              317.257141                85.153084                 86.894669
# 21              310.344788                74.287468                 81.160896
# 22              275.362000                74.501236                 76.636337
# 23              251.346054                77.980591                 81.563965
# 24              243.785583                35.617760                 26.926964
# 25              239.125854                30.614706                 33.004448
# 26              244.666702                33.237190                 34.944050
# 27              127.779945                33.156555                 31.625153
# 28              244.873199                45.621750                 50.996803
# 29              297.212219                41.306747                 54.876419
# 30              267.685394                45.787407                 46.397648
# 31              178.574326                44.238632                 50.756958
#
#     inward_charge_pA_s
# 0           225.773941
# 1           225.773941
# 2            81.596169
# 3            81.596169
# 4           998.897217
# 5           801.146484
# 6           784.237854
# 7           861.427124
# 8           342.556610
# 9           324.500854
# 10          337.829651
# 11          334.962402
# 12          819.310852
# 13          735.395081
# 14          706.096924
# 15          753.600952
# 16          467.262146
# 17          430.627472
# 18          451.607117
# 19          449.832214
# 20          682.976074
# 21          601.183105
# 22          598.152588
# 23          627.437256
# 24          276.251801
# 25          247.309723
# 26          267.610596
# 27          263.724030
# 28          370.359955
# 29          344.030457
# 30          366.918274
# 31          360.436249
#
# [32 rows x 24 columns]

# %% [markdown]
# ## Save Results

# %%
RESULTS_FILE = RESULTS_DIR / "response_summary_cell5.csv"

results.to_csv(RESULTS_FILE, index=False)

print("Saved results to:", RESULTS_FILE)
# Out:
# Saved results to: /Volumes/My Passport for Mac/retina_project/results/response_summary_cell5.csv

# %% [markdown]
# ## Separate individual sweeps from average traces

# %%
individual_results = results[results["analysis_level"] == "individual_sweep"].copy()
average_results = results[results["analysis_level"] == "average_trace"].copy()

average_results
# Out:
#                    file     drug    stimulus_type  center_sf  surround_sf  \
# 1   2026_05_12_0013.abf  control             spot        NaN          NaN
# 3   2026_05_12_0014.abf  control             spot        NaN          NaN
# 7   2026_05_12_0021.abf  control      center_only        1.0        100.0
# 11  2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 15  2026_05_12_0023.abf  control      center_only        1.0        100.0
# 19  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 23  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 27  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 31  2026_05_12_0027.abf  control  center_surround        1.0          2.0
#
#    sweeps  clamp_mV  stimID                                    notes  \
# 1       0       -70      17                             ON sustained
# 3       0       -70      18                            ON sustained?
# 7   0;1;2       -70      24  center contrast 25 surround contrast 50
# 11  0;1;2       -70      25  center contrast 25 surround contrast 50
# 15  0;1;2       -70      26  center contrast 25 surround contrast 50
# 19  0;1;2       -70      27  center contrast 25 surround contrast 50
# 23  0;1;2       -70      28  center contrast 25 surround contrast 50
# 27  0;1;2       -70      29  center contrast 25 surround contrast 50
# 31  0;1;2       -70      30  center contrast 25 surround contrast 50
#
#     peak_inward_pA  ...  charge_transfer_pA_s  analysis_level  sweep  \
# 1      -278.018097  ...           -225.773941   average_trace    avg
# 3      -213.721619  ...            -81.596169   average_trace    avg
# 7      -297.429474  ...           -861.427124   average_trace    avg
# 11     -179.465744  ...           -334.962402   average_trace    avg
# 15     -293.867645  ...           -753.600952   average_trace    avg
# 19     -266.292145  ...           -449.832214   average_trace    avg
# 23     -251.346054  ...           -627.437256   average_trace    avg
# 27     -127.779945  ...           -263.724030   average_trace    avg
# 31     -178.574326  ...           -360.436249   average_trace    avg
#
#     baseline_mean_pA  n_sweeps_averaged inward_mean_response_pA  \
# 1         -57.675266                  1               28.224926
# 3         -61.546928                  1               10.202319
# 7         -71.426323                  3              107.679390
# 11        -67.319756                  3               41.870533
# 15        -69.291527                  3               94.200867
# 19        -65.942566                  3               56.229370
# 23        -65.426407                  3               78.430351
# 27        -65.498039                  3               32.965836
# 31        -69.228416                  3               45.054718
#
#    inward_peak_response_pA  inward_late_response_pA  inward_early_response_pA  \
# 1               278.018097                19.671928                 88.084633
# 3               213.721619                 1.633875                 70.171707
# 7               297.429474               106.323967                117.146729
# 11              179.465744                41.360786                 45.429264
# 15              293.867645                93.468475                 99.310631
# 19              266.292145                56.335167                 55.478138
# 23              251.346054                77.980591                 81.563965
# 27              127.779945                33.156555                 31.625153
# 31              178.574326                44.238632                 50.756958
#
#     inward_charge_pA_s
# 1           225.773941
# 3            81.596169
# 7           861.427124
# 11          334.962402
# 15          753.600952
# 19          449.832214
# 23          627.437256
# 27          263.724030
# 31          360.436249
#
# [9 rows x 24 columns]

# %% [markdown]
# ### For final tuning curves use: average results
# ### For checking variability use: individual_results

# %% [markdown]
# ## Plot center-only spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_only"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="center_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Center spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center-only spatial frequency tuning")
plt.show()

# %% [markdown]
# ## Plot center+surround spatial frequency tuning

# %%
df = average_results[average_results["stimulus_type"] == "center_surround"].copy()

plt.figure(figsize=(8, 5))

sns.lineplot(
    data=df,
    x="surround_sf",
    y="inward_mean_response_pA",
    hue="drug",
    marker="o"
)

plt.xlabel("Surround spatial frequency")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center+surround response vs surround spatial frequency")
plt.show()

# %% [markdown]
# ## Plot control vs TTX at one condition

# %%
df = average_results[
    (average_results["stimulus_type"] == "center_surround") &
    (average_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.barplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar=None
)

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Center_Surround SF 1: control vs TTX")
plt.show()

# %% [markdown]
# ## Show individual sweep variability

# %%
df = individual_results[
    (individual_results["stimulus_type"] == "center_surround") &
    (individual_results["surround_sf"] == 1)
].copy()

plt.figure(figsize=(6, 5))

sns.stripplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    color="black",
    size=8,
    jitter=True
)

sns.pointplot(
    data=df,
    x="drug",
    y="inward_mean_response_pA",
    errorbar="se",
    color="red",
    markers="D"
)

plt.xlabel("")
plt.ylabel("Mean inward response magnitude (pA)")
plt.title("Individual sweeps: center_surround SF 1")
plt.show()

# %% [markdown]
# ## Overlay control and TTX average traces

# %%
def get_average_trace_for_row(row, baseline_window=(0.2, 1.0)):
    sweeps = parse_sweeps(row["sweeps"])

    time, corrected_traces, average_trace, baselines = average_baseline_corrected_sweeps(
        row["file"],
        sweeps,
        baseline_window=baseline_window
    )

    return time, average_trace


def overlay_average_traces(
    metadata,
    stimulus_type,
    center_sf=None,
    surround_sf=None,
    baseline_window=(0.2, 1.0),
    stim_window=(1.05, 10.0)
):
    df = metadata[metadata["stimulus_type"] == stimulus_type].copy()

    if center_sf is not None:
        df = df[df["center_sf"] == center_sf]

    if surround_sf is not None:
        df = df[df["surround_sf"] == surround_sf]

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['drug']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(f"{stimulus_type}, center SF={center_sf}, surround SF={surround_sf}")
    plt.legend()
    plt.show()

# %%
overlay_average_traces(
    metadata,
    stimulus_type="center_surround",
    center_sf=1,
    surround_sf=1,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %%
def overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=1,
    baseline_window=(0.2, 1.0),
    stim_window=(2, 10.0)
):
    df = metadata[
        (metadata["drug"] == drug) &
        (
            (
                (metadata["stimulus_type"] == "center_only") &
                (metadata["center_sf"] == center_sf)
            )
            |
            (
                (metadata["stimulus_type"] == "center_surround") &
                (metadata["center_sf"] == center_sf) &
                (metadata["surround_sf"] == surround_sf)
            )
        )
    ].copy()

    plt.figure(figsize=(12, 5))

    for _, row in df.iterrows():
        time, average_trace = get_average_trace_for_row(
            row,
            baseline_window=baseline_window
        )

        label = f"{row['stimulus_type']} | {row['file']}"
        plt.plot(time, average_trace, lw=2, label=label)

    plt.axvspan(
        stim_window[0],
        stim_window[1],
        color="orange",
        alpha=0.15,
        label="stimulus"
    )

    plt.axhline(0, color="black", lw=1)

    plt.xlabel("Time (s)")
    plt.ylabel("Baseline-subtracted current (pA)")
    plt.title(
        f"{drug}: center_only vs center_surround | "
        f"center SF={center_sf}, surround SF={surround_sf}"
    )
    plt.legend()
    plt.show()

# %%
overlay_center_vs_center_surround(
    metadata,
    drug="control",
    center_sf=1,
    surround_sf=16,
    baseline_window=baseline_window,
    stim_window=stim_window
)

# %% [markdown]
# ## Calculate surround modulation index

# %% [markdown]
# SMI = (Rc+s - Rc) / (Rc+s + Rc)

# %%
def calculate_smi(average_results, response_column="inward_mean_response_pA"):
    """
    Calculates surround modulation index for center+surround rows.

    This assumes matching center_only rows exist for the same:
    - drug
    - center_sf
    """

    center_only = average_results[
        average_results["stimulus_type"] == "center_only"
    ].copy()

    center_surround = average_results[
        average_results["stimulus_type"] == "center_surround"
    ].copy()

    smi_rows = []

    for _, cs_row in center_surround.iterrows():
        matching_center = center_only[
            (center_only["drug"] == cs_row["drug"]) &
            (center_only["center_sf"] == cs_row["center_sf"])
        ]

        if len(matching_center) == 0:
            continue

        r_center = matching_center.iloc[0][response_column]
        r_cs = cs_row[response_column]

        smi = (r_cs - r_center) / (r_cs + r_center)

        output = cs_row.to_dict()
        output["R_center"] = r_center
        output["R_center_surround"] = r_cs
        output["SMI"] = smi

        smi_rows.append(output)

    return pd.DataFrame(smi_rows)

# %%
smi_results = calculate_smi(
    average_results,
    response_column="inward_mean_response_pA"
)

smi_results
# Out:
#                   file     drug    stimulus_type  center_sf  surround_sf  \
# 0  2026_05_12_0022.abf  control  center_surround        1.0          1.0
# 1  2026_05_12_0024.abf  control  center_surround        1.0          8.0
# 2  2026_05_12_0025.abf  control  center_surround        1.0         16.0
# 3  2026_05_12_0026.abf  control  center_surround        1.0          0.5
# 4  2026_05_12_0027.abf  control  center_surround        1.0          2.0
#
#   sweeps  clamp_mV  stimID                                    notes  \
# 0  0;1;2       -70      25  center contrast 25 surround contrast 50
# 1  0;1;2       -70      27  center contrast 25 surround contrast 50
# 2  0;1;2       -70      28  center contrast 25 surround contrast 50
# 3  0;1;2       -70      29  center contrast 25 surround contrast 50
# 4  0;1;2       -70      30  center contrast 25 surround contrast 50
#
#    peak_inward_pA  ...  baseline_mean_pA  n_sweeps_averaged  \
# 0     -179.465744  ...        -67.319756                  3
# 1     -266.292145  ...        -65.942566                  3
# 2     -251.346054  ...        -65.426407                  3
# 3     -127.779945  ...        -65.498039                  3
# 4     -178.574326  ...        -69.228416                  3
#
#    inward_mean_response_pA  inward_peak_response_pA  inward_late_response_pA  \
# 0                41.870533               179.465744                41.360786
# 1                56.229370               266.292145                56.335167
# 2                78.430351               251.346054                77.980591
# 3                32.965836               127.779945                33.156555
# 4                45.054718               178.574326                44.238632
#
#   inward_early_response_pA inward_charge_pA_s   R_center  R_center_surround  \
# 0                45.429264         334.962402  107.67939          41.870533
# 1                55.478138         449.832214  107.67939          56.229370
# 2                81.563965         627.437256  107.67939          78.430351
# 3                31.625153         263.724030  107.67939          32.965836
# 4                50.756958         360.436249  107.67939          45.054718
#
#         SMI
# 0 -0.440046
# 1 -0.313894
# 2 -0.157160
# 3 -0.531220
# 4 -0.410024
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(8, 5))

sns.lineplot(
    data=smi_results,
    x="surround_sf",
    y="SMI",
    hue="drug",
    marker="o"
)

plt.axhline(0, color="black", lw=1)
plt.xlabel("Surround spatial frequency")
plt.ylabel("Surround modulation index")
plt.title("Surround modulation vs spatial frequency")
plt.show()

# %% [markdown]
# ## SAVE FIGURES

# %% [markdown]
# any plot can be saved by adding this code before plt.show()

# %%
#plt.savefig(FIG_DIR / "my_figure_name.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Things to double check
#
# 1. Are the stimulus windows correct?
# 2. Are the baseline windows quiet?
# 3. Do the three sweeps look similar?
# 4. Are inward currents plotted as positive?
# 5. Are control and TTX labels entered consistently?
# 6. Are spatial frequencies numeric?

# %%
##Checking the averaged trace
row = average_results.iloc[1]
row
# Out:
# file                        2026_05_12_0014.abf
# drug                                    control
# stimulus_type                              spot
# center_sf                                   NaN
# surround_sf                                 NaN
# sweeps                                        0
# clamp_mV                                    -70
# stimID                                       18
# notes                             ON sustained?
# peak_inward_pA                      -213.721619
# peak_outward_pA                       24.315483
# mean_response_pA                     -10.202319
# early_mean_response_pA               -70.171707
# late_mean_response_pA                 -1.633875
# charge_transfer_pA_s                 -81.596169
# analysis_level                    average_trace
# sweep                                       avg
# baseline_mean_pA                     -61.546928
# n_sweeps_averaged                             1
# inward_mean_response_pA               10.202319
# inward_peak_response_pA              213.721619
# inward_late_response_pA                1.633875
# inward_early_response_pA              70.171707
# inward_charge_pA_s                    81.596169
# Name: 3, dtype: object
